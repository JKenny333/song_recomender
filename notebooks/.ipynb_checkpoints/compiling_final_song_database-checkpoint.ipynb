# %% [markdown]
# # Final song database

# %%
import pandas as pd

# %%
#Import latest dataframe
full_af_from_csv = pd.read_csv('../data/full_af.csv')
greatest_songs_all_time_af_df = pd.read_csv('../data/greatest_songs_all_time_af.csv')
worlds_largest_af_df = pd.read_csv('../data/worlds_largest_af.csv')
r_and_b_throwbacks_af_df = pd.read_csv('../data/r_and_b_throwbacks_af.csv')
longest_playlist_ever_af_df = pd.read_csv('../data/longest_playlist_ever_af.csv')

# %%
longest_playlist_ever_af_df
# Out:
#       Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0              0         0.406   0.445    7   -13.355     0       0.0745
# 1              1         0.419   0.565    5   -11.565     1       0.0347
# 2              2         0.532   0.303    9   -13.076     1       0.0311
# 3              3         0.717   0.800    5    -5.794     0       0.0497
# 4              4         0.571   0.724    0    -5.967     1       0.0260
# ...          ...           ...     ...  ...       ...   ...          ...
# 9912        9912         0.651   0.801    0    -7.340     1       0.0514
# 9913        9913         0.812   0.644    0   -10.761     1       0.0493
# 9914        9914         0.687   0.606    7    -5.920     1       0.0262
# 9915        9915         0.711   0.718    6    -5.739     1       0.0380
# 9916        9916         0.324   0.997    1    -3.440     1       0.2640
#
#       acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.09300          0.072100    0.1130    0.123  134.972
# 1          0.13700          0.337000    0.1280    0.648  151.277
# 2          0.58700          0.065700    0.1110    0.225  124.157
# 3          0.37100          0.158000    0.3270    0.954  129.642
# 4          0.02310          0.003110    0.0919    0.385  116.755
# ...            ...               ...       ...      ...      ...
# 9912       0.12300          0.000000    0.0825    0.776  133.769
# 9913       0.08770          0.785000    0.0563    0.989  140.075
# 9914       0.17800          0.000326    0.0830    0.748   80.569
# 9915       0.00824          0.002080    0.0732    0.688  117.071
# 9916       0.00772          0.110000    0.9480    0.316  200.031
#
#                 type                      id  \
# 0     audio_features  3lMSWyB8H0A0rSRhUDSwoz
# 1     audio_features  3UnyplmZaq547hwsfOR5yy
# 2     audio_features  3HPLfZhQUds6N6tZ4WiApn
# 3     audio_features  5iFhkFf9JLA3XiROdYsg1i
# 4     audio_features  1VZedwJj1gyi88WFRhfThb
# ...              ...                     ...
# 9912  audio_features  5jzma6gCzYtKB1DbEwFZKH
# 9913  audio_features  7Bz8yww6UMbTgTVLG6zbI4
# 9914  audio_features  0jpk88zk40MjQ63ljrq7V2
# 9915  audio_features  0sEm1ld0V8YTCPcjPVfIsc
# 9916  audio_features  1ZRPhbplXmODTxBfmILr16
#
#                                        uri  \
# 0     spotify:track:3lMSWyB8H0A0rSRhUDSwoz
# 1     spotify:track:3UnyplmZaq547hwsfOR5yy
# 2     spotify:track:3HPLfZhQUds6N6tZ4WiApn
# 3     spotify:track:5iFhkFf9JLA3XiROdYsg1i
# 4     spotify:track:1VZedwJj1gyi88WFRhfThb
# ...                                    ...
# 9912  spotify:track:5jzma6gCzYtKB1DbEwFZKH
# 9913  spotify:track:7Bz8yww6UMbTgTVLG6zbI4
# 9914  spotify:track:0jpk88zk40MjQ63ljrq7V2
# 9915  spotify:track:0sEm1ld0V8YTCPcjPVfIsc
# 9916  spotify:track:1ZRPhbplXmODTxBfmILr16
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/3lMSWyB8H0A0...
# 1     https://api.spotify.com/v1/tracks/3UnyplmZaq54...
# 2     https://api.spotify.com/v1/tracks/3HPLfZhQUds6...
# 3     https://api.spotify.com/v1/tracks/5iFhkFf9JLA3...
# 4     https://api.spotify.com/v1/tracks/1VZedwJj1gyi...
# ...                                                 ...
# 9912  https://api.spotify.com/v1/tracks/5jzma6gCzYtK...
# 9913  https://api.spotify.com/v1/tracks/7Bz8yww6UMbT...
# 9914  https://api.spotify.com/v1/tracks/0jpk88zk40Mj...
# 9915  https://api.spotify.com/v1/tracks/0sEm1ld0V8YT...
# 9916  https://api.spotify.com/v1/tracks/1ZRPhbplXmOD...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/3lMS...       152560
# 1     https://api.spotify.com/v1/audio-analysis/3Uny...       197707
# 2     https://api.spotify.com/v1/audio-analysis/3HPL...       244285
# 3     https://api.spotify.com/v1/audio-analysis/5iFh...       250000
# 4     https://api.spotify.com/v1/audio-analysis/1VZe...       278320
# ...                                                 ...          ...
# 9912  https://api.spotify.com/v1/audio-analysis/5jzm...       200480
# 9913  https://api.spotify.com/v1/audio-analysis/7Bz8...       190827
# 9914  https://api.spotify.com/v1/audio-analysis/0jpk...       206307
# 9915  https://api.spotify.com/v1/audio-analysis/0sEm...       200293
# 9916  https://api.spotify.com/v1/audio-analysis/1ZRP...       409013
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 9912               4
# 9913               4
# 9914               4
# 9915               4
# 9916               4
#
# [9917 rows x 19 columns]

# %%
full_af = pd.concat([full_af_from_csv,longest_playlist_ever_af_df], ignore_index=True)
full_af
# Out:
#        Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0               0         0.382   0.451    7    -6.606     0       0.0293
# 1               1         0.742   0.375    7   -13.829     1       0.0482
# 2               2         0.585   0.552    0   -10.613     1       0.0353
# 3               3         0.405   0.535    6    -7.504     0       0.0531
# 4               4         0.586   0.526    0    -6.928     1       0.0564
# ...           ...           ...     ...  ...       ...   ...          ...
# 23860        9912         0.651   0.801    0    -7.340     1       0.0514
# 23861        9913         0.812   0.644    0   -10.761     1       0.0493
# 23862        9914         0.687   0.606    7    -5.920     1       0.0262
# 23863        9915         0.711   0.718    6    -5.739     1       0.0380
# 23864        9916         0.324   0.997    1    -3.440     1       0.2640
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 0           0.55700          0.000034    0.2650    0.506  150.803
# 1           0.39700          0.901000    0.0996    0.105  102.023
# 2           0.19400          0.017100    0.0735    0.496  100.089
# 3           0.05310          0.106000    0.0696    0.637   97.698
# 4           0.55500          0.000000    0.2340    0.456  107.153
# ...             ...               ...       ...      ...      ...
# 23860       0.12300          0.000000    0.0825    0.776  133.769
# 23861       0.08770          0.785000    0.0563    0.989  140.075
# 23862       0.17800          0.000326    0.0830    0.748   80.569
# 23863       0.00824          0.002080    0.0732    0.688  117.071
# 23864       0.00772          0.110000    0.9480    0.316  200.031
#
#                  type                      id  \
# 0      audio_features  6yzJiHzsscf0n88xb9aNT4
# 1      audio_features  5zdXRoKLZ54VBdbdn7yhz4
# 2      audio_features  5qvCKAyjgHnpR5c63OedCY
# 3      audio_features  2vByA9JgfMU2bPjUqmxCdv
# 4      audio_features  0pPQwIjwqduvLfZORYYEaI
# ...               ...                     ...
# 23860  audio_features  5jzma6gCzYtKB1DbEwFZKH
# 23861  audio_features  7Bz8yww6UMbTgTVLG6zbI4
# 23862  audio_features  0jpk88zk40MjQ63ljrq7V2
# 23863  audio_features  0sEm1ld0V8YTCPcjPVfIsc
# 23864  audio_features  1ZRPhbplXmODTxBfmILr16
#
#                                         uri  \
# 0      spotify:track:6yzJiHzsscf0n88xb9aNT4
# 1      spotify:track:5zdXRoKLZ54VBdbdn7yhz4
# 2      spotify:track:5qvCKAyjgHnpR5c63OedCY
# 3      spotify:track:2vByA9JgfMU2bPjUqmxCdv
# 4      spotify:track:0pPQwIjwqduvLfZORYYEaI
# ...                                     ...
# 23860  spotify:track:5jzma6gCzYtKB1DbEwFZKH
# 23861  spotify:track:7Bz8yww6UMbTgTVLG6zbI4
# 23862  spotify:track:0jpk88zk40MjQ63ljrq7V2
# 23863  spotify:track:0sEm1ld0V8YTCPcjPVfIsc
# 23864  spotify:track:1ZRPhbplXmODTxBfmILr16
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/6yzJiHzsscf0...
# 1      https://api.spotify.com/v1/tracks/5zdXRoKLZ54V...
# 2      https://api.spotify.com/v1/tracks/5qvCKAyjgHnp...
# 3      https://api.spotify.com/v1/tracks/2vByA9JgfMU2...
# 4      https://api.spotify.com/v1/tracks/0pPQwIjwqduv...
# ...                                                  ...
# 23860  https://api.spotify.com/v1/tracks/5jzma6gCzYtK...
# 23861  https://api.spotify.com/v1/tracks/7Bz8yww6UMbT...
# 23862  https://api.spotify.com/v1/tracks/0jpk88zk40Mj...
# 23863  https://api.spotify.com/v1/tracks/0sEm1ld0V8YT...
# 23864  https://api.spotify.com/v1/tracks/1ZRPhbplXmOD...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/6yzJ...       267540
# 1      https://api.spotify.com/v1/audio-analysis/5zdX...       342163
# 2      https://api.spotify.com/v1/audio-analysis/5qvC...       267813
# 3      https://api.spotify.com/v1/audio-analysis/2vBy...       210800
# 4      https://api.spotify.com/v1/audio-analysis/0pPQ...       161267
# ...                                                  ...          ...
# 23860  https://api.spotify.com/v1/audio-analysis/5jzm...       200480
# 23861  https://api.spotify.com/v1/audio-analysis/7Bz8...       190827
# 23862  https://api.spotify.com/v1/audio-analysis/0jpk...       206307
# 23863  https://api.spotify.com/v1/audio-analysis/0sEm...       200293
# 23864  https://api.spotify.com/v1/audio-analysis/1ZRP...       409013
#
#        time_signature
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 23860               4
# 23861               4
# 23862               4
# 23863               4
# 23864               4
#
# [23865 rows x 19 columns]

# %%
full_af.drop('Unnamed: 0', axis=1, inplace=True)

# %%
full_af
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.382   0.451    7    -6.606     0       0.0293        0.5570
# 1             0.742   0.375    7   -13.829     1       0.0482        0.3970
# 2             0.585   0.552    0   -10.613     1       0.0353        0.1940
# 3             0.405   0.535    6    -7.504     0       0.0531        0.0531
# 4             0.586   0.526    0    -6.928     1       0.0564        0.5550
# ...             ...     ...  ...       ...   ...          ...           ...
# 20831         0.468   0.723    1    -5.344     1       0.0782        0.1900
# 20832         0.730   0.602    6    -3.782     0       0.2060        0.3620
# 20833         0.794   0.662    6    -4.913     0       0.2490        0.0789
# 20834         0.764   0.821    4    -6.095     0       0.1940        0.0922
# 20835         0.652   0.473    0    -7.981     0       0.0313        0.2430
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.000034    0.2650    0.506  150.803  audio_features
# 1              0.901000    0.0996    0.105  102.023  audio_features
# 2              0.017100    0.0735    0.496  100.089  audio_features
# 3              0.106000    0.0696    0.637   97.698  audio_features
# 4              0.000000    0.2340    0.456  107.153  audio_features
# ...                 ...       ...      ...      ...             ...
# 20831          0.000000    0.3660    0.449  178.860  audio_features
# 20832          0.000004    0.1690    0.927   97.954  audio_features
# 20833          0.000000    0.0937    0.683   93.053  audio_features
# 20834          0.000000    0.1590    0.962  162.495  audio_features
# 20835          0.000000    0.1340    0.368  123.208  audio_features
#
#                            id                                   uri  \
# 0      6yzJiHzsscf0n88xb9aNT4  spotify:track:6yzJiHzsscf0n88xb9aNT4
# 1      5zdXRoKLZ54VBdbdn7yhz4  spotify:track:5zdXRoKLZ54VBdbdn7yhz4
# 2      5qvCKAyjgHnpR5c63OedCY  spotify:track:5qvCKAyjgHnpR5c63OedCY
# 3      2vByA9JgfMU2bPjUqmxCdv  spotify:track:2vByA9JgfMU2bPjUqmxCdv
# 4      0pPQwIjwqduvLfZORYYEaI  spotify:track:0pPQwIjwqduvLfZORYYEaI
# ...                       ...                                   ...
# 20831  1PzVLh1uoq5pAUnqNQElQq  spotify:track:1PzVLh1uoq5pAUnqNQElQq
# 20832  69XUpOpjzDKcfdxqZebGiI  spotify:track:69XUpOpjzDKcfdxqZebGiI
# 20833  6Wnlq1Pu3I0BajLvxn05Vr  spotify:track:6Wnlq1Pu3I0BajLvxn05Vr
# 20834  75ABQumvUWSaUsEGjZFu3G  spotify:track:75ABQumvUWSaUsEGjZFu3G
# 20835  2b29qJRy4asbQNFjPO96XC  spotify:track:2b29qJRy4asbQNFjPO96XC
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/6yzJiHzsscf0...
# 1      https://api.spotify.com/v1/tracks/5zdXRoKLZ54V...
# 2      https://api.spotify.com/v1/tracks/5qvCKAyjgHnp...
# 3      https://api.spotify.com/v1/tracks/2vByA9JgfMU2...
# 4      https://api.spotify.com/v1/tracks/0pPQwIjwqduv...
# ...                                                  ...
# 20831  https://api.spotify.com/v1/tracks/1PzVLh1uoq5p...
# 20832  https://api.spotify.com/v1/tracks/69XUpOpjzDKc...
# 20833  https://api.spotify.com/v1/tracks/6Wnlq1Pu3I0B...
# 20834  https://api.spotify.com/v1/tracks/75ABQumvUWSa...
# 20835  https://api.spotify.com/v1/tracks/2b29qJRy4asb...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/6yzJ...       267540
# 1      https://api.spotify.com/v1/audio-analysis/5zdX...       342163
# 2      https://api.spotify.com/v1/audio-analysis/5qvC...       267813
# 3      https://api.spotify.com/v1/audio-analysis/2vBy...       210800
# 4      https://api.spotify.com/v1/audio-analysis/0pPQ...       161267
# ...                                                  ...          ...
# 20831  https://api.spotify.com/v1/audio-analysis/1PzV...       181027
# 20832  https://api.spotify.com/v1/audio-analysis/69XU...       221133
# 20833  https://api.spotify.com/v1/audio-analysis/6Wnl...       284640
# 20834  https://api.spotify.com/v1/audio-analysis/75AB...       282173
# 20835  https://api.spotify.com/v1/audio-analysis/2b29...       294867
#
#        time_signature
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 20831               4
# 20832               4
# 20833               4
# 20834               4
# 20835               4
#
# [20836 rows x 18 columns]

# %%
full_af = full_af.drop_duplicates()

full_af.reset_index(drop=True, inplace=True)
full_af
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.382   0.451    7    -6.606     0       0.0293       0.55700
# 1             0.742   0.375    7   -13.829     1       0.0482       0.39700
# 2             0.585   0.552    0   -10.613     1       0.0353       0.19400
# 3             0.405   0.535    6    -7.504     0       0.0531       0.05310
# 4             0.586   0.526    0    -6.928     1       0.0564       0.55500
# ...             ...     ...  ...       ...   ...          ...           ...
# 19368         0.876   0.786    5    -3.515     1       0.0787       0.20700
# 19369         0.423   0.954    7    -3.157     0       0.0470       0.00210
# 19370         0.687   0.606    7    -5.920     1       0.0262       0.17800
# 19371         0.711   0.718    6    -5.739     1       0.0380       0.00824
# 19372         0.324   0.997    1    -3.440     1       0.2640       0.00772
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.000034    0.2650    0.506  150.803  audio_features
# 1              0.901000    0.0996    0.105  102.023  audio_features
# 2              0.017100    0.0735    0.496  100.089  audio_features
# 3              0.106000    0.0696    0.637   97.698  audio_features
# 4              0.000000    0.2340    0.456  107.153  audio_features
# ...                 ...       ...      ...      ...             ...
# 19368          0.812000    0.0724    0.808  154.024  audio_features
# 19369          0.000000    0.1770    0.500  144.553  audio_features
# 19370          0.000326    0.0830    0.748   80.569  audio_features
# 19371          0.002080    0.0732    0.688  117.071  audio_features
# 19372          0.110000    0.9480    0.316  200.031  audio_features
#
#                            id                                   uri  \
# 0      6yzJiHzsscf0n88xb9aNT4  spotify:track:6yzJiHzsscf0n88xb9aNT4
# 1      5zdXRoKLZ54VBdbdn7yhz4  spotify:track:5zdXRoKLZ54VBdbdn7yhz4
# 2      5qvCKAyjgHnpR5c63OedCY  spotify:track:5qvCKAyjgHnpR5c63OedCY
# 3      2vByA9JgfMU2bPjUqmxCdv  spotify:track:2vByA9JgfMU2bPjUqmxCdv
# 4      0pPQwIjwqduvLfZORYYEaI  spotify:track:0pPQwIjwqduvLfZORYYEaI
# ...                       ...                                   ...
# 19368  7Ca06cMSgTwcz2JfxvAD3E  spotify:track:7Ca06cMSgTwcz2JfxvAD3E
# 19369  3jJZVeExYzVYiV6Y9Fl3DX  spotify:track:3jJZVeExYzVYiV6Y9Fl3DX
# 19370  0jpk88zk40MjQ63ljrq7V2  spotify:track:0jpk88zk40MjQ63ljrq7V2
# 19371  0sEm1ld0V8YTCPcjPVfIsc  spotify:track:0sEm1ld0V8YTCPcjPVfIsc
# 19372  1ZRPhbplXmODTxBfmILr16  spotify:track:1ZRPhbplXmODTxBfmILr16
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/6yzJiHzsscf0...
# 1      https://api.spotify.com/v1/tracks/5zdXRoKLZ54V...
# 2      https://api.spotify.com/v1/tracks/5qvCKAyjgHnp...
# 3      https://api.spotify.com/v1/tracks/2vByA9JgfMU2...
# 4      https://api.spotify.com/v1/tracks/0pPQwIjwqduv...
# ...                                                  ...
# 19368  https://api.spotify.com/v1/tracks/7Ca06cMSgTwc...
# 19369  https://api.spotify.com/v1/tracks/3jJZVeExYzVY...
# 19370  https://api.spotify.com/v1/tracks/0jpk88zk40Mj...
# 19371  https://api.spotify.com/v1/tracks/0sEm1ld0V8YT...
# 19372  https://api.spotify.com/v1/tracks/1ZRPhbplXmOD...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/6yzJ...       267540
# 1      https://api.spotify.com/v1/audio-analysis/5zdX...       342163
# 2      https://api.spotify.com/v1/audio-analysis/5qvC...       267813
# 3      https://api.spotify.com/v1/audio-analysis/2vBy...       210800
# 4      https://api.spotify.com/v1/audio-analysis/0pPQ...       161267
# ...                                                  ...          ...
# 19368  https://api.spotify.com/v1/audio-analysis/7Ca0...       204560
# 19369  https://api.spotify.com/v1/audio-analysis/3jJZ...       310347
# 19370  https://api.spotify.com/v1/audio-analysis/0jpk...       206307
# 19371  https://api.spotify.com/v1/audio-analysis/0sEm...       200293
# 19372  https://api.spotify.com/v1/audio-analysis/1ZRP...       409013
#
#        time_signature
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 19368               4
# 19369               4
# 19370               4
# 19371               4
# 19372               4
#
# [19373 rows x 18 columns]

# %%
#export to csv
full_af.to_csv("../data/full_af.csv")
