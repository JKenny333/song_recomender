# %% [markdown]
# # Installing Spotipy

# %%
## conda install -c conda-forge spotipy
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 24.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.1.1
#
#
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
 ## conda update -n base -c defaults conda
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/jameskenny/anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     abseil-cpp-20230802.0      |       h313beb8_2         1.3 MB
#     aiobotocore-2.7.0          |  py311hca03da5_0         154 KB
#     aiohttp-3.9.3              |  py311h80987f9_0         799 KB
#     anaconda-cloud-auth-0.1.4  |  py311hca03da5_0          39 KB
#     anyio-4.2.0                |  py311hca03da5_0         238 KB
#     archspec-0.2.1             |     pyhd3eb1b0_0          39 KB
#     arrow-cpp-14.0.2           |       hc7aafb3_1         7.8 MB
#     astropy-5.3.4              |  py311hb9f6ed7_0         9.8 MB
#     async-lru-2.0.4            |  py311hca03da5_0          22 KB
#     async-timeout-4.0.3        |  py311hca03da5_0          15 KB
#     attrs-23.1.0               |  py311hca03da5_0         163 KB
#     aws-c-auth-0.6.19          |       h80987f9_0          87 KB
#     aws-c-cal-0.5.20           |       h80987f9_0          39 KB
#     aws-c-common-0.8.5         |       h80987f9_0         186 KB
#     aws-c-compression-0.2.16   |       h80987f9_0          18 KB
#     aws-c-event-stream-0.2.15  |       h313beb8_0          45 KB
#     aws-c-http-0.6.25          |       h80987f9_0         164 KB
#     aws-c-io-0.13.10           |       h80987f9_0         133 KB
#     aws-c-mqtt-0.7.13          |       h80987f9_0          62 KB
#     aws-c-s3-0.1.51            |       h80987f9_0          63 KB
#     aws-c-sdkutils-0.1.6       |       h80987f9_0          45 KB
#     aws-checksums-0.1.13       |       h80987f9_0          48 KB
#     aws-crt-cpp-0.18.16        |       h313beb8_0         203 KB
#     aws-sdk-cpp-1.10.55        |       h313beb8_0         2.0 MB
#     black-23.11.0              |  py311hca03da5_0         364 KB
#     bokeh-3.3.4                |  py311hb6e6a13_0         5.7 MB
#     boost-cpp-1.82.0           |       h48ca7d4_2          12 KB
#     botocore-1.31.64           |  py311hca03da5_0         7.0 MB
#     bottleneck-1.3.7           |  py311hb9f6ed7_0         128 KB
#     brotli-python-1.0.9        |  py311h313beb8_7         321 KB
#     c-blosc2-2.12.0            |       h7df6c2f_0         266 KB
#     certifi-2024.2.2           |  py311hca03da5_0         161 KB
#     cffi-1.16.0                |  py311h80987f9_0         296 KB
#     click-8.1.7                |  py311hca03da5_0         217 KB
#     conda-24.1.1               |  py311hca03da5_0         1.2 MB
#     conda-build-24.1.1         |  py311hca03da5_0         815 KB
#     conda-index-0.4.0          |     pyhd3eb1b0_0         173 KB
#     conda-libmamba-solver-24.1.0|     pyhd3eb1b0_0          39 KB
#     constantly-23.10.4         |  py311hca03da5_0          33 KB
#     contourpy-1.2.0            |  py311h48ca7d4_0         255 KB
#     cookiecutter-2.5.0         |  py311hca03da5_0         142 KB
#     cryptography-41.0.7        |  py311hd4332d6_0         1.3 MB
#     cssselect-1.2.0            |  py311hca03da5_0          50 KB
#     curl-8.5.0                 |       h02f6b3c_0          79 KB
#     cytoolz-0.12.2             |  py311h80987f9_0         368 KB
#     dask-2023.11.0             |  py311hca03da5_0           6 KB
#     dask-core-2023.11.0        |  py311hca03da5_0         2.9 MB
#     datashader-0.16.0          |  py311hca03da5_0        17.1 MB
#     deprecated-1.2.13          |  py311hca03da5_0          19 KB
#     distributed-2023.11.0      |  py311hca03da5_0         1.7 MB
#     distro-1.8.0               |  py311hca03da5_0          38 KB
#     filelock-3.13.1            |  py311hca03da5_0          25 KB
#     flask-2.2.5                |  py311hca03da5_0         191 KB
#     frozenlist-1.4.0           |  py311h80987f9_0          48 KB
#     fsspec-2023.10.0           |  py311hca03da5_0         366 KB
#     gflags-2.2.2               |       h313beb8_1         125 KB
#     glog-0.5.0                 |       h313beb8_1          92 KB
#     greenlet-3.0.1             |  py311h313beb8_0         225 KB
#     grpc-cpp-1.48.2            |       hc60591f_4         3.0 MB
#     gtest-1.14.0               |       h48ca7d4_0         390 KB
#     holoviews-1.18.3           |  py311hca03da5_0         5.2 MB
#     huggingface_hub-0.17.3     |  py311hca03da5_0         453 KB
#     hvplot-0.9.2               |  py311hca03da5_0         1.9 MB
#     icu-73.1                   |       h313beb8_0        25.4 MB
#     imageio-2.33.1             |  py311hca03da5_0         616 KB
#     imbalanced-learn-0.11.0    |  py311hca03da5_1         385 KB
#     importlib-metadata-7.0.1   |  py311hca03da5_0          50 KB
#     importlib_metadata-7.0.1   |       hd3eb1b0_0           8 KB
#     ipykernel-6.28.0           |  py311hca03da5_0         247 KB
#     ipython-8.20.0             |  py311hca03da5_0         1.4 MB
#     jinja2-3.1.3               |  py311hca03da5_0         361 KB
#     jmespath-1.0.1             |  py311hca03da5_0          50 KB
#     jsonschema-4.19.2          |  py311hca03da5_0         195 KB
#     jsonschema-specifications-2023.7.1|  py311hca03da5_0          17 KB
#     jupyter-lsp-2.2.0          |  py311hca03da5_0         108 KB
#     jupyter_client-8.6.0       |  py311hca03da5_0         235 KB
#     jupyter_core-5.5.0         |  py311hca03da5_0          92 KB
#     jupyter_events-0.8.0       |  py311hca03da5_0          43 KB
#     jupyter_server-2.10.0      |  py311hca03da5_0         587 KB
#     jupyter_server_terminals-0.4.4|  py311hca03da5_1          28 KB
#     jupyterlab-4.0.11          |  py311hca03da5_0         4.5 MB
#     jupyterlab_server-2.25.1   |  py311hca03da5_0         112 KB
#     jupyterlab_widgets-3.0.9   |  py311hca03da5_0         196 KB
#     lazy_loader-0.3            |  py311hca03da5_0          21 KB
#     libboost-1.82.0            |       h0bc93f9_2        18.2 MB
#     libcurl-8.5.0              |       h3e2b118_0         356 KB
#     libdeflate-1.17            |       h80987f9_1          55 KB
#     libedit-3.1.20230828       |       h80987f9_0         155 KB
#     libmamba-1.5.6             |       h15e39b3_0         1.3 MB
#     libmambapy-1.5.6           |  py311h1c5506f_0         273 KB
#     libnghttp2-1.57.0          |       h62f6fdd_0         634 KB
#     libpq-12.17                |       h02f6b3c_0         2.4 MB
#     libxml2-2.10.4             |       h0dcf63f_1         639 KB
#     libxslt-1.1.37             |       h80987f9_1         238 KB
#     llvmlite-0.42.0            |  py311h313beb8_0         398 KB
#     markupsafe-2.1.3           |  py311h80987f9_0          26 KB
#     matplotlib-3.8.0           |  py311hca03da5_0           9 KB
#     matplotlib-base-3.8.0      |  py311h7aedaa7_0         7.7 MB
#     menuinst-2.0.2             |  py311hca03da5_0         166 KB
#     mistune-2.0.4              |  py311hca03da5_0         108 KB
#     more-itertools-10.1.0      |  py311hca03da5_0         103 KB
#     multidict-6.0.4            |  py311h80987f9_0          54 KB
#     nbclient-0.8.0             |  py311hca03da5_0         120 KB
#     nbconvert-7.10.0           |  py311hca03da5_0         517 KB
#     notebook-7.0.6             |  py311hca03da5_0         3.3 MB
#     notebook-shim-0.2.3        |  py311hca03da5_0          27 KB
#     numba-0.59.0               |  py311h7aedaa7_0         5.8 MB
#     numexpr-2.8.7              |  py311h6dc990b_0         151 KB
#     numpy-1.26.3               |  py311he598dae_0          11 KB
#     numpy-base-1.26.3          |  py311hfbfe69c_0         6.9 MB
#     openssl-3.0.13             |       h1a28f6b_0         5.0 MB
#     overrides-7.4.0            |  py311hca03da5_0          38 KB
#     pandas-2.1.4               |  py311h7aedaa7_0        14.3 MB
#     panel-1.3.8                |  py311hca03da5_0        15.3 MB
#     param-2.0.2                |  py311hca03da5_0         260 KB
#     parsel-1.8.1               |  py311hca03da5_0          52 KB
#     partd-1.4.1                |  py311hca03da5_0          49 KB
#     pillow-10.2.0              |  py311h80987f9_0         855 KB
#     prompt-toolkit-3.0.43      |  py311hca03da5_0         735 KB
#     prompt_toolkit-3.0.43      |       hd3eb1b0_0           5 KB
#     py-cpuinfo-9.0.0           |  py311hca03da5_0          65 KB
#     pyarrow-14.0.2             |  py311ha07b5f9_0         4.2 MB
#     pycosat-0.6.6              |  py311h80987f9_0          88 KB
#     pydantic-1.10.12           |  py311h80987f9_1         2.1 MB
#     pyodbc-5.0.1               |  py311h313beb8_0          68 KB
#     pyqt-5.15.10               |  py311h313beb8_0         4.3 MB
#     pyqt5-sip-12.13.0          |  py311h80987f9_0          82 KB
#     pyqtwebengine-5.15.10      |  py311h313beb8_0         141 KB
#     pytables-3.9.2             |  py311h0326f10_0         1.6 MB
#     pytoolconfig-1.2.6         |  py311hca03da5_0          37 KB
#     pyviz_comms-3.0.0          |  py311hca03da5_0          56 KB
#     pywavelets-1.5.0           |  py311hb9f6ed7_0         3.6 MB
#     pyyaml-6.0.1               |  py311h80987f9_0         197 KB
#     pyzmq-25.1.2               |  py311h313beb8_0         520 KB
#     qt-main-5.15.2             |      h0917680_10        38.5 MB
#     qtpy-2.4.1                 |  py311hca03da5_0         132 KB
#     queuelib-1.6.2             |  py311hca03da5_0          36 KB
#     redis-py-4.3.4             |  py311hca03da5_0         432 KB
#     referencing-0.30.2         |  py311hca03da5_0          80 KB
#     regex-2023.10.3            |  py311h80987f9_0         394 KB
#     rich-13.3.5                |  py311hca03da5_0         561 KB
#     rpds-py-0.10.6             |  py311hf0e4da2_0         312 KB
#     s3fs-2023.10.0             |  py311hca03da5_0          80 KB
#     safetensors-0.4.0          |  py311h62f922a_0         404 KB
#     scikit-image-0.22.0        |  py311h7aedaa7_0        10.3 MB
#     scikit-learn-1.2.2         |  py311h313beb8_1         8.2 MB
#     scipy-1.11.4               |  py311hc76d9b0_0        21.1 MB
#     semver-2.13.0              |     pyhd3eb1b0_0          16 KB
#     send2trash-1.8.2           |  py311hca03da5_0          34 KB
#     sip-6.7.12                 |  py311h313beb8_0         594 KB
#     snappy-1.1.10              |       h313beb8_1          37 KB
#     sniffio-1.3.0              |  py311hca03da5_0          18 KB
#     soupsieve-2.5              |  py311hca03da5_0          96 KB
#     sqlalchemy-2.0.25          |  py311h80987f9_0         3.8 MB
#     sympy-1.12                 |  py311hca03da5_0        14.4 MB
#     tabulate-0.9.0             |  py311hca03da5_0          70 KB
#     tornado-6.3.3              |  py311h80987f9_0         853 KB
#     truststore-0.8.0           |  py311hca03da5_0          45 KB
#     typing-extensions-4.9.0    |  py311hca03da5_1          10 KB
#     typing_extensions-4.9.0    |  py311hca03da5_1          71 KB
#     tzdata-2023d               |       h04d1e81_0         117 KB
#     urllib3-1.26.18            |  py311hca03da5_0         254 KB
#     utf8proc-2.6.1             |       h80987f9_1          97 KB
#     xz-5.4.5                   |       h80987f9_0         366 KB
#     yaml-cpp-0.8.0             |       h313beb8_0         476 KB
#     yarl-1.9.3                 |  py311h80987f9_0         118 KB
#     zeromq-4.3.5               |       h313beb8_0         306 KB
#     zict-3.0.0                 |  py311hca03da5_0         121 KB
#     zipp-3.17.0                |  py311hca03da5_0          26 KB
#     ------------------------------------------------------------
#                                            Total:       316.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   archspec           pkgs/main/noarch::archspec-0.2.1-pyhd3eb1b0_0
#   async-lru          pkgs/main/osx-arm64::async-lru-2.0.4-py311hca03da5_0
#   aws-c-auth         pkgs/main/osx-arm64::aws-c-auth-0.6.19-h80987f9_0
#   aws-c-cal          pkgs/main/osx-arm64::aws-c-cal-0.5.20-h80987f9_0
#   aws-c-compression  pkgs/main/osx-arm64::aws-c-compression-0.2.16-h80987f9_0
#   aws-c-http         pkgs/main/osx-arm64::aws-c-http-0.6.25-h80987f9_0
#   aws-c-io           pkgs/main/osx-arm64::aws-c-io-0.13.10-h80987f9_0
#   aws-c-mqtt         pkgs/main/osx-arm64::aws-c-mqtt-0.7.13-h80987f9_0
#   aws-c-s3           pkgs/main/osx-arm64::aws-c-s3-0.1.51-h80987f9_0
#   aws-c-sdkutils     pkgs/main/osx-arm64::aws-c-sdkutils-0.1.6-h80987f9_0
#   aws-crt-cpp        pkgs/main/osx-arm64::aws-crt-cpp-0.18.16-h313beb8_0
#   brotli-python      pkgs/main/osx-arm64::brotli-python-1.0.9-py311h313beb8_7
#   deprecated         pkgs/main/osx-arm64::deprecated-1.2.13-py311hca03da5_0
#   distro             pkgs/main/osx-arm64::distro-1.8.0-py311hca03da5_0
#   gtest              pkgs/main/osx-arm64::gtest-1.14.0-h48ca7d4_0
#   jsonschema-specif~ pkgs/main/osx-arm64::jsonschema-specifications-2023.7.1-py311hca03da5_0
#   jupyter-lsp        pkgs/main/osx-arm64::jupyter-lsp-2.2.0-py311hca03da5_0
#   jupyter_server_te~ pkgs/main/osx-arm64::jupyter_server_terminals-0.4.4-py311hca03da5_1
#   menuinst           pkgs/main/osx-arm64::menuinst-2.0.2-py311hca03da5_0
#   overrides          pkgs/main/osx-arm64::overrides-7.4.0-py311hca03da5_0
#   referencing        pkgs/main/osx-arm64::referencing-0.30.2-py311hca03da5_0
#   rich               pkgs/main/osx-arm64::rich-13.3.5-py311hca03da5_0
#   rpds-py            pkgs/main/osx-arm64::rpds-py-0.10.6-py311hf0e4da2_0
#   semver             pkgs/main/noarch::semver-2.13.0-pyhd3eb1b0_0
#   truststore         pkgs/main/osx-arm64::truststore-0.8.0-py311hca03da5_0
#
# The following packages will be REMOVED:
#
#   aiofiles-22.1.0-py311hca03da5_0
#   aiosqlite-0.18.0-py311hca03da5_0
#   backcall-0.2.0-pyhd3eb1b0_0
#   brotlipy-0.7.0-py311h80987f9_1002
#   datashape-0.5.4-py311hca03da5_1
#   glob2-0.7-pyhd3eb1b0_0
#   jinja2-time-0.2.0-pyhd3eb1b0_3
#   jupyter_server_fileid-0.9.0-py311hca03da5_0
#   jupyter_server_ydoc-0.8.0-py311hca03da5_1
#   jupyter_ydoc-0.2.4-py311hca03da5_0
#   libwebp-1.3.2-ha3663a8_0
#   nbclassic-0.5.5-py311hca03da5_0
#   poyo-0.5.0-pyhd3eb1b0_0
#   pyrsistent-0.18.0-py311h80987f9_0
#   qtwebkit-5.212-h19f419d_5
#   y-py-0.5.9-py311ha6e5c4f_0
#   ypy-websocket-0.8.2-py311hca03da5_0
#
# The following packages will be UPDATED:
#
#   abseil-cpp                          20211102.0-hc377ac9_0 --> 20230802.0-h313beb8_2
#   aiobotocore                         2.5.0-py311hca03da5_0 --> 2.7.0-py311hca03da5_0
#   aiohttp                             3.8.5-py311h80987f9_0 --> 3.9.3-py311h80987f9_0
#   anaconda-cloud-au~                  0.1.3-py311hca03da5_0 --> 0.1.4-py311hca03da5_0
#   anyio                               3.5.0-py311hca03da5_0 --> 4.2.0-py311hca03da5_0
#   arrow-cpp                               11.0.0-hc7aafb3_2 --> 14.0.2-hc7aafb3_1
#   astropy                               5.1-py311ha0d4635_0 --> 5.3.4-py311hb9f6ed7_0
#   async-timeout                       4.0.2-py311hca03da5_0 --> 4.0.3-py311hca03da5_0
#   attrs                              22.1.0-py311hca03da5_0 --> 23.1.0-py311hca03da5_0
#   aws-c-common                             0.6.8-h80987f9_1 --> 0.8.5-h80987f9_0
#   aws-c-event-stream                       0.1.6-h313beb8_6 --> 0.2.15-h313beb8_0
#   aws-checksums                           0.1.11-h80987f9_2 --> 0.1.13-h80987f9_0
#   aws-sdk-cpp                            1.8.185-ha71a6ea_1 --> 1.10.55-h313beb8_0
#   black                              23.3.0-py311hca03da5_0 --> 23.11.0-py311hca03da5_0
#   bokeh                               3.2.1-py311hb6e6a13_0 --> 3.3.4-py311hb6e6a13_0
#   boost-cpp                              1.73.0-h1a28f6b_12 --> 1.82.0-h48ca7d4_2
#   botocore                          1.29.76-py311hca03da5_0 --> 1.31.64-py311hca03da5_0
#   bottleneck                          1.3.5-py311ha0d4635_0 --> 1.3.7-py311hb9f6ed7_0
#   c-blosc2                                 2.8.0-h313beb8_0 --> 2.12.0-h7df6c2f_0
#   cffi                               1.15.1-py311h80987f9_3 --> 1.16.0-py311h80987f9_0
#   click                               8.0.4-py311hca03da5_0 --> 8.1.7-py311hca03da5_0
#   conda                              23.7.4-py311hca03da5_0 --> 24.1.1-py311hca03da5_0
#   conda-build                        3.26.1-py311hca03da5_0 --> 24.1.1-py311hca03da5_0
#   conda-index        pkgs/main/osx-arm64::conda-index-0.3.~ --> pkgs/main/noarch::conda-index-0.4.0-pyhd3eb1b0_0
#   conda-libmamba-so~ pkgs/main/osx-arm64::conda-libmamba-s~ --> pkgs/main/noarch::conda-libmamba-solver-24.1.0-pyhd3eb1b0_0
#   constantly                         15.1.0-py311hca03da5_0 --> 23.10.4-py311hca03da5_0
#   contourpy                           1.0.5-py311h48ca7d4_0 --> 1.2.0-py311h48ca7d4_0
#   cookiecutter       pkgs/main/noarch::cookiecutter-1.7.3-~ --> pkgs/main/osx-arm64::cookiecutter-2.5.0-py311hca03da5_0
#   cryptography                       41.0.3-py311hd4332d6_0 --> 41.0.7-py311hd4332d6_0
#   cssselect          pkgs/main/noarch::cssselect-1.1.0-pyh~ --> pkgs/main/osx-arm64::cssselect-1.2.0-py311hca03da5_0
#   curl                                     8.2.1-h02f6b3c_0 --> 8.5.0-h02f6b3c_0
#   cytoolz                            0.12.0-py311h80987f9_0 --> 0.12.2-py311h80987f9_0
#   dask                             2023.6.0-py311hca03da5_0 --> 2023.11.0-py311hca03da5_0
#   dask-core                        2023.6.0-py311hca03da5_0 --> 2023.11.0-py311hca03da5_0
#   datashader                         0.15.2-py311hca03da5_0 --> 0.16.0-py311hca03da5_0
#   distributed                      2023.6.0-py311hca03da5_0 --> 2023.11.0-py311hca03da5_0
#   filelock                            3.9.0-py311hca03da5_0 --> 3.13.1-py311hca03da5_0
#   flask                               2.2.2-py311hca03da5_0 --> 2.2.5-py311hca03da5_0
#   frozenlist                          1.3.3-py311h80987f9_0 --> 1.4.0-py311h80987f9_0
#   fsspec                           2023.4.0-py311hca03da5_0 --> 2023.10.0-py311hca03da5_0
#   gflags                                   2.2.2-hc377ac9_0 --> 2.2.2-h313beb8_1
#   glog                                     0.5.0-hc377ac9_0 --> 0.5.0-h313beb8_1
#   greenlet                            2.0.1-py311h313beb8_0 --> 3.0.1-py311h313beb8_0
#   grpc-cpp                                1.48.2-hc60591f_1 --> 1.48.2-hc60591f_4
#   holoviews                          1.17.1-py311hca03da5_0 --> 1.18.3-py311hca03da5_0
#   huggingface_hub                    0.15.1-py311hca03da5_0 --> 0.17.3-py311hca03da5_0
#   hvplot                              0.8.4-py311hca03da5_0 --> 0.9.2-py311hca03da5_0
#   icu                                       68.1-hc377ac9_0 --> 73.1-h313beb8_0
#   imageio                            2.31.1-py311hca03da5_0 --> 2.33.1-py311hca03da5_0
#   imbalanced-learn                   0.10.1-py311hca03da5_1 --> 0.11.0-py311hca03da5_1
#   importlib-metadata                  6.0.0-py311hca03da5_0 --> 7.0.1-py311hca03da5_0
#   importlib_metadata                       6.0.0-hd3eb1b0_0 --> 7.0.1-hd3eb1b0_0
#   ipykernel                          6.25.0-py311hb6e6a13_0 --> 6.28.0-py311hca03da5_0
#   ipython                            8.15.0-py311hca03da5_0 --> 8.20.0-py311hca03da5_0
#   jinja2                              3.1.2-py311hca03da5_0 --> 3.1.3-py311hca03da5_0
#   jmespath           pkgs/main/noarch::jmespath-0.10.0-pyh~ --> pkgs/main/osx-arm64::jmespath-1.0.1-py311hca03da5_0
#   jsonschema                         4.17.3-py311hca03da5_0 --> 4.19.2-py311hca03da5_0
#   jupyter_client                      7.4.9-py311hca03da5_0 --> 8.6.0-py311hca03da5_0
#   jupyter_core                        5.3.0-py311hca03da5_0 --> 5.5.0-py311hca03da5_0
#   jupyter_events                      0.6.3-py311hca03da5_0 --> 0.8.0-py311hca03da5_0
#   jupyter_server                     1.23.4-py311hca03da5_0 --> 2.10.0-py311hca03da5_0
#   jupyterlab                          3.6.3-py311hca03da5_0 --> 4.0.11-py311hca03da5_0
#   jupyterlab_server                  2.22.0-py311hca03da5_0 --> 2.25.1-py311hca03da5_0
#   jupyterlab_widgets                  3.0.5-py311hca03da5_0 --> 3.0.9-py311hca03da5_0
#   lazy_loader                           0.2-py311hca03da5_0 --> 0.3-py311hca03da5_0
#   libboost                               1.73.0-h49e8a49_12 --> 1.82.0-h0bc93f9_2
#   libcurl                                  8.2.1-h3e2b118_0 --> 8.5.0-h3e2b118_0
#   libdeflate                                1.17-h80987f9_0 --> 1.17-h80987f9_1
#   libedit                           3.1.20221030-h80987f9_0 --> 3.1.20230828-h80987f9_0
#   libmamba                                 1.5.1-h15e39b3_0 --> 1.5.6-h15e39b3_0
#   libmambapy                          1.5.1-py311h1c5506f_0 --> 1.5.6-py311h1c5506f_0
#   libnghttp2                              1.52.0-h62f6fdd_1 --> 1.57.0-h62f6fdd_0
#   libpq                                    12.15-h02f6b3c_1 --> 12.17-h02f6b3c_0
#   libxml2                                 2.10.4-h372ba2a_0 --> 2.10.4-h0dcf63f_1
#   libxslt                                 1.1.37-habca612_0 --> 1.1.37-h80987f9_1
#   llvmlite                           0.40.0-py311h514c7bf_0 --> 0.42.0-py311h313beb8_0
#   markupsafe                          2.1.1-py311h80987f9_0 --> 2.1.3-py311h80987f9_0
#   matplotlib                          3.7.2-py311hca03da5_0 --> 3.8.0-py311hca03da5_0
#   matplotlib-base                     3.7.2-py311h7aedaa7_0 --> 3.8.0-py311h7aedaa7_0
#   mistune                          0.8.4-py311h80987f9_1000 --> 2.0.4-py311hca03da5_0
#   more-itertools     pkgs/main/noarch::more-itertools-8.12~ --> pkgs/main/osx-arm64::more-itertools-10.1.0-py311hca03da5_0
#   multidict                           6.0.2-py311h80987f9_0 --> 6.0.4-py311h80987f9_0
#   nbclient                           0.5.13-py311hca03da5_0 --> 0.8.0-py311hca03da5_0
#   nbconvert                           6.5.4-py311hca03da5_0 --> 7.10.0-py311hca03da5_0
#   notebook                            6.5.4-py311hca03da5_1 --> 7.0.6-py311hca03da5_0
#   notebook-shim                       0.2.2-py311hca03da5_0 --> 0.2.3-py311hca03da5_0
#   numba                              0.57.1-py311h7aedaa7_0 --> 0.59.0-py311h7aedaa7_0
#   numexpr                             2.8.4-py311h6dc990b_1 --> 2.8.7-py311h6dc990b_0
#   numpy                              1.24.3-py311hb57d4eb_0 --> 1.26.3-py311he598dae_0
#   numpy-base                         1.24.3-py311h1d85a46_0 --> 1.26.3-py311hfbfe69c_0
#   pandas             anaconda::pandas-2.1.1-py311h7aedaa7_0 --> pkgs/main::pandas-2.1.4-py311h7aedaa7_0
#   panel                               1.2.3-py311hca03da5_0 --> 1.3.8-py311hca03da5_0
#   param                              1.13.0-py311hca03da5_0 --> 2.0.2-py311hca03da5_0
#   parsel                              1.6.0-py311hca03da5_0 --> 1.8.1-py311hca03da5_0
#   partd                               1.4.0-py311hca03da5_0 --> 1.4.1-py311hca03da5_0
#   pillow                             10.0.1-py311h3b245a6_0 --> 10.2.0-py311h80987f9_0
#   prompt-toolkit                     3.0.36-py311hca03da5_0 --> 3.0.43-py311hca03da5_0
#   prompt_toolkit                          3.0.36-hd3eb1b0_0 --> 3.0.43-hd3eb1b0_0
#   py-cpuinfo         pkgs/main/noarch::py-cpuinfo-8.0.0-py~ --> pkgs/main/osx-arm64::py-cpuinfo-9.0.0-py311hca03da5_0
#   pyarrow                            11.0.0-py311h7575258_1 --> 14.0.2-py311ha07b5f9_0
#   pycosat                             0.6.4-py311h80987f9_0 --> 0.6.6-py311h80987f9_0
#   pydantic                           1.10.8-py311h80987f9_0 --> 1.10.12-py311h80987f9_1
#   pyodbc                             4.0.34-py311h313beb8_0 --> 5.0.1-py311h313beb8_0
#   pyqt                               5.15.7-py311h313beb8_0 --> 5.15.10-py311h313beb8_0
#   pyqt5-sip                         12.11.0-py311h313beb8_0 --> 12.13.0-py311h80987f9_0
#   pyqtwebengine                      5.15.7-py311h313beb8_0 --> 5.15.10-py311h313beb8_0
#   pytables                            3.8.0-py311he080bb3_3 --> 3.9.2-py311h0326f10_0
#   pytoolconfig                        1.2.5-py311hca03da5_1 --> 1.2.6-py311hca03da5_0
#   pyviz_comms                         2.3.0-py311hca03da5_0 --> 3.0.0-py311hca03da5_0
#   pywavelets                          1.4.1-py311h80987f9_0 --> 1.5.0-py311hb9f6ed7_0
#   pyyaml                                6.0-py311h80987f9_1 --> 6.0.1-py311h80987f9_0
#   pyzmq                              23.2.0-py311h313beb8_0 --> 25.1.2-py311h313beb8_0
#   qt-main                                 5.15.2-h9b4df51_9 --> 5.15.2-h0917680_10
#   qtpy                                2.2.0-py311hca03da5_0 --> 2.4.1-py311hca03da5_0
#   queuelib                            1.5.0-py311hca03da5_0 --> 1.6.2-py311hca03da5_0
#   regex                            2022.7.9-py311h80987f9_0 --> 2023.10.3-py311h80987f9_0
#   s3fs                             2023.4.0-py311hca03da5_0 --> 2023.10.0-py311hca03da5_0
#   safetensors                         0.3.2-py311hf0e4da2_0 --> 0.4.0-py311h62f922a_0
#   scikit-image                       0.20.0-py311h313beb8_0 --> 0.22.0-py311h7aedaa7_0
#   scipy                              1.11.1-py311hc76d9b0_0 --> 1.11.4-py311hc76d9b0_0
#   send2trash         pkgs/main/noarch::send2trash-1.8.0-py~ --> pkgs/main/osx-arm64::send2trash-1.8.2-py311hca03da5_0
#   sip                                 6.6.2-py311h313beb8_0 --> 6.7.12-py311h313beb8_0
#   snappy                                   1.1.9-hc377ac9_0 --> 1.1.10-h313beb8_1
#   sniffio                             1.2.0-py311hca03da5_1 --> 1.3.0-py311hca03da5_0
#   soupsieve                             2.4-py311hca03da5_0 --> 2.5-py311hca03da5_0
#   sqlalchemy                         1.4.39-py311h80987f9_0 --> 2.0.25-py311h80987f9_0
#   sympy                              1.11.1-py311hca03da5_0 --> 1.12-py311hca03da5_0
#   tabulate                           0.8.10-py311hca03da5_0 --> 0.9.0-py311hca03da5_0
#   tornado                             6.3.2-py311h80987f9_0 --> 6.3.3-py311h80987f9_0
#   typing-extensions                   4.7.1-py311hca03da5_0 --> 4.9.0-py311hca03da5_1
#   typing_extensions                   4.7.1-py311hca03da5_0 --> 4.9.0-py311hca03da5_1
#   tzdata                                   2023c-h04d1e81_0 --> 2023d-h04d1e81_0
#   urllib3                           1.26.16-py311hca03da5_0 --> 1.26.18-py311hca03da5_0
#   utf8proc                                 2.6.1-h1a28f6b_0 --> 2.6.1-h80987f9_1
#   xz                                       5.4.2-h80987f9_0 --> 5.4.5-h80987f9_0
#   yaml-cpp                                 0.7.0-hc377ac9_1 --> 0.8.0-h313beb8_0
#   yarl                                1.8.1-py311h80987f9_0 --> 1.9.3-py311h80987f9_0
#   zeromq                                   4.3.4-hc377ac9_0 --> 4.3.5-h313beb8_0
#   zict                                2.2.0-py311hca03da5_0 --> 3.0.0-py311hca03da5_0
#   zipp                               3.11.0-py311hca03da5_0 --> 3.17.0-py311hca03da5_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2024.2.2~ --> pkgs/main::ca-certificates-2023.12.12-hca03da5_0
#   certifi            conda-forge/noarch::certifi-2024.2.2-~ --> pkgs/main/osx-arm64::certifi-2024.2.2-py311hca03da5_0
#   openssl             conda-forge::openssl-3.2.1-h0d3ecfb_0 --> pkgs/main::openssl-3.0.13-h1a28f6b_0
#   redis-py           conda-forge/noarch::redis-py-5.0.1-py~ --> pkgs/main/osx-arm64::redis-py-4.3.4-py311hca03da5_0
#
# The following packages will be DOWNGRADED:
#
#   scikit-learn                        1.3.0-py311h7aedaa7_0 --> 1.2.2-py311h313beb8_1
#
#
#
# Downloading and Extracting Packages
# utf8proc-2.6.1       | 97 KB     |                                       |   0%
# archspec-0.2.1       | 39 KB     |                                       |   0%
#
# multidict-6.0.4      | 54 KB     |                                       |   0%
#
#
# qtpy-2.4.1           | 132 KB    |                                       |   0%
#
#
#
# jupyter_server-2.10. | 587 KB    |                                       |   0%
#
#
#
#
# hvplot-0.9.2         | 1.9 MB    |                                       |   0%
#
#
#
#
#
# llvmlite-0.42.0      | 398 KB    |                                       |   0%
#
#
#
#
#
#
# gtest-1.14.0         | 390 KB    |                                       |   0%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# contourpy-1.2.0      | 255 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.48.2      | 3.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# pyarrow-14.0.2       | 4.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# pyzmq-25.1.2         | 520 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# distributed-2023.11. | 1.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-http-0.6.25    | 164 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pycosat-0.6.6        | 88 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2024.2.2     | 161 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typing-extensions-4. | 10 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# imageio-2.33.1       | 616 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cytoolz-0.12.2       | 368 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# click-8.1.7          | 217 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mistune-2.0.4        | 108 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# snappy-1.1.10        | 37 KB     |                                       |   0%
#  ... (more hidden) ...
# archspec-0.2.1       | 39 KB     | ###############2                      |  41%
#
#
# utf8proc-2.6.1       | 97 KB     | ######1                               |  17%
#
#
#
# jupyter_server-2.10. | 587 KB    | #                                     |   3%
#
# multidict-6.0.4      | 54 KB     | ###########                           |  30%
# archspec-0.2.1       | 39 KB     | ##################################### | 100%
# archspec-0.2.1       | 39 KB     | ##################################### | 100%
#
#
# utf8proc-2.6.1       | 97 KB     | ##################3                   |  50%
#
#
#
# jupyter_server-2.10. | 587 KB    | ###                                   |   8%
#
# multidict-6.0.4      | 54 KB     | #################################     |  89%
#
# multidict-6.0.4      | 54 KB     | ##################################### | 100%
#
#
# utf8proc-2.6.1       | 97 KB     | ##############################6       |  83%
#
#
#
# jupyter_server-2.10. | 587 KB    | #####                                 |  14%
#
#
# qtpy-2.4.1           | 132 KB    | ###############################3      |  85%
#
#
#
#
# hvplot-0.9.2         | 1.9 MB    | 3                                     |   1%
#
#
#
#
#
# utf8proc-2.6.1       | 97 KB     | ##################################### | 100%
#
#
#
# jupyter_server-2.10. | 587 KB    | ###########1                          |  30%
#
#
# qtpy-2.4.1           | 132 KB    | ##################################### | 100%
#
#
#
#
#
# llvmlite-0.42.0      | 398 KB    | #######4                              |  20%
#
#
#
#
# hvplot-0.9.2         | 1.9 MB    | #2                                    |   3%
#
#
#
#
#
#
# gtest-1.14.0         | 390 KB    | #5                                    |   4%
#
#
#
# jupyter_server-2.10. | 587 KB    | ##############1                       |  38%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    |                                       |   0%
#
#
#
#
#
# llvmlite-0.42.0      | 398 KB    | ##########4                           |  28%
#
#
#
#
# hvplot-0.9.2         | 1.9 MB    | #8                                    |   5%
#
#
#
#
#
# llvmlite-0.42.0      | 398 KB    | ###################3                  |  52%
#
#
#
# jupyter_server-2.10. | 587 KB    | #########################2            |  68%
#
#
#
#
#
#
# gtest-1.14.0         | 390 KB    | ##########6                           |  29%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | 4                                     |   1%
#
#
#
#
# hvplot-0.9.2         | 1.9 MB    | ###                                   |   8%
#
#
#
#
#
# llvmlite-0.42.0      | 398 KB    | #############################7        |  80%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | 8                                     |   2%
#
#
#
#
# hvplot-0.9.2         | 1.9 MB    | ####3                                 |  12%
#
#
#
#
#
#
# gtest-1.14.0         | 390 KB    | ######################7               |  61%
#
#
#
#
#
# llvmlite-0.42.0      | 398 KB    | ##################################### | 100%
#
#
#
# jupyter_server-2.10. | 587 KB    | ##################################### | 100%
#
#
#
# jupyter_server-2.10. | 587 KB    | ##################################### | 100%
#
#
#
#
# hvplot-0.9.2         | 1.9 MB    | ######1                               |  17%
#
#
#
#
#
#
#
#
# contourpy-1.2.0      | 255 KB    | ##3                                   |   6%
#
#
#
#
#
#
# gtest-1.14.0         | 390 KB    | ##################################### | 100%
#
#
#
#
#
#
# gtest-1.14.0         | 390 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #1                                    |   3%
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.48.2      | 3.0 MB    | 1                                     |   1%
#
#
#
#
#
#
#
#
# contourpy-1.2.0      | 255 KB    | ##################################### | 100%
#
#
#
#
# hvplot-0.9.2         | 1.9 MB    | #########5                            |  26%
#
#
#
#
#
#
#
#
#
#
# pyarrow-14.0.2       | 4.2 MB    | 1                                     |   0%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #5                                    |   4%
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.48.2      | 3.0 MB    | ###                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
# pyzmq-25.1.2         | 520 KB    | #1                                    |   3%
#
#
#
#
# hvplot-0.9.2         | 1.9 MB    | #############8                        |  37%
#
#
#
#
#
#
#
#
#
#
# pyarrow-14.0.2       | 4.2 MB    | ##8                                   |   8%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #8                                    |   5%
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.48.2      | 3.0 MB    | #######1                              |  19%
#
#
#
#
#
#
#
#
#
#
#
# pyzmq-25.1.2         | 520 KB    | ###########################3          |  74%
#
#
#
#
# hvplot-0.9.2         | 1.9 MB    | ######################4               |  61%
#
#
#
#
#
#
#
#
#
#
# pyarrow-14.0.2       | 4.2 MB    | #####3                                |  14%
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.48.2      | 3.0 MB    | ############4                         |  34%
#
#
#
#
# hvplot-0.9.2         | 1.9 MB    | ###########################           |  73%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ##2                                   |   6%
#
#
#
#
#
#
#
#
#
#
# pyarrow-14.0.2       | 4.2 MB    | #######3                              |  20%
#
#
#
#
#
#
#
#
#
#
#
# pyzmq-25.1.2         | 520 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.48.2      | 3.0 MB    | ###############9                      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
# distributed-2023.11. | 1.7 MB    | 3                                     |   1%
#
#
#
#
# hvplot-0.9.2         | 1.9 MB    | ###############################       |  84%
#
#
#
#
#
#
#
#
#
#
# pyarrow-14.0.2       | 4.2 MB    | #########                             |  24%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ##5                                   |   7%
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.48.2      | 3.0 MB    | ######################8               |  62%
#
#
#
#
#
#
#
#
#
#
# pyarrow-14.0.2       | 4.2 MB    | ###########7                          |  32%
#
#
#
#
# hvplot-0.9.2         | 1.9 MB    | ##################################1   |  92%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ##9                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
# distributed-2023.11. | 1.7 MB    | ############2                         |  33%
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.48.2      | 3.0 MB    | #############################9        |  81%
#
#
#
#
#
#
#
#
#
#
# pyarrow-14.0.2       | 4.2 MB    | ################9                     |  46%
#
#
#
#
# hvplot-0.9.2         | 1.9 MB    | ##################################### | 100%
#
#
#
#
# hvplot-0.9.2         | 1.9 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# distributed-2023.11. | 1.7 MB    | ##################4                   |  50%
# astropy-5.3.4        | 9.8 MB    | ###5                                  |  10%
#
#
#
#
#
#
#
#
#
#
# pyarrow-14.0.2       | 4.2 MB    | ####################1                 |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-http-0.6.25    | 164 KB    | ###6                                  |  10%
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.48.2      | 3.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.48.2      | 3.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# distributed-2023.11. | 1.7 MB    | ##############################        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-http-0.6.25    | 164 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ###8                                  |  11%
#
#
#
#
#
#
#
#
#
#
# pyarrow-14.0.2       | 4.2 MB    | #######################               |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pycosat-0.6.6        | 88 KB     | ######7                               |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pycosat-0.6.6        | 88 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# distributed-2023.11. | 1.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2024.2.2     | 161 KB    | ###6                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2024.2.2     | 161 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ####3                                 |  12%
#
#
#
#
#
#
#
#
#
#
# pyarrow-14.0.2       | 4.2 MB    | #########################7            |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typing-extensions-4. | 10 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# imageio-2.33.1       | 616 KB    | 9                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cytoolz-0.12.2       | 368 KB    | #6                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typing-extensions-4. | 10 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# pyarrow-14.0.2       | 4.2 MB    | ################################6     |  88%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #####3                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cytoolz-0.12.2       | 368 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cytoolz-0.12.2       | 368 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# imageio-2.33.1       | 616 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# imageio-2.33.1       | 616 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# click-8.1.7          | 217 KB    | ##7                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# click-8.1.7          | 217 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# pyarrow-14.0.2       | 4.2 MB    | ####################################1 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mistune-2.0.4        | 108 KB    | #####4                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# snappy-1.1.10        | 37 KB     | ################1                     |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# snappy-1.1.10        | 37 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #####8                                |  16%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mistune-2.0.4        | 108 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ######3                               |  17%
#
#
#
#
#
#
#
#
#
#
# pyarrow-14.0.2       | 4.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ######7                               |  18%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #######7                              |  21%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ########3                             |  22%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ########7                             |  24%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #########5                            |  26%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #########9                            |  27%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ##########2                           |  28%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ##########4                           |  28%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ##########9                           |  30%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ###########2                          |  30%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ###########5                          |  31%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ###########8                          |  32%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ############1                         |  33%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ############4                         |  34%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ############6                         |  34%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ############9                         |  35%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #############                         |  35%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #############3                        |  36%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #############6                        |  37%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #############8                        |  37%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ##############                        |  38%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ##############4                       |  39%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ##############7                       |  40%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ##############9                       |  40%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ###############2                      |  41%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ###############5                      |  42%
# astropy-5.3.4        | 9.8 MB    | ###############8                      |  43%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ################1                     |  44%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ################4                     |  44%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ################7                     |  45%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #################                     |  46%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #################3                    |  47%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #################6                    |  48%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #################9                    |  48%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ##################2                   |  49%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ##################5                   |  50%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ##################8                   |  51%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ###################1                  |  52%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ###################4                  |  53%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ###################7                  |  53%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ####################                  |  54%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ####################3                 |  55%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ####################6                 |  56%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ####################8                 |  56%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #####################                 |  57%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #####################4                |  58%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #####################6                |  59%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #####################8                |  59%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ######################2               |  60%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ######################4               |  61%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ######################7               |  61%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #######################2              |  63%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #######################5              |  64%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #######################8              |  65%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ########################1             |  65%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ########################5             |  66%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ########################8             |  67%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #########################             |  68%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #########################7            |  70%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #########################9            |  70%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ##########################8           |  73%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ###########################2          |  74%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ###########################6          |  75%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ############################4         |  77%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ############################9         |  78%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #############################4        |  80%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ##############################1       |  82%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ##############################7       |  83%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ###############################6      |  85%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ################################2     |  87%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ################################7     |  88%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #################################2    |  90%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | #################################7    |  91%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ##################################3   |  93%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ###################################5  |  96%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ####################################1 |  98%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ####################################8 |  99%
#
#
#
#
#
#
#
# astropy-5.3.4        | 9.8 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Loading credentials from the config file

# %%
import config

# %% [markdown]
# ## Starting with Spotify API

# %%
import spotipy
import pandas as pd
import json
from spotipy.oauth2 import SpotifyClientCredentials


#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))



results = sp.search(q="daddy cool",limit=5,market="GB")
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=daddy+cool&type=track&market=GB&offset=0&limit=5',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#        'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#        'id': '54R6Y0I7jGUCveDTtI21nb',
#        'name': 'Boney M.',
#        'type': 'artist',
#        'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1KQUrny9y5zGpktF6hAGd4'},
#      'href': 'https://api.spotify.com/v1/albums/1KQUrny9y5zGpktF6hAGd4',
#      'id': '1KQUrny9y5zGpktF6hAGd4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273dafd1cd6e9537ec8463ea691',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02dafd1cd6e9537ec8463ea691',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851dafd1cd6e9537ec8463ea691',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Take The Heat Off Me',
#      'release_date': '1976',
#      'release_date_precision': 'year',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:1KQUrny9y5zGpktF6hAGd4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#       'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#       'id': '54R6Y0I7jGUCveDTtI21nb',
#       'name': 'Boney M.',
#       'type': 'artist',
#       'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#     'disc_number': 1,
#     'duration_ms': 208600,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEC737600002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3WMbD1OyfKuwWDWMNbPQ4g'},
#     'href': 'https://api.spotify.com/v1/tracks/3WMbD1OyfKuwWDWMNbPQ4g',
#     'id': '3WMbD1OyfKuwWDWMNbPQ4g',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Daddy Cool',
#     'popularity': 77,
#     'preview_url': 'https://p.scdn.co/mp3-preview/03e2b60a6a5c101dc0d41866f2e079d8de4a663b?cid=61f7d969ccdb47a98d5072e59a293026',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3WMbD1OyfKuwWDWMNbPQ4g'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#        'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#        'id': '54R6Y0I7jGUCveDTtI21nb',
#        'name': 'Boney M.',
#        'type': 'artist',
#        'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/155cebHEGGBqYJAXKWJw6D'},
#      'href': 'https://api.spotify.com/v1/albums/155cebHEGGBqYJAXKWJw6D',
#      'id': '155cebHEGGBqYJAXKWJw6D',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d792d961638fd28f8d281947',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d792d961638fd28f8d281947',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d792d961638fd28f8d281947',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Daddy Cool',
#      'release_date': '1994-03-14',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:155cebHEGGBqYJAXKWJw6D'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#       'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#       'id': '54R6Y0I7jGUCveDTtI21nb',
#       'name': 'Boney M.',
#       'type': 'artist',
#       'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#     'disc_number': 1,
#     'duration_ms': 220666,
#     'explicit': False,
#     'external_ids': {'isrc': 'DED160000010'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5lWSa1rmuSL6OBPOnkAqoa'},
#     'href': 'https://api.spotify.com/v1/tracks/5lWSa1rmuSL6OBPOnkAqoa',
#     'id': '5lWSa1rmuSL6OBPOnkAqoa',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Rasputin',
#     'popularity': 72,
#     'preview_url': 'https://p.scdn.co/mp3-preview/99129129d46b1937b0897e38d561110e1cd319f4?cid=61f7d969ccdb47a98d5072e59a293026',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5lWSa1rmuSL6OBPOnkAqoa'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12A83CWwFiyXy90ScLWPIe'},
#        'href': 'https://api.spotify.com/v1/artists/12A83CWwFiyXy90ScLWPIe',
#        'id': '12A83CWwFiyXy90ScLWPIe',
#        'name': 'LIZOT',
#        'type': 'artist',
#        'uri': 'spotify:artist:12A83CWwFiyXy90ScLWPIe'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#        'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#        'id': '54R6Y0I7jGUCveDTtI21nb',
#        'name': 'Boney M.',
#        'type': 'artist',
#        'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7fXtm0TpLRIJhxobKDjxRp'},
#      'href': 'https://api.spotify.com/v1/albums/7fXtm0TpLRIJhxobKDjxRp',
#      'id': '7fXtm0TpLRIJhxobKDjxRp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273da8ce498bc7d441e6d841d25',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02da8ce498bc7d441e6d841d25',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851da8ce498bc7d441e6d841d25',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Daddy Cool',
#      'release_date': '2021-12-03',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7fXtm0TpLRIJhxobKDjxRp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12A83CWwFiyXy90ScLWPIe'},
#       'href': 'https://api.spotify.com/v1/artists/12A83CWwFiyXy90ScLWPIe',
#       'id': '12A83CWwFiyXy90ScLWPIe',
#       'name': 'LIZOT',
#       'type': 'artist',
#       'uri': 'spotify:artist:12A83CWwFiyXy90ScLWPIe'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#       'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#       'id': '54R6Y0I7jGUCveDTtI21nb',
#       'name': 'Boney M.',
#       'type': 'artist',
#       'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#     'disc_number': 1,
#     'duration_ms': 154858,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEE862102870'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/50rcUhHimavzT1qq6QrgMG'},
#     'href': 'https://api.spotify.com/v1/tracks/50rcUhHimavzT1qq6QrgMG',
#     'id': '50rcUhHimavzT1qq6QrgMG',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Daddy Cool',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/857d68f8f69125e431cea3e5e89e653440600762?cid=61f7d969ccdb47a98d5072e59a293026',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:50rcUhHimavzT1qq6QrgMG'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dn4KQgTE4P3jrwa3iIVzQ'},
#        'href': 'https://api.spotify.com/v1/artists/4dn4KQgTE4P3jrwa3iIVzQ',
#        'id': '4dn4KQgTE4P3jrwa3iIVzQ',
#        'name': 'Baccara',
#        'type': 'artist',
#        'uri': 'spotify:artist:4dn4KQgTE4P3jrwa3iIVzQ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5e6VPOPLw5cSXsVMvQEioq'},
#      'href': 'https://api.spotify.com/v1/albums/5e6VPOPLw5cSXsVMvQEioq',
#      'id': '5e6VPOPLw5cSXsVMvQEioq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f9742033ffb15f5413898ef9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f9742033ffb15f5413898ef9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f9742033ffb15f5413898ef9',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'The Collection & Tracklisting',
#      'release_date': '1998',
#      'release_date_precision': 'year',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:5e6VPOPLw5cSXsVMvQEioq'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dn4KQgTE4P3jrwa3iIVzQ'},
#       'href': 'https://api.spotify.com/v1/artists/4dn4KQgTE4P3jrwa3iIVzQ',
#       'id': '4dn4KQgTE4P3jrwa3iIVzQ',
#       'name': 'Baccara',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dn4KQgTE4P3jrwa3iIVzQ'}],
#     'disc_number': 1,
#     'duration_ms': 273866,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEC760000065'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2LScqpywMqGcnum6nNaxXX'},
#     'href': 'https://api.spotify.com/v1/tracks/2LScqpywMqGcnum6nNaxXX',
#     'id': '2LScqpywMqGcnum6nNaxXX',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Yes Sir, I Can Boogie',
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/704fbc9b86f59da239d2de11d6d5baf808596856?cid=61f7d969ccdb47a98d5072e59a293026',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:2LScqpywMqGcnum6nNaxXX'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#        'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#        'id': '6RZUqkomCmb8zCRqc9eznB',
#        'name': 'Placebo',
#        'type': 'artist',
#        'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7kTsa1wUFrahJJf1cJEOpZ'},
#      'href': 'https://api.spotify.com/v1/albums/7kTsa1wUFrahJJf1cJEOpZ',
#      'id': '7kTsa1wUFrahJJf1cJEOpZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27362c995dbce6d7ffa4c097475',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0262c995dbce6d7ffa4c097475',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485162c995dbce6d7ffa4c097475',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Covers',
#      'release_date': '2003-03-24',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:7kTsa1wUFrahJJf1cJEOpZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#       'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#       'id': '6RZUqkomCmb8zCRqc9eznB',
#       'name': 'Placebo',
#       'type': 'artist',
#       'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#     'disc_number': 1,
#     'duration_ms': 201706,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAAA0201215'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6blKbRwYDoXl5fFvQY2U75'},
#     'href': 'https://api.spotify.com/v1/tracks/6blKbRwYDoXl5fFvQY2U75',
#     'id': '6blKbRwYDoXl5fFvQY2U75',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Daddy Cool',
#     'popularity': 47,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4af3ad78f847b23200036e9cee4d5b06868aea6b?cid=61f7d969ccdb47a98d5072e59a293026',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:6blKbRwYDoXl5fFvQY2U75'}],
#   'limit': 5,
#   'next': 'https://api.spotify.com/v1/search?query=daddy+cool&type=track&market=GB&offset=5&limit=5',
#   'offset': 0,
#   'previous': None,
#   'total': 825}}

# %%
import pprint

# %%
pprint.pprint(results)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=daddy+cool&type=track&market=GB&offset=0&limit=5',
#             'items': [{'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#                                               'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#                                               'id': '54R6Y0I7jGUCveDTtI21nb',
#                                               'name': 'Boney M.',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/1KQUrny9y5zGpktF6hAGd4'},
#                                  'href': 'https://api.spotify.com/v1/albums/1KQUrny9y5zGpktF6hAGd4',
#                                  'id': '1KQUrny9y5zGpktF6hAGd4',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273dafd1cd6e9537ec8463ea691',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02dafd1cd6e9537ec8463ea691',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851dafd1cd6e9537ec8463ea691',
#                                              'width': 64}],
#                                  'is_playable': True,
#                                  'name': 'Take The Heat Off Me',
#                                  'release_date': '1976',
#                                  'release_date_precision': 'year',
#                                  'total_tracks': 10,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:1KQUrny9y5zGpktF6hAGd4'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#                                     'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#                                     'id': '54R6Y0I7jGUCveDTtI21nb',
#                                     'name': 'Boney M.',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#                        'disc_number': 1,
#                        'duration_ms': 208600,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'DEC737600002'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/3WMbD1OyfKuwWDWMNbPQ4g'},
#                        'href': 'https://api.spotify.com/v1/tracks/3WMbD1OyfKuwWDWMNbPQ4g',
#                        'id': '3WMbD1OyfKuwWDWMNbPQ4g',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Daddy Cool',
#                        'popularity': 77,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/03e2b60a6a5c101dc0d41866f2e079d8de4a663b?cid=61f7d969ccdb47a98d5072e59a293026',
#                        'track_number': 1,
#                        'type': 'track',
#                        'uri': 'spotify:track:3WMbD1OyfKuwWDWMNbPQ4g'},
#                       {'album': {'album_type': 'compilation',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#                                               'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#                                               'id': '54R6Y0I7jGUCveDTtI21nb',
#                                               'name': 'Boney M.',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/155cebHEGGBqYJAXKWJw6D'},
#                                  'href': 'https://api.spotify.com/v1/albums/155cebHEGGBqYJAXKWJw6D',
#                                  'id': '155cebHEGGBqYJAXKWJw6D',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273d792d961638fd28f8d281947',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02d792d961638fd28f8d281947',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851d792d961638fd28f8d281947',
#                                              'width': 64}],
#                                  'is_playable': True,
#                                  'name': 'Daddy Cool',
#                                  'release_date': '1994-03-14',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 16,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:155cebHEGGBqYJAXKWJw6D'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#                                     'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#                                     'id': '54R6Y0I7jGUCveDTtI21nb',
#                                     'name': 'Boney M.',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#                        'disc_number': 1,
#                        'duration_ms': 220666,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'DED160000010'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/5lWSa1rmuSL6OBPOnkAqoa'},
#                        'href': 'https://api.spotify.com/v1/tracks/5lWSa1rmuSL6OBPOnkAqoa',
#                        'id': '5lWSa1rmuSL6OBPOnkAqoa',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Rasputin',
#                        'popularity': 72,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/99129129d46b1937b0897e38d561110e1cd319f4?cid=61f7d969ccdb47a98d5072e59a293026',
#                        'track_number': 3,
#                        'type': 'track',
#                        'uri': 'spotify:track:5lWSa1rmuSL6OBPOnkAqoa'},
#                       {'album': {'album_type': 'single',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12A83CWwFiyXy90ScLWPIe'},
#                                               'href': 'https://api.spotify.com/v1/artists/12A83CWwFiyXy90ScLWPIe',
#                                               'id': '12A83CWwFiyXy90ScLWPIe',
#                                               'name': 'LIZOT',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:12A83CWwFiyXy90ScLWPIe'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#                                               'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#                                               'id': '54R6Y0I7jGUCveDTtI21nb',
#                                               'name': 'Boney M.',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/7fXtm0TpLRIJhxobKDjxRp'},
#                                  'href': 'https://api.spotify.com/v1/albums/7fXtm0TpLRIJhxobKDjxRp',
#                                  'id': '7fXtm0TpLRIJhxobKDjxRp',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273da8ce498bc7d441e6d841d25',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02da8ce498bc7d441e6d841d25',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851da8ce498bc7d441e6d841d25',
#                                              'width': 64}],
#                                  'is_playable': True,
#                                  'name': 'Daddy Cool',
#                                  'release_date': '2021-12-03',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 1,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:7fXtm0TpLRIJhxobKDjxRp'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12A83CWwFiyXy90ScLWPIe'},
#                                     'href': 'https://api.spotify.com/v1/artists/12A83CWwFiyXy90ScLWPIe',
#                                     'id': '12A83CWwFiyXy90ScLWPIe',
#                                     'name': 'LIZOT',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:12A83CWwFiyXy90ScLWPIe'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#                                     'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#                                     'id': '54R6Y0I7jGUCveDTtI21nb',
#                                     'name': 'Boney M.',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#                        'disc_number': 1,
#                        'duration_ms': 154858,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'DEE862102870'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/50rcUhHimavzT1qq6QrgMG'},
#                        'href': 'https://api.spotify.com/v1/tracks/50rcUhHimavzT1qq6QrgMG',
#                        'id': '50rcUhHimavzT1qq6QrgMG',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Daddy Cool',
#                        'popularity': 59,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/857d68f8f69125e431cea3e5e89e653440600762?cid=61f7d969ccdb47a98d5072e59a293026',
#                        'track_number': 1,
#                        'type': 'track',
#                        'uri': 'spotify:track:50rcUhHimavzT1qq6QrgMG'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dn4KQgTE4P3jrwa3iIVzQ'},
#                                               'href': 'https://api.spotify.com/v1/artists/4dn4KQgTE4P3jrwa3iIVzQ',
#                                               'id': '4dn4KQgTE4P3jrwa3iIVzQ',
#                                               'name': 'Baccara',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:4dn4KQgTE4P3jrwa3iIVzQ'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/5e6VPOPLw5cSXsVMvQEioq'},
#                                  'href': 'https://api.spotify.com/v1/albums/5e6VPOPLw5cSXsVMvQEioq',
#                                  'id': '5e6VPOPLw5cSXsVMvQEioq',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273f9742033ffb15f5413898ef9',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02f9742033ffb15f5413898ef9',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851f9742033ffb15f5413898ef9',
#                                              'width': 64}],
#                                  'is_playable': True,
#                                  'name': 'The Collection & Tracklisting',
#                                  'release_date': '1998',
#                                  'release_date_precision': 'year',
#                                  'total_tracks': 19,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:5e6VPOPLw5cSXsVMvQEioq'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dn4KQgTE4P3jrwa3iIVzQ'},
#                                     'href': 'https://api.spotify.com/v1/artists/4dn4KQgTE4P3jrwa3iIVzQ',
#                                     'id': '4dn4KQgTE4P3jrwa3iIVzQ',
#                                     'name': 'Baccara',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:4dn4KQgTE4P3jrwa3iIVzQ'}],
#                        'disc_number': 1,
#                        'duration_ms': 273866,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'DEC760000065'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/2LScqpywMqGcnum6nNaxXX'},
#                        'href': 'https://api.spotify.com/v1/tracks/2LScqpywMqGcnum6nNaxXX',
#                        'id': '2LScqpywMqGcnum6nNaxXX',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Yes Sir, I Can Boogie',
#                        'popularity': 65,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/704fbc9b86f59da239d2de11d6d5baf808596856?cid=61f7d969ccdb47a98d5072e59a293026',
#                        'track_number': 6,
#                        'type': 'track',
#                        'uri': 'spotify:track:2LScqpywMqGcnum6nNaxXX'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#                                               'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#                                               'id': '6RZUqkomCmb8zCRqc9eznB',
#                                               'name': 'Placebo',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/7kTsa1wUFrahJJf1cJEOpZ'},
#                                  'href': 'https://api.spotify.com/v1/albums/7kTsa1wUFrahJJf1cJEOpZ',
#                                  'id': '7kTsa1wUFrahJJf1cJEOpZ',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b27362c995dbce6d7ffa4c097475',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e0262c995dbce6d7ffa4c097475',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000485162c995dbce6d7ffa4c097475',
#                                              'width': 64}],
#                                  'is_playable': True,
#                                  'name': 'Covers',
#                                  'release_date': '2003-03-24',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 10,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:7kTsa1wUFrahJJf1cJEOpZ'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#                                     'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#                                     'id': '6RZUqkomCmb8zCRqc9eznB',
#                                     'name': 'Placebo',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#                        'disc_number': 1,
#                        'duration_ms': 201706,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'GBAAA0201215'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/6blKbRwYDoXl5fFvQY2U75'},
#                        'href': 'https://api.spotify.com/v1/tracks/6blKbRwYDoXl5fFvQY2U75',
#                        'id': '6blKbRwYDoXl5fFvQY2U75',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Daddy Cool',
#                        'popularity': 47,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/4af3ad78f847b23200036e9cee4d5b06868aea6b?cid=61f7d969ccdb47a98d5072e59a293026',
#                        'track_number': 9,
#                        'type': 'track',
#                        'uri': 'spotify:track:6blKbRwYDoXl5fFvQY2U75'}],
#             'limit': 5,
#             'next': 'https://api.spotify.com/v1/search?query=daddy+cool&type=track&market=GB&offset=5&limit=5',
#             'offset': 0,
#             'previous': None,
#             'total': 825}}

# %%
results["tracks"]["items"][0]
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#      'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#      'id': '54R6Y0I7jGUCveDTtI21nb',
#      'name': 'Boney M.',
#      'type': 'artist',
#      'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1KQUrny9y5zGpktF6hAGd4'},
#    'href': 'https://api.spotify.com/v1/albums/1KQUrny9y5zGpktF6hAGd4',
#    'id': '1KQUrny9y5zGpktF6hAGd4',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273dafd1cd6e9537ec8463ea691',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02dafd1cd6e9537ec8463ea691',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851dafd1cd6e9537ec8463ea691',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Take The Heat Off Me',
#    'release_date': '1976',
#    'release_date_precision': 'year',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:1KQUrny9y5zGpktF6hAGd4'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#     'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#     'id': '54R6Y0I7jGUCveDTtI21nb',
#     'name': 'Boney M.',
#     'type': 'artist',
#     'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#   'disc_number': 1,
#   'duration_ms': 208600,
#   'explicit': False,
#   'external_ids': {'isrc': 'DEC737600002'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3WMbD1OyfKuwWDWMNbPQ4g'},
#   'href': 'https://api.spotify.com/v1/tracks/3WMbD1OyfKuwWDWMNbPQ4g',
#   'id': '3WMbD1OyfKuwWDWMNbPQ4g',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Daddy Cool',
#   'popularity': 77,
#   'preview_url': 'https://p.scdn.co/mp3-preview/03e2b60a6a5c101dc0d41866f2e079d8de4a663b?cid=61f7d969ccdb47a98d5072e59a293026',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:3WMbD1OyfKuwWDWMNbPQ4g'},
#  {'album': {'album_type': 'compilation',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#      'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#      'id': '54R6Y0I7jGUCveDTtI21nb',
#      'name': 'Boney M.',
#      'type': 'artist',
#      'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/155cebHEGGBqYJAXKWJw6D'},
#    'href': 'https://api.spotify.com/v1/albums/155cebHEGGBqYJAXKWJw6D',
#    'id': '155cebHEGGBqYJAXKWJw6D',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273d792d961638fd28f8d281947',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02d792d961638fd28f8d281947',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851d792d961638fd28f8d281947',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Daddy Cool',
#    'release_date': '1994-03-14',
#    'release_date_precision': 'day',
#    'total_tracks': 16,
#    'type': 'album',
#    'uri': 'spotify:album:155cebHEGGBqYJAXKWJw6D'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#     'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#     'id': '54R6Y0I7jGUCveDTtI21nb',
#     'name': 'Boney M.',
#     'type': 'artist',
#     'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#   'disc_number': 1,
#   'duration_ms': 220666,
#   'explicit': False,
#   'external_ids': {'isrc': 'DED160000010'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5lWSa1rmuSL6OBPOnkAqoa'},
#   'href': 'https://api.spotify.com/v1/tracks/5lWSa1rmuSL6OBPOnkAqoa',
#   'id': '5lWSa1rmuSL6OBPOnkAqoa',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Rasputin',
#   'popularity': 72,
#   'preview_url': 'https://p.scdn.co/mp3-preview/99129129d46b1937b0897e38d561110e1cd319f4?cid=61f7d969ccdb47a98d5072e59a293026',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:5lWSa1rmuSL6OBPOnkAqoa'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12A83CWwFiyXy90ScLWPIe'},
#      'href': 'https://api.spotify.com/v1/artists/12A83CWwFiyXy90ScLWPIe',
#      'id': '12A83CWwFiyXy90ScLWPIe',
#      'name': 'LIZOT',
#      'type': 'artist',
#      'uri': 'spotify:artist:12A83CWwFiyXy90ScLWPIe'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#      'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#      'id': '54R6Y0I7jGUCveDTtI21nb',
#      'name': 'Boney M.',
#      'type': 'artist',
#      'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7fXtm0TpLRIJhxobKDjxRp'},
#    'href': 'https://api.spotify.com/v1/albums/7fXtm0TpLRIJhxobKDjxRp',
#    'id': '7fXtm0TpLRIJhxobKDjxRp',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273da8ce498bc7d441e6d841d25',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02da8ce498bc7d441e6d841d25',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851da8ce498bc7d441e6d841d25',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Daddy Cool',
#    'release_date': '2021-12-03',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:7fXtm0TpLRIJhxobKDjxRp'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12A83CWwFiyXy90ScLWPIe'},
#     'href': 'https://api.spotify.com/v1/artists/12A83CWwFiyXy90ScLWPIe',
#     'id': '12A83CWwFiyXy90ScLWPIe',
#     'name': 'LIZOT',
#     'type': 'artist',
#     'uri': 'spotify:artist:12A83CWwFiyXy90ScLWPIe'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#     'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#     'id': '54R6Y0I7jGUCveDTtI21nb',
#     'name': 'Boney M.',
#     'type': 'artist',
#     'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#   'disc_number': 1,
#   'duration_ms': 154858,
#   'explicit': False,
#   'external_ids': {'isrc': 'DEE862102870'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/50rcUhHimavzT1qq6QrgMG'},
#   'href': 'https://api.spotify.com/v1/tracks/50rcUhHimavzT1qq6QrgMG',
#   'id': '50rcUhHimavzT1qq6QrgMG',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Daddy Cool',
#   'popularity': 59,
#   'preview_url': 'https://p.scdn.co/mp3-preview/857d68f8f69125e431cea3e5e89e653440600762?cid=61f7d969ccdb47a98d5072e59a293026',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:50rcUhHimavzT1qq6QrgMG'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dn4KQgTE4P3jrwa3iIVzQ'},
#      'href': 'https://api.spotify.com/v1/artists/4dn4KQgTE4P3jrwa3iIVzQ',
#      'id': '4dn4KQgTE4P3jrwa3iIVzQ',
#      'name': 'Baccara',
#      'type': 'artist',
#      'uri': 'spotify:artist:4dn4KQgTE4P3jrwa3iIVzQ'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5e6VPOPLw5cSXsVMvQEioq'},
#    'href': 'https://api.spotify.com/v1/albums/5e6VPOPLw5cSXsVMvQEioq',
#    'id': '5e6VPOPLw5cSXsVMvQEioq',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273f9742033ffb15f5413898ef9',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02f9742033ffb15f5413898ef9',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851f9742033ffb15f5413898ef9',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'The Collection & Tracklisting',
#    'release_date': '1998',
#    'release_date_precision': 'year',
#    'total_tracks': 19,
#    'type': 'album',
#    'uri': 'spotify:album:5e6VPOPLw5cSXsVMvQEioq'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dn4KQgTE4P3jrwa3iIVzQ'},
#     'href': 'https://api.spotify.com/v1/artists/4dn4KQgTE4P3jrwa3iIVzQ',
#     'id': '4dn4KQgTE4P3jrwa3iIVzQ',
#     'name': 'Baccara',
#     'type': 'artist',
#     'uri': 'spotify:artist:4dn4KQgTE4P3jrwa3iIVzQ'}],
#   'disc_number': 1,
#   'duration_ms': 273866,
#   'explicit': False,
#   'external_ids': {'isrc': 'DEC760000065'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2LScqpywMqGcnum6nNaxXX'},
#   'href': 'https://api.spotify.com/v1/tracks/2LScqpywMqGcnum6nNaxXX',
#   'id': '2LScqpywMqGcnum6nNaxXX',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Yes Sir, I Can Boogie',
#   'popularity': 65,
#   'preview_url': 'https://p.scdn.co/mp3-preview/704fbc9b86f59da239d2de11d6d5baf808596856?cid=61f7d969ccdb47a98d5072e59a293026',
#   'track_number': 6,
#   'type': 'track',
#   'uri': 'spotify:track:2LScqpywMqGcnum6nNaxXX'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#      'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#      'id': '6RZUqkomCmb8zCRqc9eznB',
#      'name': 'Placebo',
#      'type': 'artist',
#      'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7kTsa1wUFrahJJf1cJEOpZ'},
#    'href': 'https://api.spotify.com/v1/albums/7kTsa1wUFrahJJf1cJEOpZ',
#    'id': '7kTsa1wUFrahJJf1cJEOpZ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27362c995dbce6d7ffa4c097475',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0262c995dbce6d7ffa4c097475',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485162c995dbce6d7ffa4c097475',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Covers',
#    'release_date': '2003-03-24',
#    'release_date_precision': 'day',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:7kTsa1wUFrahJJf1cJEOpZ'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#     'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#     'id': '6RZUqkomCmb8zCRqc9eznB',
#     'name': 'Placebo',
#     'type': 'artist',
#     'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#   'disc_number': 1,
#   'duration_ms': 201706,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBAAA0201215'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6blKbRwYDoXl5fFvQY2U75'},
#   'href': 'https://api.spotify.com/v1/tracks/6blKbRwYDoXl5fFvQY2U75',
#   'id': '6blKbRwYDoXl5fFvQY2U75',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Daddy Cool',
#   'popularity': 47,
#   'preview_url': 'https://p.scdn.co/mp3-preview/4af3ad78f847b23200036e9cee4d5b06868aea6b?cid=61f7d969ccdb47a98d5072e59a293026',
#   'track_number': 9,
#   'type': 'track',
#   'uri': 'spotify:track:6blKbRwYDoXl5fFvQY2U75'}]

# %%
pprint.pprint(results["tracks"]["items"][0]["id"])
# Out:
# '3WMbD1OyfKuwWDWMNbPQ4g'

# %% [markdown]
# # Understanding the json

# %%
print("The json file has the following keys: ",list(results.keys())) # We can see that we only have tracks
print("The 'tracks' key has the following child keys: ",list(results["tracks"].keys())) # Let's check the values
print("The query we made is: ",results["tracks"]["href"]) # Query we have searched 
print("The song's info is contained in: ",results["tracks"]["items"]) #items (actual tracks)
print("The limit of the query we've made is: ",results["tracks"]["limit"]) #Limit we have chosen
print("The next page if any: ",results["tracks"]["next"]) #link to the next page (next 50 tracks)
print("The starting webpage: ",results["tracks"]["offset"]) # Actual offset (starting point)
print("Starting webpage: ",results["tracks"]["previous"]) #Previous search
print("Total number of results: ",results["tracks"]["total"]) # Number of matches
# Out:
# The json file has the following keys:  ['tracks']
# The 'tracks' key has the following child keys:  ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# The query we made is:  https://api.spotify.com/v1/search?query=daddy+cool&type=track&market=GB&offset=0&limit=5
# The song's info is contained in:  [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'}, 'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb', 'id': '54R6Y0I7jGUCveDTtI21nb', 'name': 'Boney M.', 'type': 'artist', 'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/1KQUrny9y5zGpktF6hAGd4'}, 'href': 'https://api.spotify.com/v1/albums/1KQUrny9y5zGpktF6hAGd4', 'id': '1KQUrny9y5zGpktF6hAGd4', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273dafd1cd6e9537ec8463ea691', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02dafd1cd6e9537ec8463ea691', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851dafd1cd6e9537ec8463ea691', 'width': 64}], 'is_playable': True, 'name': 'Take The Heat Off Me', 'release_date': '1976', 'release_date_precision': 'year', 'total_tracks': 10, 'type': 'album', 'uri': 'spotify:album:1KQUrny9y5zGpktF6hAGd4'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'}, 'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb', 'id': '54R6Y0I7jGUCveDTtI21nb', 'name': 'Boney M.', 'type': 'artist', 'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}], 'disc_number': 1, 'duration_ms': 208600, 'explicit': False, 'external_ids': {'isrc': 'DEC737600002'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/3WMbD1OyfKuwWDWMNbPQ4g'}, 'href': 'https://api.spotify.com/v1/tracks/3WMbD1OyfKuwWDWMNbPQ4g', 'id': '3WMbD1OyfKuwWDWMNbPQ4g', 'is_local': False, 'is_playable': True, 'name': 'Daddy Cool', 'popularity': 77, 'preview_url': 'https://p.scdn.co/mp3-preview/03e2b60a6a5c101dc0d41866f2e079d8de4a663b?cid=61f7d969ccdb47a98d5072e59a293026', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:3WMbD1OyfKuwWDWMNbPQ4g'}, {'album': {'album_type': 'compilation', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'}, 'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb', 'id': '54R6Y0I7jGUCveDTtI21nb', 'name': 'Boney M.', 'type': 'artist', 'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/155cebHEGGBqYJAXKWJw6D'}, 'href': 'https://api.spotify.com/v1/albums/155cebHEGGBqYJAXKWJw6D', 'id': '155cebHEGGBqYJAXKWJw6D', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273d792d961638fd28f8d281947', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02d792d961638fd28f8d281947', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851d792d961638fd28f8d281947', 'width': 64}], 'is_playable': True, 'name': 'Daddy Cool', 'release_date': '1994-03-14', 'release_date_precision': 'day', 'total_tracks': 16, 'type': 'album', 'uri': 'spotify:album:155cebHEGGBqYJAXKWJw6D'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'}, 'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb', 'id': '54R6Y0I7jGUCveDTtI21nb', 'name': 'Boney M.', 'type': 'artist', 'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}], 'disc_number': 1, 'duration_ms': 220666, 'explicit': False, 'external_ids': {'isrc': 'DED160000010'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/5lWSa1rmuSL6OBPOnkAqoa'}, 'href': 'https://api.spotify.com/v1/tracks/5lWSa1rmuSL6OBPOnkAqoa', 'id': '5lWSa1rmuSL6OBPOnkAqoa', 'is_local': False, 'is_playable': True, 'name': 'Rasputin', 'popularity': 72, 'preview_url': 'https://p.scdn.co/mp3-preview/99129129d46b1937b0897e38d561110e1cd319f4?cid=61f7d969ccdb47a98d5072e59a293026', 'track_number': 3, 'type': 'track', 'uri': 'spotify:track:5lWSa1rmuSL6OBPOnkAqoa'}, {'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12A83CWwFiyXy90ScLWPIe'}, 'href': 'https://api.s ...
# The limit of the query we've made is:  5
# The next page if any:  https://api.spotify.com/v1/search?query=daddy+cool&type=track&market=GB&offset=5&limit=5
# The starting webpage:  0
# Starting webpage:  None
# Total number of results:  825

# %% [markdown]
# ## Other Info

# %%
results["tracks"]["items"][0]["artists"] # Track artists
results["tracks"]["items"][0]["id"] # Track ID
results["tracks"]["items"][0]["name"] # Track name
results["tracks"]["items"][0]["popularity"] # Popularity index
results["tracks"]["items"][0]["uri"] # Basically ID
# Out:
# 'spotify:track:3WMbD1OyfKuwWDWMNbPQ4g'

# %%
len(results['tracks']["items"])
# Out:
# 5

# %% [markdown]
# ## Getting the track_id

# %%
track_id=results["tracks"]["items"][0]["id"]
track_id
# Out:
# '3WMbD1OyfKuwWDWMNbPQ4g'

# %%
for item in results['tracks']['items']:
    print("The name of song is: '{}' and the id is: {}".format(item['name'],item["id"]))
# Out:
# The name of song is: 'Daddy Cool' and the id is: 3WMbD1OyfKuwWDWMNbPQ4g
# The name of song is: 'Rasputin' and the id is: 5lWSa1rmuSL6OBPOnkAqoa
# The name of song is: 'Daddy Cool' and the id is: 50rcUhHimavzT1qq6QrgMG
# The name of song is: 'Yes Sir, I Can Boogie' and the id is: 2LScqpywMqGcnum6nNaxXX
# The name of song is: 'Daddy Cool' and the id is: 6blKbRwYDoXl5fFvQY2U75

# %% [markdown]
# ## Embeded track player

# %%
from IPython.display import IFrame

track_id = '3WMbD1OyfKuwWDWMNbPQ4g'
#track_id= 'spotify:track:3hgl7EQwTutSm6PESsB7gZ'
IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/3WMbD1OyfKuwWDWMNbPQ4g?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
play_song('3WMbD1OyfKuwWDWMNbPQ4g')
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/3WMbD1OyfKuwWDWMNbPQ4g?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
recommendable_songs = ["tiny dancer",]

# %%
user_input = input("please enter your song: ")
if user_input in recommendable_songs:
    print("song found!")
    rec = random.choice(recommendable_songs)
    rec_json = sp.search
    user_json = sp.search(q=user_input, limit=5, market="GB")
    user_id = user_json["tracks"]["items"][0]["id"]
    display(play_song(user_id))

# %% [markdown]
# # Getting the Audio features of a song

# %%
id_ = results["tracks"]["items"][0]["id"]

# %%
sp.audio_features(id_ )

# %%
play_song('2TVxnKdb3tqe1nhQWwwZCO')

# %%
sp.audio_features("3WMbD1OyfKuwWDWMNbPQ4g")

# %% [markdown]
# ## Building a Data frame of audio features

# %%
sp.audio_features(results["tracks"]["items"][0]["uri"])

# %%
results

# %%
list_of_songs=[]
for i in results["tracks"]["items"]:
    list_of_songs.append(i["id"])

song_features = sp.audio_features(list_of_songs)

df=pd.DataFrame(song_features)    
df=df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df

# %% [markdown]
# ## Searching a playlist

# %%
results = sp.search(q="down jay sean")
play_song(results["tracks"]["items"][0]["id"])

# %%
playlist = sp.user_playlist_tracks("spotify", "4ebKOuGNfJ5g8RdtbEBHxe",market="GB")

# %%
playlist

# %%
type(playlist)

# %%
playlist.keys()

# %%
len(playlist["items"])

# %% [markdown]
# ## Extracting a song from playlist

# %%
pprint.pprint(playlist)

# %%
playlist["items"][0]["track"]["id"]

# %%
play_song(playlist["items"][0]["track"]["id"])

# %%
print(list(playlist.keys())) # Let's look at items and total:
print("Total number of songs in the playlist: ",playlist["total"]) #  Let's check items:
len(playlist["items"]) # It is limited to 100 tracks, we will have to fix it:

# %% [markdown]
# ## Extracting the songs of a playlist

# %% [markdown]
# Pagination using "next"
# When you collect songs from a playlist using sp.playlist_tracks, you're limited by the limit parameter, which has a maximum (and default) value of 100. When the playlist has more than 100 songs, you have to collect them by navigating through the "pages" of the results.
#
# The parameter offset allows you to retrieve resuls starting at a certain position: if you start at position 101, you'd get the next "page" of results. An offset of 201 would give you the third page, and so on.
#
# The function sp.next() does the same, but in a simpler way: it can be used on the results from any request to directly retrieve the results for the next page.
#
# We can check whether there's a next page or not by accessing the key next on the results from any request.

# %%
sp.audio_features(bob_dylan_id_list)

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
spanish_tracks = get_playlist_tracks("Spotify","37i9dQZF1EQpj7X7UK8OOF")

spanish_ids = []
for i in spanish_tracks:
    spanish_ids.append(i['track']['id'])
 
af = sp.audio_features(spanish_ids)

# %%
len(spanish_tracks)

# %%
spanish_ids = []
for i in spanish_tracks:
    spanish_ids.append(i['track']['id'])

# %%
len(spanish_ids)

# %%
spanish_ids

# %%
af = sp.audio_features(spanish_ids)

# %%
af

# %%
spanish_df = pd.DataFrame(af)
spanish_df.head()

# %% [markdown]
# ### Chopping a big playlist into chunks

# %%
big_playlist_tracks = get_playlist_tracks("Spotify","2s1KwThY09NjEkmzeTsZWe")

# %%
bp_ids = []
for i in big_playlist_tracks:
    bp_ids.append(i['track']['id'])

# %%
chunk_size = 100
bp_ids_chopped = [bp_ids[i:i+chunk_size] for i in range(0,len(bp_ids), 100)]

# %%
bp_ids_chopped

# %%
af_list = []
for i in bp_ids_chopped:
    af_list.extend(sp.audio_features(i))
pd.DataFrame(af_list)

# %% [markdown]
# ### Example with rock

# %%
rock = get_playlist_tracks('Spotify','37i9dQZF1DWXRqgorJj26U')

# %%
rock_ids =[]
for i in rock:
    rock_ids.append(i['track']['id'])

# %%
len(rock_ids)

# %%
chunk_size = 100
rock_ids_chopped = [rock_ids[i:i+chunk_size] for i in range(0,len(rock_ids), 100)]

# %%
rock_af = []
for i in rock_ids_chopped:
    rock_af.extend(sp.audio_features(i))

# %%
rock_df = pd.DataFrame(rock_af)
rock_df

# %% [markdown]
# ## Optional(Extra)

# %% [markdown]
# ## Getting the artists of the playlist

# %%
def get_artists_from_track(track):
    return [artist["name"] for artist in track["artists"]]

# %%
def get_artists_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    return list(set(artist for subset in [get_artists_from_track(track["track"]) for track in tracks_from_playlist] for artist in subset))

# %%
get_artists_from_playlist("4rnleEAOdmFAbRcNCgZMpY")

# %% [markdown]
# # Getting albums

# %% [markdown]
# In this section we will work with albums to extract information. We will start by extracting all the albums of an artist.

# %%
def get_albums_from_artist(artist_id):
    results = sp.artist_albums(artist_id, limit = 50,country="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# Same for albums ids
def get_album_ids_from_artist(artist_id):
    results = sp.artist_albums(artist_id, limit = 50)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return [track["id"] for track in tracks]

# %% [markdown]
# Example: Coldplay

# %%
coldplay_id = "4gzpq5DPGxSnKTe4SA8HAU"
coldplay_albums = get_albums_from_artist(coldplay_id)
coldplay_album_ids = get_album_ids_from_artist(coldplay_id)

# Check artists that played with coldplay
set([artist["name"] for track in coldplay_albums for artist in track["artists"]])

# %% [markdown]
# ## Getting the songs of a given album

# %%
def get_track_ids_from_albums(album_ids):
    return list(set([i["id"] for j in album_ids for i in sp.album(j)["tracks"]["items"]]))

# %%
coldplay_songs = get_track_ids_from_albums(coldplay_album_ids)

len(coldplay_songs)
