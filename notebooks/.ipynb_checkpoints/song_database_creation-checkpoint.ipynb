# %% [markdown]
# # Song Database Creation

# %% [markdown]
# ## Overview

# %% [markdown]
# ### Deliverable
# - Audio features dataframe with minimum of 1000 songs. Although the more song the better. A few thousand would be good.
#
# ### Notes
# - for getting audio features, each user account has a limited number of requests. Sending too many requests will result in you getting locked out. To avoid this make sure to divide your track list in chunks and send one request for your whole playlist
#
# ### Ideas
# - Create function to make the process repeatable for other playlist

# %% [markdown]
# ### Steps
# 1. get playlist_id
#    - playlist_id can be copied from url
#    - or use sp.search(q=“r&b, limit=3,type=“playlist”)
# 2. get playlist tracks
# 3. get track ids
# 4. chop id's into chunks
# 5. get audio features of each chunk
# 6. create dataframe
# 7. csv export

# %% [markdown]
# #### Importing functions credentials and data

# %%
#Libraries and functions
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import json
import pprint

#importing spotify API credentials
import config

# %%
#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %% [markdown]
# #### 1. Get playlist id

# %%
everything_good_playlist_id = '1v94bqukAqC4IqLTERiljX'
everything_good_user_name = "1167792454"

#pprint.pprint(everything_good)

# %% [markdown]
# #### 2. Get playlist tracks

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
tracks = get_playlist_tracks(everything_good_user_name,everything_good_playlist_id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       6         tracks.extend(results['items'])
#       7     return tracks
# ----> 9 tracks = get_playlist_tracks(everything_good_user_name,everything_good_playlist_id)
#
# NameError: name 'everything_good_user_name' is not defined

# %% [markdown]
# #### 3. Get track ids

# %%
#testing for 1 track
tracks["tracks"]["items"][0]["track"]["id"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[97], line 2
#       1 #testing for 1 track
# ----> 2 tracks["tracks"]["items"][0]["track"]["id"]
#
# TypeError: list indices must be integers or slices, not str

# %%
#for all
track_ids = []
for i in tracks:
    track_ids.append(i['track']['id'])
#track_ids

# %% [markdown]
# #### 4. Chopping track ids into chunks

# %%
chunk_size = 100
track_ids_chopped = [track_ids[i:i+chunk_size] for i in range(0,len(track_ids), 100)]
#track_ids_chopped

# %% [markdown]
# #### 5. Get audio features

# %%
af_list = []
for i in track_ids_chopped:
    af_list.extend(sp.audio_features(i))

# %%
af_list
# Out:
# [{'danceability': 0.382,
#   'energy': 0.451,
#   'key': 7,
#   'loudness': -6.606,
#   'mode': 0,
#   'speechiness': 0.0293,
#   'acousticness': 0.557,
#   'instrumentalness': 3.39e-05,
#   'liveness': 0.265,
#   'valence': 0.506,
#   'tempo': 150.803,
#   'type': 'audio_features',
#   'id': '6yzJiHzsscf0n88xb9aNT4',
#   'uri': 'spotify:track:6yzJiHzsscf0n88xb9aNT4',
#   'track_href': 'https://api.spotify.com/v1/tracks/6yzJiHzsscf0n88xb9aNT4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6yzJiHzsscf0n88xb9aNT4',
#   'duration_ms': 267540,
#   'time_signature': 4},
#  {'danceability': 0.742,
#   'energy': 0.375,
#   'key': 7,
#   'loudness': -13.829,
#   'mode': 1,
#   'speechiness': 0.0482,
#   'acousticness': 0.397,
#   'instrumentalness': 0.901,
#   'liveness': 0.0996,
#   'valence': 0.105,
#   'tempo': 102.023,
#   'type': 'audio_features',
#   'id': '5zdXRoKLZ54VBdbdn7yhz4',
#   'uri': 'spotify:track:5zdXRoKLZ54VBdbdn7yhz4',
#   'track_href': 'https://api.spotify.com/v1/tracks/5zdXRoKLZ54VBdbdn7yhz4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5zdXRoKLZ54VBdbdn7yhz4',
#   'duration_ms': 342163,
#   'time_signature': 4},
#  {'danceability': 0.585,
#   'energy': 0.552,
#   'key': 0,
#   'loudness': -10.613,
#   'mode': 1,
#   'speechiness': 0.0353,
#   'acousticness': 0.194,
#   'instrumentalness': 0.0171,
#   'liveness': 0.0735,
#   'valence': 0.496,
#   'tempo': 100.089,
#   'type': 'audio_features',
#   'id': '5qvCKAyjgHnpR5c63OedCY',
#   'uri': 'spotify:track:5qvCKAyjgHnpR5c63OedCY',
#   'track_href': 'https://api.spotify.com/v1/tracks/5qvCKAyjgHnpR5c63OedCY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5qvCKAyjgHnpR5c63OedCY',
#   'duration_ms': 267813,
#   'time_signature': 4},
#  {'danceability': 0.405,
#   'energy': 0.535,
#   'key': 6,
#   'loudness': -7.504,
#   'mode': 0,
#   'speechiness': 0.0531,
#   'acousticness': 0.0531,
#   'instrumentalness': 0.106,
#   'liveness': 0.0696,
#   'valence': 0.637,
#   'tempo': 97.698,
#   'type': 'audio_features',
#   'id': '2vByA9JgfMU2bPjUqmxCdv',
#   'uri': 'spotify:track:2vByA9JgfMU2bPjUqmxCdv',
#   'track_href': 'https://api.spotify.com/v1/tracks/2vByA9JgfMU2bPjUqmxCdv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2vByA9JgfMU2bPjUqmxCdv',
#   'duration_ms': 210800,
#   'time_signature': 4},
#  {'danceability': 0.586,
#   'energy': 0.526,
#   'key': 0,
#   'loudness': -6.928,
#   'mode': 1,
#   'speechiness': 0.0564,
#   'acousticness': 0.555,
#   'instrumentalness': 0,
#   'liveness': 0.234,
#   'valence': 0.456,
#   'tempo': 107.153,
#   'type': 'audio_features',
#   'id': '0pPQwIjwqduvLfZORYYEaI',
#   'uri': 'spotify:track:0pPQwIjwqduvLfZORYYEaI',
#   'track_href': 'https://api.spotify.com/v1/tracks/0pPQwIjwqduvLfZORYYEaI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0pPQwIjwqduvLfZORYYEaI',
#   'duration_ms': 161267,
#   'time_signature': 4},
#  {'danceability': 0.71,
#   'energy': 0.831,
#   'key': 2,
#   'loudness': -6.847,
#   'mode': 0,
#   'speechiness': 0.0392,
#   'acousticness': 0.107,
#   'instrumentalness': 0.00131,
#   'liveness': 0.159,
#   'valence': 0.867,
#   'tempo': 104.972,
#   'type': 'audio_features',
#   'id': '39OqZkxrUiMAR1bG3oquBA',
#   'uri': 'spotify:track:39OqZkxrUiMAR1bG3oquBA',
#   'track_href': 'https://api.spotify.com/v1/tracks/39OqZkxrUiMAR1bG3oquBA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/39OqZkxrUiMAR1bG3oquBA',
#   'duration_ms': 227067,
#   'time_signature': 4},
#  {'danceability': 0.582,
#   'energy': 0.515,
#   'key': 11,
#   'loudness': -9.283,
#   'mode': 0,
#   'speechiness': 0.0578,
#   'acousticness': 0.608,
#   'instrumentalness': 0.000641,
#   'liveness': 0.0931,
#   'valence': 0.603,
#   'tempo': 115.732,
#   'type': 'audio_features',
#   'id': '3wO7lEbQYuxxEXmwfk335E',
#   'uri': 'spotify:track:3wO7lEbQYuxxEXmwfk335E',
#   'track_href': 'https://api.spotify.com/v1/tracks/3wO7lEbQYuxxEXmwfk335E',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3wO7lEbQYuxxEXmwfk335E',
#   'duration_ms': 263397,
#   'time_signature': 4},
#  {'danceability': 0.472,
#   'energy': 0.284,
#   'key': 9,
#   'loudness': -9.43,
#   'mode': 1,
#   'speechiness': 0.027,
#   'acousticness': 0.342,
#   'instrumentalness': 0.164,
#   'liveness': 0.104,
#   'valence': 0.304,
#   'tempo': 75.133,
#   'type': 'audio_features',
#   'id': '3ujQCboY7MGBBnU5uy9EUI',
#   'uri': 'spotify:track:3ujQCboY7MGBBnU5uy9EUI',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ujQCboY7MGBBnU5uy9EUI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ujQCboY7MGBBnU5uy9EUI',
#   'duration_ms': 294493,
#   'time_signature': 4},
#  {'danceability': 0.293,
#   'energy': 0.375,
#   'key': 1,
#   'loudness': -12.44,
#   'mode': 0,
#   'speechiness': 0.0328,
#   'acousticness': 0.826,
#   'instrumentalness': 1.83e-05,
#   'liveness': 0.161,
#   'valence': 0.29,
#   'tempo': 123.079,
#   'type': 'audio_features',
#   'id': '36EKCiUoj6onFAU6dQ6A1c',
#   'uri': 'spotify:track:36EKCiUoj6onFAU6dQ6A1c',
#   'track_href': 'https://api.spotify.com/v1/tracks/36EKCiUoj6onFAU6dQ6A1c',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/36EKCiUoj6onFAU6dQ6A1c',
#   'duration_ms': 220000,
#   'time_signature': 3},
#  {'danceability': 0.738,
#   'energy': 0.73,
#   'key': 1,
#   'loudness': -7.143,
#   'mode': 0,
#   'speechiness': 0.0575,
#   'acousticness': 0.115,
#   'instrumentalness': 0.538,
#   'liveness': 0.0791,
#   'valence': 0.567,
#   'tempo': 130.028,
#   'type': 'audio_features',
#   'id': '6mtfWoTjJbjk8cKjBB5UIf',
#   'uri': 'spotify:track:6mtfWoTjJbjk8cKjBB5UIf',
#   'track_href': 'https://api.spotify.com/v1/tracks/6mtfWoTjJbjk8cKjBB5UIf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6mtfWoTjJbjk8cKjBB5UIf',
#   'duration_ms': 243853,
#   'time_signature': 4},
#  {'danceability': 0.487,
#   'energy': 0.696,
#   'key': 4,
#   'loudness': -7.756,
#   'mode': 1,
#   'speechiness': 0.0269,
#   'acousticness': 0.0114,
#   'instrumentalness': 0.568,
#   'liveness': 0.107,
#   'valence': 0.529,
#   'tempo': 100.021,
#   'type': 'audio_features',
#   'id': '7LJv6Z43m6Z8TDDYPLkz8K',
#   'uri': 'spotify:track:7LJv6Z43m6Z8TDDYPLkz8K',
#   'track_href': 'https://api.spotify.com/v1/tracks/7LJv6Z43m6Z8TDDYPLkz8K',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7LJv6Z43m6Z8TDDYPLkz8K',
#   'duration_ms': 340040,
#   'time_signature': 4},
#  {'danceability': 0.734,
#   'energy': 0.491,
#   'key': 9,
#   'loudness': -10.743,
#   'mode': 0,
#   'speechiness': 0.0286,
#   'acousticness': 0.635,
#   'instrumentalness': 0.0284,
#   'liveness': 0.0834,
#   'valence': 0.59,
#   'tempo': 119.161,
#   'type': 'audio_features',
#   'id': '315zoLAH6dY5ON7zQe8cWs',
#   'uri': 'spotify:track:315zoLAH6dY5ON7zQe8cWs',
#   'track_href': 'https://api.spotify.com/v1/tracks/315zoLAH6dY5ON7zQe8cWs',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/315zoLAH6dY5ON7zQe8cWs',
#   'duration_ms': 337480,
#   'time_signature': 4},
#  {'danceability': 0.741,
#   'energy': 0.734,
#   'key': 8,
#   'loudness': -7.97,
#   'mode': 1,
#   'speechiness': 0.0501,
#   'acousticness': 0.00642,
#   'instrumentalness': 0.000286,
#   'liveness': 0.0292,
#   'valence': 0.806,
#   'tempo': 109.066,
#   'type': 'audio_features',
#   'id': '4CD5Jr9UuR1itRoM4dSYnh',
#   'uri': 'spotify:track:4CD5Jr9UuR1itRoM4dSYnh',
#   'track_href': 'https://api.spotify.com/v1/tracks/4CD5Jr9UuR1itRoM4dSYnh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4CD5Jr9UuR1itRoM4dSYnh',
#   'duration_ms': 300399,
#   'time_signature': 4},
#  {'danceability': 0.51,
#   'energy': 0.877,
#   'key': 8,
#   'loudness': -5.719,
#   'mode': 0,
#   'speechiness': 0.0385,
#   'acousticness': 0.0706,
#   'instrumentalness': 0.00144,
#   'liveness': 0.269,
#   'valence': 0.843,
#   'tempo': 79.882,
#   'type': 'audio_features',
#   'id': '4G4CUtpdFldmLcKqDdrVaJ',
#   'uri': 'spotify:track:4G4CUtpdFldmLcKqDdrVaJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/4G4CUtpdFldmLcKqDdrVaJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4G4CUtpdFldmLcKqDdrVaJ',
#   'duration_ms': 282060,
#   'time_signature': 4},
#  {'danceability': 0.608,
#   'energy': 0.402,
#   'key': 2,
#   'loudness': -10.816,
#   'mode': 0,
#   'speechiness': 0.0339,
#   'acousticness': 0.208,
#   'instrumentalness': 0.105,
#   'liveness': 0.12,
#   'valence': 0.119,
#   'tempo': 116.378,
#   'type': 'audio_features',
#   'id': '2m32wOGkiV8ltxXvwwVeao',
#   'uri': 'spotify:track:2m32wOGkiV8ltxXvwwVeao',
#   'track_href': 'https://api.spotify.com/v1/tracks/2m32wOGkiV8ltxXvwwVeao',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2m32wOGkiV8ltxXvwwVeao',
#   'duration_ms': 327680,
#   'time_signature': 4},
#  {'danceability': 0.578,
#   'energy': 0.808,
#   'key': 9,
#   'loudness': -4.131,
#   'mode': 1,
#   'speechiness': 0.0284,
#   'acousticness': 0.0608,
#   'instrumentalness': 0.144,
#   'liveness': 0.0388,
#   'valence': 0.597,
#   'tempo': 93.979,
#   'type': 'audio_features',
#   'id': '3O30ywyRk6EKT68sBvVqOP',
#   'uri': 'spotify:track:3O30ywyRk6EKT68sBvVqOP',
#   'track_href': 'https://api.spotify.com/v1/tracks/3O30ywyRk6EKT68sBvVqOP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3O30ywyRk6EKT68sBvVqOP',
#   'duration_ms': 190613,
#   'time_signature': 4},
#  {'danceability': 0.629,
#   'energy': 0.915,
#   'key': 10,
#   'loudness': -6.567,
#   'mode': 1,
#   'speechiness': 0.0383,
#   'acousticness': 0.0666,
#   'instrumentalness': 0.793,
#   'liveness': 0.0928,
#   'valence': 0.892,
#   'tempo': 118.345,
#   'type': 'audio_features',
#   'id': '21extzX26A1BEXAkllMPT4',
#   'uri': 'spotify:track:21extzX26A1BEXAkllMPT4',
#   'track_href': 'https://api.spotify.com/v1/tracks/21extzX26A1BEXAkllMPT4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/21extzX26A1BEXAkllMPT4',
#   'duration_ms': 262000,
#   'time_signature': 4},
#  {'danceability': 0.752,
#   'energy': 0.54,
#   'key': 5,
#   'loudness': -8.986,
#   'mode': 1,
#   'speechiness': 0.0768,
#   'acousticness': 0.561,
#   'instrumentalness': 0.000155,
#   'liveness': 0.0919,
#   'valence': 0.882,
#   'tempo': 114.217,
#   'type': 'audio_features',
#   'id': '4AHU8QRdwCUWxPC53cw4Hh',
#   'uri': 'spotify:track:4AHU8QRdwCUWxPC53cw4Hh',
#   'track_href': 'https://api.spotify.com/v1/tracks/4AHU8QRdwCUWxPC53cw4Hh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4AHU8QRdwCUWxPC53cw4Hh',
#   'duration_ms': 172733,
#   'time_signature': 4},
#  {'danceability': 0.562,
#   'energy': 0.717,
#   'key': 4,
#   'loudness': -6.449,
#   'mode': 1,
#   'speechiness': 0.0293,
#   'acousticness': 0.0426,
#   'instrumentalness': 0.00919,
#   'liveness': 0.257,
#   'valence': 0.527,
#   'tempo': 85.0,
#   'type': 'audio_features',
#   'id': '1kDL4EErmvXdQCZRJoJHQn',
#   'uri': 'spotify:track:1kDL4EErmvXdQCZRJoJHQn',
#   'track_href': 'https://api.spotify.com/v1/tracks/1kDL4EErmvXdQCZRJoJHQn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1kDL4EErmvXdQCZRJoJHQn',
#   'duration_ms': 297733,
#   'time_signature': 4},
#  {'danceability': 0.746,
#   'energy': 0.582,
#   'key': 9,
#   'loudness': -6.283,
#   'mode': 1,
#   'speechiness': 0.0394,
#   'acousticness': 0.12,
#   'instrumentalness': 2.44e-05,
#   'liveness': 0.0831,
#   'valence': 0.914,
#   'tempo': 113.058,
#   'type': 'audio_features',
#   'id': '4aCsgwFhbZ8CmYAotK7W2B',
#   'uri': 'spotify:track:4aCsgwFhbZ8CmYAotK7W2B',
#   'track_href': 'https://api.spotify.com/v1/tracks/4aCsgwFhbZ8CmYAotK7W2B',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4aCsgwFhbZ8CmYAotK7W2B',
#   'duration_ms': 284387,
#   'time_signature': 4},
#  {'danceability': 0.182,
#   'energy': 0.539,
#   'key': 10,
#   'loudness': -10.839,
#   'mode': 0,
#   'speechiness': 0.0799,
#   'acousticness': 0.0781,
#   'instrumentalness': 0.000101,
#   'liveness': 0.212,
#   'valence': 0.413,
#   'tempo': 69.717,
#   'type': 'audio_features',
#   'id': '3Wkho6tesTh4aF80T6evqH',
#   'uri': 'spotify:track:3Wkho6tesTh4aF80T6evqH',
#   'track_href': 'https://api.spotify.com/v1/tracks/3Wkho6tesTh4aF80T6evqH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Wkho6tesTh4aF80T6evqH',
#   'duration_ms': 329467,
#   'time_signature': 4},
#  {'danceability': 0.566,
#   'energy': 0.511,
#   'key': 6,
#   'loudness': -8.826,
#   'mode': 0,
#   'speechiness': 0.0614,
#   'acousticness': 0.676,
#   'instrumentalness': 3e-06,
#   'liveness': 0.221,
#   'valence': 0.257,
#   'tempo': 123.311,
#   'type': 'audio_features',
#   'id': '2h2FLYLTGP3wKSbZAPrnes',
#   'uri': 'spotify:track:2h2FLYLTGP3wKSbZAPrnes',
#   'track_href': 'https://api.spotify.com/v1/tracks/2h2FLYLTGP3wKSbZAPrnes',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2h2FLYLTGP3wKSbZAPrnes',
#   'duration_ms': 250013,
#   'time_signature': 4},
#  {'danceability': 0.553,
#   'energy': 0.417,
#   'key': 9,
#   'loudness': -9.032,
#   'mode': 1,
#   'speechiness': 0.0347,
#   'acousticness': 0.648,
#   'instrumentalness': 0.0004,
#   'liveness': 0.102,
#   'valence': 0.244,
#   'tempo': 87.372,
#   'type': 'audio_features',
#   'id': '6QlroU0h60W8iiJdwQGd2C',
#   'uri': 'spotify:track:6QlroU0h60W8iiJdwQGd2C',
#   'track_href': 'https://api.spotify.com/v1/tracks/6QlroU0h60W8iiJdwQGd2C',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6QlroU0h60W8iiJdwQGd2C',
#   'duration_ms': 195053,
#   'time_signature': 4},
#  {'danceability': 0.427,
#   'energy': 0.467,
#   'key': 6,
#   'loudness': -4.589,
#   'mode': 1,
#   'speechiness': 0.0348,
#   'acousticness': 0.22,
#   'instrumentalness': 0.79,
#   'liveness': 0.102,
#   'valence': 0.0758,
#   'tempo': 77.217,
#   'type': 'audio_features',
#   'id': '4GZ0mDOTfdYEFqhddeguic',
#   'uri': 'spotify:track:4GZ0mDOTfdYEFqhddeguic',
#   'track_href': 'https://api.spotify.com/v1/tracks/4GZ0mDOTfdYEFqhddeguic',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4GZ0mDOTfdYEFqhddeguic',
#   'duration_ms': 251665,
#   'time_signature': 3},
#  {'danceability': 0.459,
#   'energy': 0.774,
#   'key': 6,
#   'loudness': -4.326,
#   'mode': 0,
#   'speechiness': 0.0438,
#   'acousticness': 0.116,
#   'instrumentalness': 0.246,
#   'liveness': 0.0957,
#   'valence': 0.523,
#   'tempo': 76.761,
#   'type': 'audio_features',
#   'id': '0Iz72FGhG44jBHV1KhteYs',
#   'uri': 'spotify:track:0Iz72FGhG44jBHV1KhteYs',
#   'track_href': 'https://api.spotify.com/v1/tracks/0Iz72FGhG44jBHV1KhteYs',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Iz72FGhG44jBHV1KhteYs',
#   'duration_ms': 201613,
#   'time_signature': 4},
#  {'danceability': 0.386,
#   'energy': 0.866,
#   'key': 6,
#   'loudness': -5.56,
#   'mode': 1,
#   'speechiness': 0.0465,
#   'acousticness': 0.0517,
#   'instrumentalness': 0.912,
#   'liveness': 0.0778,
#   'valence': 0.151,
#   'tempo': 120.048,
#   'type': 'audio_features',
#   'id': '3tBbcuulKDC1o2odykT18R',
#   'uri': 'spotify:track:3tBbcuulKDC1o2odykT18R',
#   'track_href': 'https://api.spotify.com/v1/tracks/3tBbcuulKDC1o2odykT18R',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3tBbcuulKDC1o2odykT18R',
#   'duration_ms': 301493,
#   'time_signature': 4},
#  {'danceability': 0.561,
#   'energy': 0.489,
#   'key': 9,
#   'loudness': -7.476,
#   'mode': 0,
#   'speechiness': 0.0322,
#   'acousticness': 0.0236,
#   'instrumentalness': 0.0401,
#   'liveness': 0.0828,
#   'valence': 0.156,
#   'tempo': 141.382,
#   'type': 'audio_features',
#   'id': '09wLmYMwtkACbGAPqX22Pb',
#   'uri': 'spotify:track:09wLmYMwtkACbGAPqX22Pb',
#   'track_href': 'https://api.spotify.com/v1/tracks/09wLmYMwtkACbGAPqX22Pb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/09wLmYMwtkACbGAPqX22Pb',
#   'duration_ms': 202440,
#   'time_signature': 4},
#  {'danceability': 0.718,
#   'energy': 0.642,
#   'key': 0,
#   'loudness': -5.129,
#   'mode': 1,
#   'speechiness': 0.0234,
#   'acousticness': 0.0227,
#   'instrumentalness': 0.00116,
#   'liveness': 0.0445,
#   'valence': 0.637,
#   'tempo': 105.983,
#   'type': 'audio_features',
#   'id': '4JVdyAfcmWebp3lWO4OOHk',
#   'uri': 'spotify:track:4JVdyAfcmWebp3lWO4OOHk',
#   'track_href': 'https://api.spotify.com/v1/tracks/4JVdyAfcmWebp3lWO4OOHk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4JVdyAfcmWebp3lWO4OOHk',
#   'duration_ms': 257467,
#   'time_signature': 4},
#  {'danceability': 0.586,
#   'energy': 0.822,
#   'key': 7,
#   'loudness': -6.86,
#   'mode': 1,
#   'speechiness': 0.0972,
#   'acousticness': 0.199,
#   'instrumentalness': 8.44e-06,
#   'liveness': 0.258,
#   'valence': 0.701,
#   'tempo': 131.833,
#   'type': 'audio_features',
#   'id': '3LKfHbhF3HAyWA2IcoE1lP',
#   'uri': 'spotify:track:3LKfHbhF3HAyWA2IcoE1lP',
#   'track_href': 'https://api.spotify.com/v1/tracks/3LKfHbhF3HAyWA2IcoE1lP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3LKfHbhF3HAyWA2IcoE1lP',
#   'duration_ms': 304507,
#   'time_signature': 4},
#  {'danceability': 0.676,
#   'energy': 0.352,
#   'key': 2,
#   'loudness': -10.239,
#   'mode': 0,
#   'speechiness': 0.0345,
#   'acousticness': 0.129,
#   'instrumentalness': 0.283,
#   'liveness': 0.11,
#   'valence': 0.492,
#   'tempo': 121.438,
#   'type': 'audio_features',
#   'id': '5x4Tv2PICzkwkixYuSmbYX',
#   'uri': 'spotify:track:5x4Tv2PICzkwkixYuSmbYX',
#   'track_href': 'https://api.spotify.com/v1/tracks/5x4Tv2PICzkwkixYuSmbYX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5x4Tv2PICzkwkixYuSmbYX',
#   'duration_ms': 492267,
#   'time_signature': 4},
#  {'danceability': 0.733,
#   'energy': 0.47,
#   'key': 7,
#   'loudness': -9.303,
#   'mode': 1,
#   'speechiness': 0.0398,
#   'acousticness': 0.541,
#   'instrumentalness': 0.272,
#   'liveness': 0.0992,
#   'valence': 0.326,
#   'tempo': 117.965,
#   'type': 'audio_features',
#   'id': '51BNtB8pe00pzc6oa36G3C',
#   'uri': 'spotify:track:51BNtB8pe00pzc6oa36G3C',
#   'track_href': 'https://api.spotify.com/v1/tracks/51BNtB8pe00pzc6oa36G3C',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/51BNtB8pe00pzc6oa36G3C',
#   'duration_ms': 289880,
#   'time_signature': 4},
#  {'danceability': 0.389,
#   'energy': 0.698,
#   'key': 8,
#   'loudness': -7.214,
#   'mode': 0,
#   'speechiness': 0.0314,
#   'acousticness': 0.00026,
#   'instrumentalness': 0.216,
#   'liveness': 0.135,
#   'valence': 0.405,
#   'tempo': 90.853,
#   'type': 'audio_features',
#   'id': '3wqMCDKWWYHnPLldMskKHe',
#   'uri': 'spotify:track:3wqMCDKWWYHnPLldMskKHe',
#   'track_href': 'https://api.spotify.com/v1/tracks/3wqMCDKWWYHnPLldMskKHe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3wqMCDKWWYHnPLldMskKHe',
#   'duration_ms': 220918,
#   'time_signature': 4},
#  {'danceability': 0.573,
#   'energy': 0.639,
#   'key': 0,
#   'loudness': -7.143,
#   'mode': 1,
#   'speechiness': 0.0247,
#   'acousticness': 0.784,
#   'instrumentalness': 0.633,
#   'liveness': 0.0923,
#   'valence': 0.24,
#   'tempo': 89.575,
#   'type': 'audio_features',
#   'id': '2NJGAT43AvS7BQvn2017yS',
#   'uri': 'spotify:track:2NJGAT43AvS7BQvn2017yS',
#   'track_href': 'https://api.spotify.com/v1/tracks/2NJGAT43AvS7BQvn2017yS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2NJGAT43AvS7BQvn2017yS',
#   'duration_ms': 248707,
#   'time_signature': 4},
#  {'danceability': 0.47,
#   'energy': 0.707,
#   'key': 1,
#   'loudness': -7.477,
#   'mode': 0,
#   'speechiness': 0.0419,
#   'acousticness': 0.01,
#   'instrumentalness': 0.677,
#   'liveness': 0.37,
#   'valence': 0.165,
#   'tempo': 122.042,
#   'type': 'audio_features',
#   'id': '5eqzXinSklkN4gId6EQUAR',
#   'uri': 'spotify:track:5eqzXinSklkN4gId6EQUAR',
#   'track_href': 'https://api.spotify.com/v1/tracks/5eqzXinSklkN4gId6EQUAR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5eqzXinSklkN4gId6EQUAR',
#   'duration_ms': 608280,
#   'time_signature': 4},
#  {'danceability': 0.81,
#   'energy': 0.591,
#   'key': 8,
#   'loudness': -13.385,
#   'mode': 1,
#   'speechiness': 0.0638,
#   'acousticness': 0.414,
#   'instrumentalness': 0.799,
#   'liveness': 0.072,
#   'valence': 0.297,
#   'tempo': 136.028,
#   'type': 'audio_features',
#   'id': '2BndJYJQ17UcEeUFJP5JmY',
#   'uri': 'spotify:track:2BndJYJQ17UcEeUFJP5JmY',
#   'track_href': 'https://api.spotify.com/v1/tracks/2BndJYJQ17UcEeUFJP5JmY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2BndJYJQ17UcEeUFJP5JmY',
#   'duration_ms': 297775,
#   'time_signature': 4},
#  {'danceability': 0.55,
#   'energy': 0.534,
#   'key': 9,
#   'loudness': -9.356,
#   'mode': 1,
#   'speechiness': 0.0242,
#   'acousticness': 0.0585,
#   'instrumentalness': 0.321,
#   'liveness': 0.0985,
#   'valence': 0.383,
#   'tempo': 103.008,
#   'type': 'audio_features',
#   'id': '75JpQ4zVP7oev1dJwlMRwb',
#   'uri': 'spotify:track:75JpQ4zVP7oev1dJwlMRwb',
#   'track_href': 'https://api.spotify.com/v1/tracks/75JpQ4zVP7oev1dJwlMRwb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/75JpQ4zVP7oev1dJwlMRwb',
#   'duration_ms': 266283,
#   'time_signature': 1},
#  {'danceability': 0.539,
#   'energy': 0.937,
#   'key': 9,
#   'loudness': -3.14,
#   'mode': 1,
#   'speechiness': 0.345,
#   'acousticness': 0.489,
#   'instrumentalness': 0,
#   'liveness': 0.0723,
#   'valence': 0.523,
#   'tempo': 85.037,
#   'type': 'audio_features',
#   'id': '4T4nq08BQ3zygdf74K5AZM',
#   'uri': 'spotify:track:4T4nq08BQ3zygdf74K5AZM',
#   'track_href': 'https://api.spotify.com/v1/tracks/4T4nq08BQ3zygdf74K5AZM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4T4nq08BQ3zygdf74K5AZM',
#   'duration_ms': 356800,
#   'time_signature': 4},
#  {'danceability': 0.655,
#   'energy': 0.422,
#   'key': 1,
#   'loudness': -9.424,
#   'mode': 0,
#   'speechiness': 0.0341,
#   'acousticness': 0.902,
#   'instrumentalness': 0.549,
#   'liveness': 0.105,
#   'valence': 0.425,
#   'tempo': 78.678,
#   'type': 'audio_features',
#   'id': '4AlpKDHtYkP6gsBNVAZ8FR',
#   'uri': 'spotify:track:4AlpKDHtYkP6gsBNVAZ8FR',
#   'track_href': 'https://api.spotify.com/v1/tracks/4AlpKDHtYkP6gsBNVAZ8FR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4AlpKDHtYkP6gsBNVAZ8FR',
#   'duration_ms': 184773,
#   'time_signature': 4},
#  {'danceability': 0.554,
#   'energy': 0.749,
#   'key': 10,
#   'loudness': -7.365,
#   'mode': 1,
#   'speechiness': 0.0266,
#   'acousticness': 0.00189,
#   'instrumentalness': 0.39,
#   'liveness': 0.124,
#   'valence': 0.823,
#   'tempo': 168.057,
#   'type': 'audio_features',
#   'id': '5mqr5kF7oNDdcG01qazSqK',
#   'uri': 'spotify:track:5mqr5kF7oNDdcG01qazSqK',
#   'track_href': 'https://api.spotify.com/v1/tracks/5mqr5kF7oNDdcG01qazSqK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5mqr5kF7oNDdcG01qazSqK',
#   'duration_ms': 252140,
#   'time_signature': 4},
#  {'danceability': 0.88,
#   'energy': 0.336,
#   'key': 5,
#   'loudness': -12.824,
#   'mode': 1,
#   'speechiness': 0.0769,
#   'acousticness': 0.79,
#   'instrumentalness': 0.939,
#   'liveness': 0.0841,
#   'valence': 0.741,
#   'tempo': 135.055,
#   'type': 'audio_features',
#   'id': '5QvreZXI9NSx1A7NXLjuxt',
#   'uri': 'spotify:track:5QvreZXI9NSx1A7NXLjuxt',
#   'track_href': 'https://api.spotify.com/v1/tracks/5QvreZXI9NSx1A7NXLjuxt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5QvreZXI9NSx1A7NXLjuxt',
#   'duration_ms': 217227,
#   'time_signature': 4},
#  {'danceability': 0.428,
#   'energy': 0.641,
#   'key': 0,
#   'loudness': -8.131,
#   'mode': 1,
#   'speechiness': 0.0296,
#   'acousticness': 0.00884,
#   'instrumentalness': 0.111,
#   'liveness': 0.122,
#   'valence': 0.208,
#   'tempo': 109.356,
#   'type': 'audio_features',
#   'id': '0YBA7eO8kqEzUoC6zAEutF',
#   'uri': 'spotify:track:0YBA7eO8kqEzUoC6zAEutF',
#   'track_href': 'https://api.spotify.com/v1/tracks/0YBA7eO8kqEzUoC6zAEutF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0YBA7eO8kqEzUoC6zAEutF',
#   'duration_ms': 337240,
#   'time_signature': 4},
#  {'danceability': 0.484,
#   'energy': 0.548,
#   'key': 7,
#   'loudness': -6.119,
#   'mode': 1,
#   'speechiness': 0.033,
#   'acousticness': 0.0218,
#   'instrumentalness': 0.558,
#   'liveness': 0.0956,
#   'valence': 0.177,
#   'tempo': 119.98,
#   'type': 'audio_features',
#   'id': '7GEo5JQN8lcqBaj6qyvWw1',
#   'uri': 'spotify:track:7GEo5JQN8lcqBaj6qyvWw1',
#   'track_href': 'https://api.spotify.com/v1/tracks/7GEo5JQN8lcqBaj6qyvWw1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7GEo5JQN8lcqBaj6qyvWw1',
#   'duration_ms': 249413,
#   'time_signature': 4},
#  {'danceability': 0.433,
#   'energy': 0.583,
#   'key': 9,
#   'loudness': -6.922,
#   'mode': 1,
#   'speechiness': 0.0687,
#   'acousticness': 0.799,
#   'instrumentalness': 0.000645,
#   'liveness': 0.0989,
#   'valence': 0.497,
#   'tempo': 84.415,
#   'type': 'audio_features',
#   'id': '6KPaX2zvWAOXYZjvhqdQZj',
#   'uri': 'spotify:track:6KPaX2zvWAOXYZjvhqdQZj',
#   'track_href': 'https://api.spotify.com/v1/tracks/6KPaX2zvWAOXYZjvhqdQZj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6KPaX2zvWAOXYZjvhqdQZj',
#   'duration_ms': 246253,
#   'time_signature': 4},
#  {'danceability': 0.497,
#   'energy': 0.681,
#   'key': 11,
#   'loudness': -6.817,
#   'mode': 0,
#   'speechiness': 0.0393,
#   'acousticness': 0.0123,
#   'instrumentalness': 0.0346,
#   'liveness': 0.121,
#   'valence': 0.523,
#   'tempo': 140.73,
#   'type': 'audio_features',
#   'id': '27IlmZoL4yRv7pK9pkf8N4',
#   'uri': 'spotify:track:27IlmZoL4yRv7pK9pkf8N4',
#   'track_href': 'https://api.spotify.com/v1/tracks/27IlmZoL4yRv7pK9pkf8N4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/27IlmZoL4yRv7pK9pkf8N4',
#   'duration_ms': 286613,
#   'time_signature': 4},
#  {'danceability': 0.179,
#   'energy': 0.182,
#   'key': 7,
#   'loudness': -17.737,
#   'mode': 1,
#   'speechiness': 0.0345,
#   'acousticness': 0.0476,
#   'instrumentalness': 0.0348,
#   'liveness': 0.398,
#   'valence': 0.0385,
#   'tempo': 142.748,
#   'type': 'audio_features',
#   'id': '1xD44zf2m2Ww06kZFRmeEc',
#   'uri': 'spotify:track:1xD44zf2m2Ww06kZFRmeEc',
#   'track_href': 'https://api.spotify.com/v1/tracks/1xD44zf2m2Ww06kZFRmeEc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1xD44zf2m2Ww06kZFRmeEc',
#   'duration_ms': 364773,
#   'time_signature': 4},
#  {'danceability': 0.534,
#   'energy': 0.62,
#   'key': 1,
#   'loudness': -8.733,
#   'mode': 0,
#   'speechiness': 0.0444,
#   'acousticness': 0.0115,
#   'instrumentalness': 0.655,
#   'liveness': 0.312,
#   'valence': 0.218,
#   'tempo': 116.998,
#   'type': 'audio_features',
#   'id': '3EGVvzScKq3FDFrMLky98x',
#   'uri': 'spotify:track:3EGVvzScKq3FDFrMLky98x',
#   'track_href': 'https://api.spotify.com/v1/tracks/3EGVvzScKq3FDFrMLky98x',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3EGVvzScKq3FDFrMLky98x',
#   'duration_ms': 338608,
#   'time_signature': 4},
#  {'danceability': 0.603,
#   'energy': 0.611,
#   'key': 8,
#   'loudness': -6.628,
#   'mode': 1,
#   'speechiness': 0.0396,
#   'acousticness': 0.145,
#   'instrumentalness': 0.000239,
#   'liveness': 0.26,
#   'valence': 0.35,
#   'tempo': 79.992,
#   'type': 'audio_features',
#   'id': '3m4G3QrKcKmgk0a7ZNWTtB',
#   'uri': 'spotify:track:3m4G3QrKcKmgk0a7ZNWTtB',
#   'track_href': 'https://api.spotify.com/v1/tracks/3m4G3QrKcKmgk0a7ZNWTtB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3m4G3QrKcKmgk0a7ZNWTtB',
#   'duration_ms': 276640,
#   'time_signature': 4},
#  {'danceability': 0.34,
#   'energy': 0.737,
#   'key': 8,
#   'loudness': -4.681,
#   'mode': 1,
#   'speechiness': 0.0582,
#   'acousticness': 0.000105,
#   'instrumentalness': 0.762,
#   'liveness': 0.0699,
#   'valence': 0.499,
#   'tempo': 172.022,
#   'type': 'audio_features',
#   'id': '4V0x90QcMh4ZxwHzEWOdtK',
#   'uri': 'spotify:track:4V0x90QcMh4ZxwHzEWOdtK',
#   'track_href': 'https://api.spotify.com/v1/tracks/4V0x90QcMh4ZxwHzEWOdtK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4V0x90QcMh4ZxwHzEWOdtK',
#   'duration_ms': 192080,
#   'time_signature': 4},
#  {'danceability': 0.129,
#   'energy': 0.288,
#   'key': 0,
#   'loudness': -7.05,
#   'mode': 1,
#   'speechiness': 0.0326,
#   'acousticness': 0.56,
#   'instrumentalness': 0.0164,
#   'liveness': 0.0468,
#   'valence': 0.06,
#   'tempo': 152.291,
#   'type': 'audio_features',
#   'id': '2eDKm1cwvnVGN4QufqdAJ1',
#   'uri': 'spotify:track:2eDKm1cwvnVGN4QufqdAJ1',
#   'track_href': 'https://api.spotify.com/v1/tracks/2eDKm1cwvnVGN4QufqdAJ1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2eDKm1cwvnVGN4QufqdAJ1',
#   'duration_ms': 218680,
#   'time_signature': 4},
#  {'danceability': 0.167,
#   'energy': 0.921,
#   'key': 6,
#   'loudness': -4.881,
#   'mode': 0,
#   'speechiness': 0.061,
#   'acousticness': 0.000141,
#   'instrumentalness': 0.0716,
#   'liveness': 0.239,
#   'valence': 0.315,
#   'tempo': 168.225,
#   'type': 'audio_features',
#   'id': '2YIOkqKgg3jZEFoL5qcEPT',
#   'uri': 'spotify:track:2YIOkqKgg3jZEFoL5qcEPT',
#   'track_href': 'https://api.spotify.com/v1/tracks/2YIOkqKgg3jZEFoL5qcEPT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2YIOkqKgg3jZEFoL5qcEPT',
#   'duration_ms': 262227,
#   'time_signature': 4},
#  {'danceability': 0.601,
#   'energy': 0.251,
#   'key': 0,
#   'loudness': -17.626,
#   'mode': 1,
#   'speechiness': 0.0348,
#   'acousticness': 0.118,
#   'instrumentalness': 0.104,
#   'liveness': 0.115,
#   'valence': 0.27,
#   'tempo': 116.49,
#   'type': 'audio_features',
#   'id': '6Q9kdCHXpAef5YbKXKeG9M',
#   'uri': 'spotify:track:6Q9kdCHXpAef5YbKXKeG9M',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Q9kdCHXpAef5YbKXKeG9M',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Q9kdCHXpAef5YbKXKeG9M',
#   'duration_ms': 232307,
#   'time_signature': 4},
#  {'danceability': 0.688,
#   'energy': 0.42,
#   'key': 11,
#   'loudness': -9.015,
#   'mode': 0,
#   'speechiness': 0.0446,
#   'acousticness': 0.723,
#   'instrumentalness': 0.626,
#   'liveness': 0.0734,
#   'valence': 0.624,
#   'tempo': 137.999,
#   'type': 'audio_features',
#   'id': '5oq5kmKIKbcJYLJXhBmmLh',
#   'uri': 'spotify:track:5oq5kmKIKbcJYLJXhBmmLh',
#   'track_href': 'https://api.spotify.com/v1/tracks/5oq5kmKIKbcJYLJXhBmmLh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5oq5kmKIKbcJYLJXhBmmLh',
#   'duration_ms': 427227,
#   'time_signature': 4},
#  {'danceability': 0.445,
#   'energy': 0.77,
#   'key': 6,
#   'loudness': -5.92,
#   'mode': 0,
#   'speechiness': 0.0345,
#   'acousticness': 0.0875,
#   'instrumentalness': 0.91,
#   'liveness': 0.854,
#   'valence': 0.202,
#   'tempo': 154.868,
#   'type': 'audio_features',
#   'id': '4nNSgSfqhtAQ9upuIp1QgM',
#   'uri': 'spotify:track:4nNSgSfqhtAQ9upuIp1QgM',
#   'track_href': 'https://api.spotify.com/v1/tracks/4nNSgSfqhtAQ9upuIp1QgM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4nNSgSfqhtAQ9upuIp1QgM',
#   'duration_ms': 315440,
#   'time_signature': 4},
#  {'danceability': 0.904,
#   'energy': 0.837,
#   'key': 10,
#   'loudness': -5.729,
#   'mode': 1,
#   'speechiness': 0.0394,
#   'acousticness': 0.241,
#   'instrumentalness': 0.453,
#   'liveness': 0.0901,
#   'valence': 0.809,
#   'tempo': 120.0,
#   'type': 'audio_features',
#   'id': '4dn65tI4IFeBE2EKcXXMMZ',
#   'uri': 'spotify:track:4dn65tI4IFeBE2EKcXXMMZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/4dn65tI4IFeBE2EKcXXMMZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4dn65tI4IFeBE2EKcXXMMZ',
#   'duration_ms': 286093,
#   'time_signature': 4},
#  {'danceability': 0.632,
#   'energy': 0.893,
#   'key': 7,
#   'loudness': -6.04,
#   'mode': 1,
#   'speechiness': 0.0455,
#   'acousticness': 0.0143,
#   'instrumentalness': 5.24e-06,
#   'liveness': 0.0741,
#   'valence': 0.773,
#   'tempo': 149.97,
#   'type': 'audio_features',
#   'id': '1XT5kxg6Tk0ukCO2vBQN4v',
#   'uri': 'spotify:track:1XT5kxg6Tk0ukCO2vBQN4v',
#   'track_href': 'https://api.spotify.com/v1/tracks/1XT5kxg6Tk0ukCO2vBQN4v',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1XT5kxg6Tk0ukCO2vBQN4v',
#   'duration_ms': 253800,
#   'time_signature': 4},
#  {'danceability': 0.895,
#   'energy': 0.569,
#   'key': 2,
#   'loudness': -7.142,
#   'mode': 1,
#   'speechiness': 0.0406,
#   'acousticness': 0.0375,
#   'instrumentalness': 9.45e-05,
#   'liveness': 0.0636,
#   'valence': 0.828,
#   'tempo': 110.003,
#   'type': 'audio_features',
#   'id': '4NWpGwfkWMlA7G2ZpFKDXZ',
#   'uri': 'spotify:track:4NWpGwfkWMlA7G2ZpFKDXZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/4NWpGwfkWMlA7G2ZpFKDXZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4NWpGwfkWMlA7G2ZpFKDXZ',
#   'duration_ms': 251381,
#   'time_signature': 4},
#  {'danceability': 0.66,
#   'energy': 0.641,
#   'key': 9,
#   'loudness': -8.658,
#   'mode': 0,
#   'speechiness': 0.035,
#   'acousticness': 0.533,
#   'instrumentalness': 0.0114,
#   'liveness': 0.0855,
#   'valence': 0.851,
#   'tempo': 139.735,
#   'type': 'audio_features',
#   'id': '4FeZm3qG8HwTJ5ggYrNVRp',
#   'uri': 'spotify:track:4FeZm3qG8HwTJ5ggYrNVRp',
#   'track_href': 'https://api.spotify.com/v1/tracks/4FeZm3qG8HwTJ5ggYrNVRp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4FeZm3qG8HwTJ5ggYrNVRp',
#   'duration_ms': 303413,
#   'time_signature': 4},
#  {'danceability': 0.796,
#   'energy': 0.653,
#   'key': 0,
#   'loudness': -8.154,
#   'mode': 0,
#   'speechiness': 0.107,
#   'acousticness': 0.288,
#   'instrumentalness': 0.0375,
#   'liveness': 0.0647,
#   'valence': 0.799,
#   'tempo': 100.06,
#   'type': 'audio_features',
#   'id': '4dDTgx0tUaSepOCONb9RrP',
#   'uri': 'spotify:track:4dDTgx0tUaSepOCONb9RrP',
#   'track_href': 'https://api.spotify.com/v1/tracks/4dDTgx0tUaSepOCONb9RrP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4dDTgx0tUaSepOCONb9RrP',
#   'duration_ms': 195120,
#   'time_signature': 4},
#  {'danceability': 0.697,
#   'energy': 0.607,
#   'key': 9,
#   'loudness': -9.771,
#   'mode': 1,
#   'speechiness': 0.0549,
#   'acousticness': 0.0984,
#   'instrumentalness': 0.139,
#   'liveness': 0.239,
#   'valence': 0.705,
#   'tempo': 112.141,
#   'type': 'audio_features',
#   'id': '7igDDKaYTMkV5xbse143IW',
#   'uri': 'spotify:track:7igDDKaYTMkV5xbse143IW',
#   'track_href': 'https://api.spotify.com/v1/tracks/7igDDKaYTMkV5xbse143IW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7igDDKaYTMkV5xbse143IW',
#   'duration_ms': 366067,
#   'time_signature': 4},
#  {'danceability': 0.701,
#   'energy': 0.86,
#   'key': 7,
#   'loudness': -6.727,
#   'mode': 0,
#   'speechiness': 0.0476,
#   'acousticness': 0.0101,
#   'instrumentalness': 8.95e-05,
#   'liveness': 0.278,
#   'valence': 0.709,
#   'tempo': 113.087,
#   'type': 'audio_features',
#   'id': '3fnvElSyFC2xCc20sYTP5N',
#   'uri': 'spotify:track:3fnvElSyFC2xCc20sYTP5N',
#   'track_href': 'https://api.spotify.com/v1/tracks/3fnvElSyFC2xCc20sYTP5N',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3fnvElSyFC2xCc20sYTP5N',
#   'duration_ms': 215200,
#   'time_signature': 4},
#  {'danceability': 0.67,
#   'energy': 0.452,
#   'key': 2,
#   'loudness': -9.628,
#   'mode': 1,
#   'speechiness': 0.03,
#   'acousticness': 0.444,
#   'instrumentalness': 0.876,
#   'liveness': 0.114,
#   'valence': 0.433,
#   'tempo': 119.094,
#   'type': 'audio_features',
#   'id': '5H9tBfhicddZB01lOVuD9q',
#   'uri': 'spotify:track:5H9tBfhicddZB01lOVuD9q',
#   'track_href': 'https://api.spotify.com/v1/tracks/5H9tBfhicddZB01lOVuD9q',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5H9tBfhicddZB01lOVuD9q',
#   'duration_ms': 265333,
#   'time_signature': 4},
#  {'danceability': 0.693,
#   'energy': 0.557,
#   'key': 7,
#   'loudness': -9.166,
#   'mode': 1,
#   'speechiness': 0.0435,
#   'acousticness': 0.00719,
#   'instrumentalness': 0.28,
#   'liveness': 0.0965,
#   'valence': 0.365,
#   'tempo': 112.399,
#   'type': 'audio_features',
#   'id': '3Y0O6CiCqe3iPfWCNXSnkq',
#   'uri': 'spotify:track:3Y0O6CiCqe3iPfWCNXSnkq',
#   'track_href': 'https://api.spotify.com/v1/tracks/3Y0O6CiCqe3iPfWCNXSnkq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Y0O6CiCqe3iPfWCNXSnkq',
#   'duration_ms': 349533,
#   'time_signature': 4},
#  {'danceability': 0.573,
#   'energy': 0.226,
#   'key': 2,
#   'loudness': -14.767,
#   'mode': 1,
#   'speechiness': 0.082,
#   'acousticness': 0.825,
#   'instrumentalness': 4.4e-06,
#   'liveness': 0.15,
#   'valence': 0.366,
#   'tempo': 131.692,
#   'type': 'audio_features',
#   'id': '6oI7lWaQ1jfjDduxYblGOo',
#   'uri': 'spotify:track:6oI7lWaQ1jfjDduxYblGOo',
#   'track_href': 'https://api.spotify.com/v1/tracks/6oI7lWaQ1jfjDduxYblGOo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6oI7lWaQ1jfjDduxYblGOo',
#   'duration_ms': 253853,
#   'time_signature': 4},
#  {'danceability': 0.46,
#   'energy': 0.624,
#   'key': 10,
#   'loudness': -9.409,
#   'mode': 0,
#   'speechiness': 0.039,
#   'acousticness': 0.196,
#   'instrumentalness': 0.015,
#   'liveness': 0.291,
#   'valence': 0.256,
#   'tempo': 96.111,
#   'type': 'audio_features',
#   'id': '06fcOVvKx9y2mY9PiGeKVQ',
#   'uri': 'spotify:track:06fcOVvKx9y2mY9PiGeKVQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/06fcOVvKx9y2mY9PiGeKVQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/06fcOVvKx9y2mY9PiGeKVQ',
#   'duration_ms': 259554,
#   'time_signature': 4},
#  {'danceability': 0.561,
#   'energy': 0.895,
#   'key': 2,
#   'loudness': -4.903,
#   'mode': 1,
#   'speechiness': 0.0529,
#   'acousticness': 0.766,
#   'instrumentalness': 0.67,
#   'liveness': 0.124,
#   'valence': 0.634,
#   'tempo': 86.808,
#   'type': 'audio_features',
#   'id': '0fDFzVTG8c2fW9EM5f1RHM',
#   'uri': 'spotify:track:0fDFzVTG8c2fW9EM5f1RHM',
#   'track_href': 'https://api.spotify.com/v1/tracks/0fDFzVTG8c2fW9EM5f1RHM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0fDFzVTG8c2fW9EM5f1RHM',
#   'duration_ms': 213786,
#   'time_signature': 4},
#  {'danceability': 0.519,
#   'energy': 0.74,
#   'key': 9,
#   'loudness': -7.7,
#   'mode': 0,
#   'speechiness': 0.0425,
#   'acousticness': 0.302,
#   'instrumentalness': 0.526,
#   'liveness': 0.385,
#   'valence': 0.479,
#   'tempo': 95.008,
#   'type': 'audio_features',
#   'id': '3knjH2NQ4OC9pgXnoHKkmh',
#   'uri': 'spotify:track:3knjH2NQ4OC9pgXnoHKkmh',
#   'track_href': 'https://api.spotify.com/v1/tracks/3knjH2NQ4OC9pgXnoHKkmh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3knjH2NQ4OC9pgXnoHKkmh',
#   'duration_ms': 304440,
#   'time_signature': 4},
#  {'danceability': 0.663,
#   'energy': 0.444,
#   'key': 11,
#   'loudness': -11.214,
#   'mode': 0,
#   'speechiness': 0.0338,
#   'acousticness': 0.274,
#   'instrumentalness': 0.664,
#   'liveness': 0.388,
#   'valence': 0.2,
#   'tempo': 122.975,
#   'type': 'audio_features',
#   'id': '3DZfp14PTnqbFToBnCztfW',
#   'uri': 'spotify:track:3DZfp14PTnqbFToBnCztfW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3DZfp14PTnqbFToBnCztfW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3DZfp14PTnqbFToBnCztfW',
#   'duration_ms': 240493,
#   'time_signature': 4},
#  {'danceability': 0.557,
#   'energy': 0.341,
#   'key': 9,
#   'loudness': -12.102,
#   'mode': 0,
#   'speechiness': 0.0344,
#   'acousticness': 0.939,
#   'instrumentalness': 0.00469,
#   'liveness': 0.412,
#   'valence': 0.229,
#   'tempo': 94.899,
#   'type': 'audio_features',
#   'id': '5Cjh9XUhSL4AA39p7y3qdP',
#   'uri': 'spotify:track:5Cjh9XUhSL4AA39p7y3qdP',
#   'track_href': 'https://api.spotify.com/v1/tracks/5Cjh9XUhSL4AA39p7y3qdP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Cjh9XUhSL4AA39p7y3qdP',
#   'duration_ms': 171893,
#   'time_signature': 4},
#  {'danceability': 0.598,
#   'energy': 0.657,
#   'key': 8,
#   'loudness': -7.466,
#   'mode': 1,
#   'speechiness': 0.0386,
#   'acousticness': 0.0328,
#   'instrumentalness': 2.72e-05,
#   'liveness': 0.172,
#   'valence': 0.194,
#   'tempo': 114.969,
#   'type': 'audio_features',
#   'id': '6JH2Z9YixSoQTgIoxx4w3P',
#   'uri': 'spotify:track:6JH2Z9YixSoQTgIoxx4w3P',
#   'track_href': 'https://api.spotify.com/v1/tracks/6JH2Z9YixSoQTgIoxx4w3P',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6JH2Z9YixSoQTgIoxx4w3P',
#   'duration_ms': 260400,
#   'time_signature': 4},
#  {'danceability': 0.677,
#   'energy': 0.61,
#   'key': 4,
#   'loudness': -4.124,
#   'mode': 0,
#   'speechiness': 0.0278,
#   'acousticness': 0.061,
#   'instrumentalness': 0.0823,
#   'liveness': 0.0903,
#   'valence': 0.638,
#   'tempo': 99.975,
#   'type': 'audio_features',
#   'id': '2sHshROvRicHcj3pnXeovj',
#   'uri': 'spotify:track:2sHshROvRicHcj3pnXeovj',
#   'track_href': 'https://api.spotify.com/v1/tracks/2sHshROvRicHcj3pnXeovj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2sHshROvRicHcj3pnXeovj',
#   'duration_ms': 327368,
#   'time_signature': 4},
#  {'danceability': 0.613,
#   'energy': 0.77,
#   'key': 7,
#   'loudness': -10.304,
#   'mode': 0,
#   'speechiness': 0.0353,
#   'acousticness': 0.0542,
#   'instrumentalness': 0.0135,
#   'liveness': 0.608,
#   'valence': 0.691,
#   'tempo': 107.023,
#   'type': 'audio_features',
#   'id': '1w7WAOQ65UjKpwhqB5rTNl',
#   'uri': 'spotify:track:1w7WAOQ65UjKpwhqB5rTNl',
#   'track_href': 'https://api.spotify.com/v1/tracks/1w7WAOQ65UjKpwhqB5rTNl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1w7WAOQ65UjKpwhqB5rTNl',
#   'duration_ms': 259067,
#   'time_signature': 4},
#  {'danceability': 0.63,
#   'energy': 0.801,
#   'key': 0,
#   'loudness': -6.434,
#   'mode': 0,
#   'speechiness': 0.0266,
#   'acousticness': 0.0683,
#   'instrumentalness': 0.135,
#   'liveness': 0.13,
#   'valence': 0.317,
#   'tempo': 103.713,
#   'type': 'audio_features',
#   'id': '1I1IBDfNijHmOjYSCErerM',
#   'uri': 'spotify:track:1I1IBDfNijHmOjYSCErerM',
#   'track_href': 'https://api.spotify.com/v1/tracks/1I1IBDfNijHmOjYSCErerM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1I1IBDfNijHmOjYSCErerM',
#   'duration_ms': 212842,
#   'time_signature': 4},
#  {'danceability': 0.623,
#   'energy': 0.739,
#   'key': 7,
#   'loudness': -8.116,
#   'mode': 1,
#   'speechiness': 0.0244,
#   'acousticness': 0.338,
#   'instrumentalness': 1.88e-05,
#   'liveness': 0.109,
#   'valence': 0.642,
#   'tempo': 95.007,
#   'type': 'audio_features',
#   'id': '5lwQGZYF4BXOzFtXc5zk8q',
#   'uri': 'spotify:track:5lwQGZYF4BXOzFtXc5zk8q',
#   'track_href': 'https://api.spotify.com/v1/tracks/5lwQGZYF4BXOzFtXc5zk8q',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5lwQGZYF4BXOzFtXc5zk8q',
#   'duration_ms': 257316,
#   'time_signature': 4},
#  {'danceability': 0.496,
#   'energy': 0.738,
#   'key': 2,
#   'loudness': -6.773,
#   'mode': 0,
#   'speechiness': 0.124,
#   'acousticness': 0.0301,
#   'instrumentalness': 0,
#   'liveness': 0.132,
#   'valence': 0.634,
#   'tempo': 90.571,
#   'type': 'audio_features',
#   'id': '6Bqa0hj0zakKc7gR601Cnn',
#   'uri': 'spotify:track:6Bqa0hj0zakKc7gR601Cnn',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Bqa0hj0zakKc7gR601Cnn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Bqa0hj0zakKc7gR601Cnn',
#   'duration_ms': 160427,
#   'time_signature': 4},
#  {'danceability': 0.693,
#   'energy': 0.678,
#   'key': 6,
#   'loudness': -6.914,
#   'mode': 0,
#   'speechiness': 0.035,
#   'acousticness': 0.00981,
#   'instrumentalness': 0.0924,
#   'liveness': 0.162,
#   'valence': 0.776,
#   'tempo': 96.981,
#   'type': 'audio_features',
#   'id': '6GEIpzW14NtOjqHejbcSRE',
#   'uri': 'spotify:track:6GEIpzW14NtOjqHejbcSRE',
#   'track_href': 'https://api.spotify.com/v1/tracks/6GEIpzW14NtOjqHejbcSRE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6GEIpzW14NtOjqHejbcSRE',
#   'duration_ms': 225306,
#   'time_signature': 4},
#  {'danceability': 0.528,
#   'energy': 0.342,
#   'key': 10,
#   'loudness': -9.782,
#   'mode': 0,
#   'speechiness': 0.0253,
#   'acousticness': 0.914,
#   'instrumentalness': 0.476,
#   'liveness': 0.115,
#   'valence': 0.135,
#   'tempo': 73.924,
#   'type': 'audio_features',
#   'id': '31G7lCtzXKRZmf5wbkL1HC',
#   'uri': 'spotify:track:31G7lCtzXKRZmf5wbkL1HC',
#   'track_href': 'https://api.spotify.com/v1/tracks/31G7lCtzXKRZmf5wbkL1HC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/31G7lCtzXKRZmf5wbkL1HC',
#   'duration_ms': 308480,
#   'time_signature': 4},
#  {'danceability': 0.499,
#   'energy': 0.516,
#   'key': 9,
#   'loudness': -10.846,
#   'mode': 1,
#   'speechiness': 0.028,
#   'acousticness': 0.185,
#   'instrumentalness': 0.0215,
#   'liveness': 0.11,
#   'valence': 0.485,
#   'tempo': 149.886,
#   'type': 'audio_features',
#   'id': '2kkX9IzielZhUBybezdE0m',
#   'uri': 'spotify:track:2kkX9IzielZhUBybezdE0m',
#   'track_href': 'https://api.spotify.com/v1/tracks/2kkX9IzielZhUBybezdE0m',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2kkX9IzielZhUBybezdE0m',
#   'duration_ms': 325427,
#   'time_signature': 4},
#  {'danceability': 0.542,
#   'energy': 0.744,
#   'key': 0,
#   'loudness': -6.836,
#   'mode': 0,
#   'speechiness': 0.028,
#   'acousticness': 0.126,
#   'instrumentalness': 0.0155,
#   'liveness': 0.157,
#   'valence': 0.546,
#   'tempo': 142.065,
#   'type': 'audio_features',
#   'id': '6Yl9Q888fSayfD5YngBD1m',
#   'uri': 'spotify:track:6Yl9Q888fSayfD5YngBD1m',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Yl9Q888fSayfD5YngBD1m',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Yl9Q888fSayfD5YngBD1m',
#   'duration_ms': 334333,
#   'time_signature': 4},
#  {'danceability': 0.485,
#   'energy': 0.904,
#   'key': 8,
#   'loudness': -3.48,
#   'mode': 0,
#   'speechiness': 0.0465,
#   'acousticness': 0.000775,
#   'instrumentalness': 0,
#   'liveness': 0.182,
#   'valence': 0.898,
#   'tempo': 92.067,
#   'type': 'audio_features',
#   'id': '1EXMtjti643XyQLiGDdki0',
#   'uri': 'spotify:track:1EXMtjti643XyQLiGDdki0',
#   'track_href': 'https://api.spotify.com/v1/tracks/1EXMtjti643XyQLiGDdki0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1EXMtjti643XyQLiGDdki0',
#   'duration_ms': 287136,
#   'time_signature': 4},
#  {'danceability': 0.63,
#   'energy': 0.799,
#   'key': 5,
#   'loudness': -8.11,
#   'mode': 1,
#   'speechiness': 0.0701,
#   'acousticness': 0.00345,
#   'instrumentalness': 0.305,
#   'liveness': 0.109,
#   'valence': 0.843,
#   'tempo': 115.251,
#   'type': 'audio_features',
#   'id': '7HbwnIlS0PIGHUackivPQs',
#   'uri': 'spotify:track:7HbwnIlS0PIGHUackivPQs',
#   'track_href': 'https://api.spotify.com/v1/tracks/7HbwnIlS0PIGHUackivPQs',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7HbwnIlS0PIGHUackivPQs',
#   'duration_ms': 180093,
#   'time_signature': 4},
#  {'danceability': 0.472,
#   'energy': 0.653,
#   'key': 3,
#   'loudness': -6.484,
#   'mode': 1,
#   'speechiness': 0.0338,
#   'acousticness': 0.0435,
#   'instrumentalness': 0.075,
#   'liveness': 0.299,
#   'valence': 0.525,
#   'tempo': 139.887,
#   'type': 'audio_features',
#   'id': '1g367bU5GiVMgAU2aW37d2',
#   'uri': 'spotify:track:1g367bU5GiVMgAU2aW37d2',
#   'track_href': 'https://api.spotify.com/v1/tracks/1g367bU5GiVMgAU2aW37d2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1g367bU5GiVMgAU2aW37d2',
#   'duration_ms': 267789,
#   'time_signature': 4},
#  {'danceability': 0.593,
#   'energy': 0.511,
#   'key': 7,
#   'loudness': -8.391,
#   'mode': 0,
#   'speechiness': 0.0373,
#   'acousticness': 0.595,
#   'instrumentalness': 0.00139,
#   'liveness': 0.113,
#   'valence': 0.569,
#   'tempo': 139.906,
#   'type': 'audio_features',
#   'id': '1mJD7hr3BRIpo7uJdZ8NHz',
#   'uri': 'spotify:track:1mJD7hr3BRIpo7uJdZ8NHz',
#   'track_href': 'https://api.spotify.com/v1/tracks/1mJD7hr3BRIpo7uJdZ8NHz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1mJD7hr3BRIpo7uJdZ8NHz',
#   'duration_ms': 204893,
#   'time_signature': 4},
#  {'danceability': 0.829,
#   'energy': 0.435,
#   'key': 0,
#   'loudness': -10.136,
#   'mode': 1,
#   'speechiness': 0.0515,
#   'acousticness': 0.0363,
#   'instrumentalness': 0.881,
#   'liveness': 0.119,
#   'valence': 0.594,
#   'tempo': 103.817,
#   'type': 'audio_features',
#   'id': '3DXHaJzqRCgv3rd5U9EoXU',
#   'uri': 'spotify:track:3DXHaJzqRCgv3rd5U9EoXU',
#   'track_href': 'https://api.spotify.com/v1/tracks/3DXHaJzqRCgv3rd5U9EoXU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3DXHaJzqRCgv3rd5U9EoXU',
#   'duration_ms': 230147,
#   'time_signature': 4},
#  {'danceability': 0.752,
#   'energy': 0.844,
#   'key': 9,
#   'loudness': -8.705,
#   'mode': 1,
#   'speechiness': 0.0398,
#   'acousticness': 0.0462,
#   'instrumentalness': 0.131,
#   'liveness': 0.0782,
#   'valence': 0.78,
#   'tempo': 124.013,
#   'type': 'audio_features',
#   'id': '5gmv3BgePSYiHnPJgY7oTJ',
#   'uri': 'spotify:track:5gmv3BgePSYiHnPJgY7oTJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/5gmv3BgePSYiHnPJgY7oTJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5gmv3BgePSYiHnPJgY7oTJ',
#   'duration_ms': 473333,
#   'time_signature': 4},
#  {'danceability': 0.814,
#   'energy': 0.493,
#   'key': 0,
#   'loudness': -6.767,
#   'mode': 1,
#   'speechiness': 0.205,
#   'acousticness': 0.818,
#   'instrumentalness': 0,
#   'liveness': 0.195,
#   'valence': 0.931,
#   'tempo': 87.777,
#   'type': 'audio_features',
#   'id': '5N5NEi5Xoa6lMTSzWtVQTC',
#   'uri': 'spotify:track:5N5NEi5Xoa6lMTSzWtVQTC',
#   'track_href': 'https://api.spotify.com/v1/tracks/5N5NEi5Xoa6lMTSzWtVQTC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5N5NEi5Xoa6lMTSzWtVQTC',
#   'duration_ms': 120293,
#   'time_signature': 4},
#  {'danceability': 0.649,
#   'energy': 0.404,
#   'key': 0,
#   'loudness': -10.454,
#   'mode': 1,
#   'speechiness': 0.0311,
#   'acousticness': 0.789,
#   'instrumentalness': 0.000962,
#   'liveness': 0.0794,
#   'valence': 0.277,
#   'tempo': 111.563,
#   'type': 'audio_features',
#   'id': '2MzuBHUg1YLezoTZqfBfVl',
#   'uri': 'spotify:track:2MzuBHUg1YLezoTZqfBfVl',
#   'track_href': 'https://api.spotify.com/v1/tracks/2MzuBHUg1YLezoTZqfBfVl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2MzuBHUg1YLezoTZqfBfVl',
#   'duration_ms': 241646,
#   'time_signature': 4},
#  {'danceability': 0.64,
#   'energy': 0.668,
#   'key': 11,
#   'loudness': -7.025,
#   'mode': 0,
#   'speechiness': 0.0317,
#   'acousticness': 0.3,
#   'instrumentalness': 0.031,
#   'liveness': 0.312,
#   'valence': 0.737,
#   'tempo': 94.963,
#   'type': 'audio_features',
#   'id': '4XNska8wDJLpjbvXNebs5C',
#   'uri': 'spotify:track:4XNska8wDJLpjbvXNebs5C',
# ...
#   'loudness': -8.34,
#   'mode': 1,
#   'speechiness': 0.0465,
#   'acousticness': 0.000252,
#   'instrumentalness': 0.163,
#   'liveness': 0.0842,
#   'valence': 0.368,
#   'tempo': 120.195,
#   'type': 'audio_features',
#   'id': '2OtXVC8bMtf9uO7cDCNoCr',
#   'uri': 'spotify:track:2OtXVC8bMtf9uO7cDCNoCr',
#   'track_href': 'https://api.spotify.com/v1/tracks/2OtXVC8bMtf9uO7cDCNoCr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2OtXVC8bMtf9uO7cDCNoCr',
#   'duration_ms': 206960,
#   'time_signature': 4},
#  {'danceability': 0.659,
#   'energy': 0.929,
#   'key': 8,
#   'loudness': -8.047,
#   'mode': 1,
#   'speechiness': 0.0494,
#   'acousticness': 0.0224,
#   'instrumentalness': 0.627,
#   'liveness': 0.567,
#   'valence': 0.0374,
#   'tempo': 118.495,
#   'type': 'audio_features',
#   'id': '2z0nkZLzKp1IbZzdQCaD6Z',
#   'uri': 'spotify:track:2z0nkZLzKp1IbZzdQCaD6Z',
#   'track_href': 'https://api.spotify.com/v1/tracks/2z0nkZLzKp1IbZzdQCaD6Z',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2z0nkZLzKp1IbZzdQCaD6Z',
#   'duration_ms': 401253,
#   'time_signature': 4},
#  {'danceability': 0.445,
#   'energy': 0.75,
#   'key': 6,
#   'loudness': -7.159,
#   'mode': 1,
#   'speechiness': 0.035,
#   'acousticness': 0.00805,
#   'instrumentalness': 0,
#   'liveness': 0.0358,
#   'valence': 0.466,
#   'tempo': 95.957,
#   'type': 'audio_features',
#   'id': '4zoZQvmST8gliv9S9L8lUw',
#   'uri': 'spotify:track:4zoZQvmST8gliv9S9L8lUw',
#   'track_href': 'https://api.spotify.com/v1/tracks/4zoZQvmST8gliv9S9L8lUw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4zoZQvmST8gliv9S9L8lUw',
#   'duration_ms': 230440,
#   'time_signature': 4},
#  {'danceability': 0.566,
#   'energy': 0.294,
#   'key': 4,
#   'loudness': -10.89,
#   'mode': 0,
#   'speechiness': 0.0394,
#   'acousticness': 0.391,
#   'instrumentalness': 2.61e-05,
#   'liveness': 0.103,
#   'valence': 0.372,
#   'tempo': 113.542,
#   'type': 'audio_features',
#   'id': '0rexlITgOonNpN9XjcgyRR',
#   'uri': 'spotify:track:0rexlITgOonNpN9XjcgyRR',
#   'track_href': 'https://api.spotify.com/v1/tracks/0rexlITgOonNpN9XjcgyRR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0rexlITgOonNpN9XjcgyRR',
#   'duration_ms': 168253,
#   'time_signature': 4},
#  {'danceability': 0.654,
#   'energy': 0.577,
#   'key': 0,
#   'loudness': -8.217,
#   'mode': 0,
#   'speechiness': 0.0285,
#   'acousticness': 0.0506,
#   'instrumentalness': 0.0499,
#   'liveness': 0.481,
#   'valence': 0.657,
#   'tempo': 116.903,
#   'type': 'audio_features',
#   'id': '43o7PowhXdkjBlaGC6GIfg',
#   'uri': 'spotify:track:43o7PowhXdkjBlaGC6GIfg',
#   'track_href': 'https://api.spotify.com/v1/tracks/43o7PowhXdkjBlaGC6GIfg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/43o7PowhXdkjBlaGC6GIfg',
#   'duration_ms': 322000,
#   'time_signature': 4},
#  {'danceability': 0.56,
#   'energy': 0.279,
#   'key': 2,
#   'loudness': -11.137,
#   'mode': 1,
#   'speechiness': 0.0301,
#   'acousticness': 0.105,
#   'instrumentalness': 0.303,
#   'liveness': 0.144,
#   'valence': 0.122,
#   'tempo': 104.69,
#   'type': 'audio_features',
#   'id': '6xtVGRGXzAEIIMrpQDoYFW',
#   'uri': 'spotify:track:6xtVGRGXzAEIIMrpQDoYFW',
#   'track_href': 'https://api.spotify.com/v1/tracks/6xtVGRGXzAEIIMrpQDoYFW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6xtVGRGXzAEIIMrpQDoYFW',
#   'duration_ms': 305373,
#   'time_signature': 4},
#  {'danceability': 0.666,
#   'energy': 0.956,
#   'key': 9,
#   'loudness': -4.392,
#   'mode': 0,
#   'speechiness': 0.195,
#   'acousticness': 0.472,
#   'instrumentalness': 0.021,
#   'liveness': 0.0459,
#   'valence': 0.463,
#   'tempo': 72.29,
#   'type': 'audio_features',
#   'id': '50MNCojhSwCd4QkJ7O80E5',
#   'uri': 'spotify:track:50MNCojhSwCd4QkJ7O80E5',
#   'track_href': 'https://api.spotify.com/v1/tracks/50MNCojhSwCd4QkJ7O80E5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/50MNCojhSwCd4QkJ7O80E5',
#   'duration_ms': 216840,
#   'time_signature': 4},
#  {'danceability': 0.622,
#   'energy': 0.448,
#   'key': 0,
#   'loudness': -10.709,
#   'mode': 1,
#   'speechiness': 0.0265,
#   'acousticness': 0.23,
#   'instrumentalness': 0,
#   'liveness': 0.102,
#   'valence': 0.553,
#   'tempo': 106.085,
#   'type': 'audio_features',
#   'id': '6JuEshIRliNXRU1LXctRjZ',
#   'uri': 'spotify:track:6JuEshIRliNXRU1LXctRjZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6JuEshIRliNXRU1LXctRjZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6JuEshIRliNXRU1LXctRjZ',
#   'duration_ms': 196227,
#   'time_signature': 4},
#  {'danceability': 0.63,
#   'energy': 0.249,
#   'key': 9,
#   'loudness': -12.935,
#   'mode': 1,
#   'speechiness': 0.0357,
#   'acousticness': 0.886,
#   'instrumentalness': 4.92e-05,
#   'liveness': 0.0821,
#   'valence': 0.359,
#   'tempo': 110.246,
#   'type': 'audio_features',
#   'id': '0xTggtP2weZNXgY7s0dh2b',
#   'uri': 'spotify:track:0xTggtP2weZNXgY7s0dh2b',
#   'track_href': 'https://api.spotify.com/v1/tracks/0xTggtP2weZNXgY7s0dh2b',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0xTggtP2weZNXgY7s0dh2b',
#   'duration_ms': 269600,
#   'time_signature': 4},
#  {'danceability': 0.794,
#   'energy': 0.32,
#   'key': 1,
#   'loudness': -12.92,
#   'mode': 0,
#   'speechiness': 0.173,
#   'acousticness': 0.853,
#   'instrumentalness': 0.134,
#   'liveness': 0.112,
#   'valence': 0.241,
#   'tempo': 174.088,
#   'type': 'audio_features',
#   'id': '1DWZUa5Mzf2BwzpHtgbHPY',
#   'uri': 'spotify:track:1DWZUa5Mzf2BwzpHtgbHPY',
#   'track_href': 'https://api.spotify.com/v1/tracks/1DWZUa5Mzf2BwzpHtgbHPY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1DWZUa5Mzf2BwzpHtgbHPY',
#   'duration_ms': 342040,
#   'time_signature': 4},
#  {'danceability': 0.806,
#   'energy': 0.78,
#   'key': 8,
#   'loudness': -7.407,
#   'mode': 1,
#   'speechiness': 0.0397,
#   'acousticness': 0.000269,
#   'instrumentalness': 0.795,
#   'liveness': 0.0961,
#   'valence': 0.317,
#   'tempo': 119.998,
#   'type': 'audio_features',
#   'id': '7BUpmFlSMGK5COcnhVmsvH',
#   'uri': 'spotify:track:7BUpmFlSMGK5COcnhVmsvH',
#   'track_href': 'https://api.spotify.com/v1/tracks/7BUpmFlSMGK5COcnhVmsvH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7BUpmFlSMGK5COcnhVmsvH',
#   'duration_ms': 425107,
#   'time_signature': 4},
#  {'danceability': 0.662,
#   'energy': 0.828,
#   'key': 11,
#   'loudness': -8.748,
#   'mode': 0,
#   'speechiness': 0.0327,
#   'acousticness': 0.02,
#   'instrumentalness': 8.49e-05,
#   'liveness': 0.264,
#   'valence': 0.402,
#   'tempo': 143.916,
#   'type': 'audio_features',
#   'id': '7FMG6KTqNPzTnPTDiMfyJs',
#   'uri': 'spotify:track:7FMG6KTqNPzTnPTDiMfyJs',
#   'track_href': 'https://api.spotify.com/v1/tracks/7FMG6KTqNPzTnPTDiMfyJs',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7FMG6KTqNPzTnPTDiMfyJs',
#   'duration_ms': 282373,
#   'time_signature': 4},
#  {'danceability': 0.37,
#   'energy': 0.467,
#   'key': 5,
#   'loudness': -9.013,
#   'mode': 1,
#   'speechiness': 0.0273,
#   'acousticness': 0.0205,
#   'instrumentalness': 0.572,
#   'liveness': 0.109,
#   'valence': 0.182,
#   'tempo': 94.485,
#   'type': 'audio_features',
#   'id': '0yc6Gst2xkRu0eMLeRMGCX',
#   'uri': 'spotify:track:0yc6Gst2xkRu0eMLeRMGCX',
#   'track_href': 'https://api.spotify.com/v1/tracks/0yc6Gst2xkRu0eMLeRMGCX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0yc6Gst2xkRu0eMLeRMGCX',
#   'duration_ms': 290617,
#   'time_signature': 4},
#  {'danceability': 0.261,
#   'energy': 0.541,
#   'key': 11,
#   'loudness': -5.349,
#   'mode': 1,
#   'speechiness': 0.0343,
#   'acousticness': 0.47,
#   'instrumentalness': 2.89e-06,
#   'liveness': 0.37,
#   'valence': 0.243,
#   'tempo': 169.173,
#   'type': 'audio_features',
#   'id': '5JhPo3rh5KOm859EpDXCdc',
#   'uri': 'spotify:track:5JhPo3rh5KOm859EpDXCdc',
#   'track_href': 'https://api.spotify.com/v1/tracks/5JhPo3rh5KOm859EpDXCdc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5JhPo3rh5KOm859EpDXCdc',
#   'duration_ms': 268493,
#   'time_signature': 4},
#  {'danceability': 0.552,
#   'energy': 0.634,
#   'key': 1,
#   'loudness': -8.302,
#   'mode': 0,
#   'speechiness': 0.0261,
#   'acousticness': 0.00994,
#   'instrumentalness': 0.202,
#   'liveness': 0.0798,
#   'valence': 0.213,
#   'tempo': 76.557,
#   'type': 'audio_features',
#   'id': '3kQfBtkQqgN1fAMfhks8TU',
#   'uri': 'spotify:track:3kQfBtkQqgN1fAMfhks8TU',
#   'track_href': 'https://api.spotify.com/v1/tracks/3kQfBtkQqgN1fAMfhks8TU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3kQfBtkQqgN1fAMfhks8TU',
#   'duration_ms': 191797,
#   'time_signature': 4},
#  {'danceability': 0.787,
#   'energy': 0.771,
#   'key': 5,
#   'loudness': -7.757,
#   'mode': 0,
#   'speechiness': 0.0382,
#   'acousticness': 0.115,
#   'instrumentalness': 0.203,
#   'liveness': 0.0328,
#   'valence': 0.942,
#   'tempo': 127.96,
#   'type': 'audio_features',
#   'id': '74XTnXmhiAnFU2uJvgwaem',
#   'uri': 'spotify:track:74XTnXmhiAnFU2uJvgwaem',
#   'track_href': 'https://api.spotify.com/v1/tracks/74XTnXmhiAnFU2uJvgwaem',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/74XTnXmhiAnFU2uJvgwaem',
#   'duration_ms': 239082,
#   'time_signature': 4},
#  {'danceability': 0.561,
#   'energy': 0.871,
#   'key': 10,
#   'loudness': -4.5,
#   'mode': 1,
#   'speechiness': 0.0531,
#   'acousticness': 0.0149,
#   'instrumentalness': 0.000443,
#   'liveness': 0.0694,
#   'valence': 0.539,
#   'tempo': 141.638,
#   'type': 'audio_features',
#   'id': '3FjYAj4hg5KiXpVAMjpLKq',
#   'uri': 'spotify:track:3FjYAj4hg5KiXpVAMjpLKq',
#   'track_href': 'https://api.spotify.com/v1/tracks/3FjYAj4hg5KiXpVAMjpLKq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3FjYAj4hg5KiXpVAMjpLKq',
#   'duration_ms': 297067,
#   'time_signature': 4},
#  {'danceability': 0.799,
#   'energy': 0.887,
#   'key': 2,
#   'loudness': -5.775,
#   'mode': 1,
#   'speechiness': 0.0411,
#   'acousticness': 0.08,
#   'instrumentalness': 9.58e-05,
#   'liveness': 0.0975,
#   'valence': 0.9,
#   'tempo': 108.919,
#   'type': 'audio_features',
#   'id': '2z1uVu3OwTmPlfqt5TWk5k',
#   'uri': 'spotify:track:2z1uVu3OwTmPlfqt5TWk5k',
#   'track_href': 'https://api.spotify.com/v1/tracks/2z1uVu3OwTmPlfqt5TWk5k',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2z1uVu3OwTmPlfqt5TWk5k',
#   'duration_ms': 243600,
#   'time_signature': 4},
#  {'danceability': 0.353,
#   'energy': 0.898,
#   'key': 2,
#   'loudness': -5.877,
#   'mode': 1,
#   'speechiness': 0.052,
#   'acousticness': 2.23e-05,
#   'instrumentalness': 0.105,
#   'liveness': 0.39,
#   'valence': 0.525,
#   'tempo': 103.293,
#   'type': 'audio_features',
#   'id': '6W21LNLz9Sw7sUSNWMSHRu',
#   'uri': 'spotify:track:6W21LNLz9Sw7sUSNWMSHRu',
#   'track_href': 'https://api.spotify.com/v1/tracks/6W21LNLz9Sw7sUSNWMSHRu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6W21LNLz9Sw7sUSNWMSHRu',
#   'duration_ms': 255733,
#   'time_signature': 4},
#  {'danceability': 0.221,
#   'energy': 0.826,
#   'key': 1,
#   'loudness': -6.266,
#   'mode': 1,
#   'speechiness': 0.195,
#   'acousticness': 0.0163,
#   'instrumentalness': 0.00159,
#   'liveness': 0.104,
#   'valence': 0.157,
#   'tempo': 82.95,
#   'type': 'audio_features',
#   'id': '11DMBFTwnjRlLlvBfc0d10',
#   'uri': 'spotify:track:11DMBFTwnjRlLlvBfc0d10',
#   'track_href': 'https://api.spotify.com/v1/tracks/11DMBFTwnjRlLlvBfc0d10',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/11DMBFTwnjRlLlvBfc0d10',
#   'duration_ms': 149521,
#   'time_signature': 4},
#  {'danceability': 0.808,
#   'energy': 0.544,
#   'key': 5,
#   'loudness': -7.022,
#   'mode': 1,
#   'speechiness': 0.0672,
#   'acousticness': 0.557,
#   'instrumentalness': 2.03e-05,
#   'liveness': 0.0796,
#   'valence': 0.758,
#   'tempo': 115.01,
#   'type': 'audio_features',
#   'id': '0jhDyfdBiRfMi3jh9z2S0U',
#   'uri': 'spotify:track:0jhDyfdBiRfMi3jh9z2S0U',
#   'track_href': 'https://api.spotify.com/v1/tracks/0jhDyfdBiRfMi3jh9z2S0U',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0jhDyfdBiRfMi3jh9z2S0U',
#   'duration_ms': 225160,
#   'time_signature': 4},
#  {'danceability': 0.269,
#   'energy': 0.895,
#   'key': 9,
#   'loudness': -6.382,
#   'mode': 1,
#   'speechiness': 0.118,
#   'acousticness': 0.083,
#   'instrumentalness': 0.00266,
#   'liveness': 0.153,
#   'valence': 0.16,
#   'tempo': 168.479,
#   'type': 'audio_features',
#   'id': '02lTDOxHeXTHsdwXoz6lpC',
#   'uri': 'spotify:track:02lTDOxHeXTHsdwXoz6lpC',
#   'track_href': 'https://api.spotify.com/v1/tracks/02lTDOxHeXTHsdwXoz6lpC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/02lTDOxHeXTHsdwXoz6lpC',
#   'duration_ms': 299507,
#   'time_signature': 4},
#  {'danceability': 0.491,
#   'energy': 0.87,
#   'key': 0,
#   'loudness': -5.138,
#   'mode': 1,
#   'speechiness': 0.0393,
#   'acousticness': 0.000141,
#   'instrumentalness': 0.000729,
#   'liveness': 0.368,
#   'valence': 0.314,
#   'tempo': 131.989,
#   'type': 'audio_features',
#   'id': '3EwTIu5qka2l5ZekB0b6QC',
#   'uri': 'spotify:track:3EwTIu5qka2l5ZekB0b6QC',
#   'track_href': 'https://api.spotify.com/v1/tracks/3EwTIu5qka2l5ZekB0b6QC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3EwTIu5qka2l5ZekB0b6QC',
#   'duration_ms': 232320,
#   'time_signature': 4},
#  {'danceability': 0.467,
#   'energy': 0.757,
#   'key': 3,
#   'loudness': -5.093,
#   'mode': 1,
#   'speechiness': 0.033,
#   'acousticness': 0.0807,
#   'instrumentalness': 0.908,
#   'liveness': 0.0876,
#   'valence': 0.433,
#   'tempo': 82.282,
#   'type': 'audio_features',
#   'id': '11iIikXxC6NP0Ma8vMD27x',
#   'uri': 'spotify:track:11iIikXxC6NP0Ma8vMD27x',
#   'track_href': 'https://api.spotify.com/v1/tracks/11iIikXxC6NP0Ma8vMD27x',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/11iIikXxC6NP0Ma8vMD27x',
#   'duration_ms': 155933,
#   'time_signature': 4},
#  {'danceability': 0.744,
#   'energy': 0.831,
#   'key': 7,
#   'loudness': -6.004,
#   'mode': 0,
#   'speechiness': 0.03,
#   'acousticness': 0.025,
#   'instrumentalness': 0.000236,
#   'liveness': 0.0728,
#   'valence': 0.702,
#   'tempo': 129.968,
#   'type': 'audio_features',
#   'id': '0aWhxzFrP2Yyz3CetJe0xE',
#   'uri': 'spotify:track:0aWhxzFrP2Yyz3CetJe0xE',
#   'track_href': 'https://api.spotify.com/v1/tracks/0aWhxzFrP2Yyz3CetJe0xE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0aWhxzFrP2Yyz3CetJe0xE',
#   'duration_ms': 228066,
#   'time_signature': 4},
#  {'danceability': 0.609,
#   'energy': 0.797,
#   'key': 1,
#   'loudness': -5.945,
#   'mode': 0,
#   'speechiness': 0.0361,
#   'acousticness': 0.0244,
#   'instrumentalness': 0.345,
#   'liveness': 0.443,
#   'valence': 0.546,
#   'tempo': 120.039,
#   'type': 'audio_features',
#   'id': '5yzqu20ssqs9ric3fHO74I',
#   'uri': 'spotify:track:5yzqu20ssqs9ric3fHO74I',
#   'track_href': 'https://api.spotify.com/v1/tracks/5yzqu20ssqs9ric3fHO74I',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5yzqu20ssqs9ric3fHO74I',
#   'duration_ms': 216674,
#   'time_signature': 4},
#  {'danceability': 0.594,
#   'energy': 0.608,
#   'key': 1,
#   'loudness': -8.93,
#   'mode': 1,
#   'speechiness': 0.041,
#   'acousticness': 0.0259,
#   'instrumentalness': 0.122,
#   'liveness': 0.156,
#   'valence': 0.639,
#   'tempo': 169.969,
#   'type': 'audio_features',
#   'id': '2j5AyPkjugfvw0HWrK1Wvr',
#   'uri': 'spotify:track:2j5AyPkjugfvw0HWrK1Wvr',
#   'track_href': 'https://api.spotify.com/v1/tracks/2j5AyPkjugfvw0HWrK1Wvr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2j5AyPkjugfvw0HWrK1Wvr',
#   'duration_ms': 141503,
#   'time_signature': 4},
#  {'danceability': 0.811,
#   'energy': 0.452,
#   'key': 7,
#   'loudness': -8.676,
#   'mode': 1,
#   'speechiness': 0.115,
#   'acousticness': 0.162,
#   'instrumentalness': 0.00305,
#   'liveness': 0.12,
#   'valence': 0.556,
#   'tempo': 121.058,
#   'type': 'audio_features',
#   'id': '0BWBqb5XxraObLopqskk6D',
#   'uri': 'spotify:track:0BWBqb5XxraObLopqskk6D',
#   'track_href': 'https://api.spotify.com/v1/tracks/0BWBqb5XxraObLopqskk6D',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0BWBqb5XxraObLopqskk6D',
#   'duration_ms': 199006,
#   'time_signature': 4},
#  {'danceability': 0.782,
#   'energy': 0.716,
#   'key': 4,
#   'loudness': -6.113,
#   'mode': 0,
#   'speechiness': 0.199,
#   'acousticness': 0.219,
#   'instrumentalness': 0,
#   'liveness': 0.0749,
#   'valence': 0.85,
#   'tempo': 94.01,
#   'type': 'audio_features',
#   'id': '1ifVrAQPH2DZ3FBFu48rFw',
#   'uri': 'spotify:track:1ifVrAQPH2DZ3FBFu48rFw',
#   'track_href': 'https://api.spotify.com/v1/tracks/1ifVrAQPH2DZ3FBFu48rFw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1ifVrAQPH2DZ3FBFu48rFw',
#   'duration_ms': 181290,
#   'time_signature': 4}]

# %% [markdown]
# #### 6. Create dataframe

# %%
df = pd.DataFrame(af_list)
df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.382   0.451    7    -6.606     0       0.0293        0.5570
# 1           0.742   0.375    7   -13.829     1       0.0482        0.3970
# 2           0.585   0.552    0   -10.613     1       0.0353        0.1940
# 3           0.405   0.535    6    -7.504     0       0.0531        0.0531
# 4           0.586   0.526    0    -6.928     1       0.0564        0.5550
# ..            ...     ...  ...       ...   ...          ...           ...
# 314         0.744   0.831    7    -6.004     0       0.0300        0.0250
# 315         0.609   0.797    1    -5.945     0       0.0361        0.0244
# 316         0.594   0.608    1    -8.930     1       0.0410        0.0259
# 317         0.811   0.452    7    -8.676     1       0.1150        0.1620
# 318         0.782   0.716    4    -6.113     0       0.1990        0.2190
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000034    0.2650    0.506  150.803  audio_features
# 1            0.901000    0.0996    0.105  102.023  audio_features
# 2            0.017100    0.0735    0.496  100.089  audio_features
# 3            0.106000    0.0696    0.637   97.698  audio_features
# 4            0.000000    0.2340    0.456  107.153  audio_features
# ..                ...       ...      ...      ...             ...
# 314          0.000236    0.0728    0.702  129.968  audio_features
# 315          0.345000    0.4430    0.546  120.039  audio_features
# 316          0.122000    0.1560    0.639  169.969  audio_features
# 317          0.003050    0.1200    0.556  121.058  audio_features
# 318          0.000000    0.0749    0.850   94.010  audio_features
#
#                          id                                   uri  \
# 0    6yzJiHzsscf0n88xb9aNT4  spotify:track:6yzJiHzsscf0n88xb9aNT4
# 1    5zdXRoKLZ54VBdbdn7yhz4  spotify:track:5zdXRoKLZ54VBdbdn7yhz4
# 2    5qvCKAyjgHnpR5c63OedCY  spotify:track:5qvCKAyjgHnpR5c63OedCY
# 3    2vByA9JgfMU2bPjUqmxCdv  spotify:track:2vByA9JgfMU2bPjUqmxCdv
# 4    0pPQwIjwqduvLfZORYYEaI  spotify:track:0pPQwIjwqduvLfZORYYEaI
# ..                      ...                                   ...
# 314  0aWhxzFrP2Yyz3CetJe0xE  spotify:track:0aWhxzFrP2Yyz3CetJe0xE
# 315  5yzqu20ssqs9ric3fHO74I  spotify:track:5yzqu20ssqs9ric3fHO74I
# 316  2j5AyPkjugfvw0HWrK1Wvr  spotify:track:2j5AyPkjugfvw0HWrK1Wvr
# 317  0BWBqb5XxraObLopqskk6D  spotify:track:0BWBqb5XxraObLopqskk6D
# 318  1ifVrAQPH2DZ3FBFu48rFw  spotify:track:1ifVrAQPH2DZ3FBFu48rFw
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/6yzJiHzsscf0...
# 1    https://api.spotify.com/v1/tracks/5zdXRoKLZ54V...
# 2    https://api.spotify.com/v1/tracks/5qvCKAyjgHnp...
# 3    https://api.spotify.com/v1/tracks/2vByA9JgfMU2...
# 4    https://api.spotify.com/v1/tracks/0pPQwIjwqduv...
# ..                                                 ...
# 314  https://api.spotify.com/v1/tracks/0aWhxzFrP2Yy...
# 315  https://api.spotify.com/v1/tracks/5yzqu20ssqs9...
# 316  https://api.spotify.com/v1/tracks/2j5AyPkjugfv...
# 317  https://api.spotify.com/v1/tracks/0BWBqb5XxraO...
# 318  https://api.spotify.com/v1/tracks/1ifVrAQPH2DZ...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/6yzJ...       267540
# 1    https://api.spotify.com/v1/audio-analysis/5zdX...       342163
# 2    https://api.spotify.com/v1/audio-analysis/5qvC...       267813
# 3    https://api.spotify.com/v1/audio-analysis/2vBy...       210800
# 4    https://api.spotify.com/v1/audio-analysis/0pPQ...       161267
# ..                                                 ...          ...
# 314  https://api.spotify.com/v1/audio-analysis/0aWh...       228066
# 315  https://api.spotify.com/v1/audio-analysis/5yzq...       216674
# 316  https://api.spotify.com/v1/audio-analysis/2j5A...       141503
# 317  https://api.spotify.com/v1/audio-analysis/0BWB...       199006
# 318  https://api.spotify.com/v1/audio-analysis/1ifV...       181290
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 314               4
# 315               4
# 316               4
# 317               4
# 318               4
#
# [319 rows x 18 columns]

# %% [markdown]
# #### 7. Csv export

# %%
df.to_csv("../data/everything_good_af.csv")

# %% [markdown]
# ## Creating function to make process repeatable

# %% [markdown]
# ### Defining function

# %%
def playlist_audio_features(username, playlist_id):
    # Get tracks
    tracks = get_playlist_tracks(username, playlist_id)
    
    # Get track ids, skipping None
    track_ids = [i['track']['id'] for i in tracks if i['track']['id'] is not None]
        
    # Chopping track ids list in chunks of 100 songs 
    chunk_size = 100
    track_ids_chopped = [track_ids[i:i + chunk_size] for i in range(0, len(track_ids), chunk_size)]
    
    # Get audio features
    af_list = []
    for chunk in track_ids_chopped:
        try:
            af_list.extend(sp.audio_features(chunk))
        except TypeError as e:
            print(f"Error retrieving audio features for chunk: {e}")
    
    # Create dataframe
    af_df = pd.DataFrame(af_list)

    return af_df

# %% [markdown]
# ### Testing the function with previous playlist

# %%
everything_good_af_df = playlist_audio_features(everything_good_user_name,everything_good_playlist_id)

# %%
everything_good_af_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.382   0.451    7    -6.606     0       0.0293        0.5570
# 1           0.742   0.375    7   -13.829     1       0.0482        0.3970
# 2           0.585   0.552    0   -10.613     1       0.0353        0.1940
# 3           0.405   0.535    6    -7.504     0       0.0531        0.0531
# 4           0.586   0.526    0    -6.928     1       0.0564        0.5550
# ..            ...     ...  ...       ...   ...          ...           ...
# 314         0.744   0.831    7    -6.004     0       0.0300        0.0250
# 315         0.609   0.797    1    -5.945     0       0.0361        0.0244
# 316         0.594   0.608    1    -8.930     1       0.0410        0.0259
# 317         0.811   0.452    7    -8.676     1       0.1150        0.1620
# 318         0.782   0.716    4    -6.113     0       0.1990        0.2190
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000034    0.2650    0.506  150.803  audio_features
# 1            0.901000    0.0996    0.105  102.023  audio_features
# 2            0.017100    0.0735    0.496  100.089  audio_features
# 3            0.106000    0.0696    0.637   97.698  audio_features
# 4            0.000000    0.2340    0.456  107.153  audio_features
# ..                ...       ...      ...      ...             ...
# 314          0.000236    0.0728    0.702  129.968  audio_features
# 315          0.345000    0.4430    0.546  120.039  audio_features
# 316          0.122000    0.1560    0.639  169.969  audio_features
# 317          0.003050    0.1200    0.556  121.058  audio_features
# 318          0.000000    0.0749    0.850   94.010  audio_features
#
#                          id                                   uri  \
# 0    6yzJiHzsscf0n88xb9aNT4  spotify:track:6yzJiHzsscf0n88xb9aNT4
# 1    5zdXRoKLZ54VBdbdn7yhz4  spotify:track:5zdXRoKLZ54VBdbdn7yhz4
# 2    5qvCKAyjgHnpR5c63OedCY  spotify:track:5qvCKAyjgHnpR5c63OedCY
# 3    2vByA9JgfMU2bPjUqmxCdv  spotify:track:2vByA9JgfMU2bPjUqmxCdv
# 4    0pPQwIjwqduvLfZORYYEaI  spotify:track:0pPQwIjwqduvLfZORYYEaI
# ..                      ...                                   ...
# 314  0aWhxzFrP2Yyz3CetJe0xE  spotify:track:0aWhxzFrP2Yyz3CetJe0xE
# 315  5yzqu20ssqs9ric3fHO74I  spotify:track:5yzqu20ssqs9ric3fHO74I
# 316  2j5AyPkjugfvw0HWrK1Wvr  spotify:track:2j5AyPkjugfvw0HWrK1Wvr
# 317  0BWBqb5XxraObLopqskk6D  spotify:track:0BWBqb5XxraObLopqskk6D
# 318  1ifVrAQPH2DZ3FBFu48rFw  spotify:track:1ifVrAQPH2DZ3FBFu48rFw
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/6yzJiHzsscf0...
# 1    https://api.spotify.com/v1/tracks/5zdXRoKLZ54V...
# 2    https://api.spotify.com/v1/tracks/5qvCKAyjgHnp...
# 3    https://api.spotify.com/v1/tracks/2vByA9JgfMU2...
# 4    https://api.spotify.com/v1/tracks/0pPQwIjwqduv...
# ..                                                 ...
# 314  https://api.spotify.com/v1/tracks/0aWhxzFrP2Yy...
# 315  https://api.spotify.com/v1/tracks/5yzqu20ssqs9...
# 316  https://api.spotify.com/v1/tracks/2j5AyPkjugfv...
# 317  https://api.spotify.com/v1/tracks/0BWBqb5XxraO...
# 318  https://api.spotify.com/v1/tracks/1ifVrAQPH2DZ...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/6yzJ...       267540
# 1    https://api.spotify.com/v1/audio-analysis/5zdX...       342163
# 2    https://api.spotify.com/v1/audio-analysis/5qvC...       267813
# 3    https://api.spotify.com/v1/audio-analysis/2vBy...       210800
# 4    https://api.spotify.com/v1/audio-analysis/0pPQ...       161267
# ..                                                 ...          ...
# 314  https://api.spotify.com/v1/audio-analysis/0aWh...       228066
# 315  https://api.spotify.com/v1/audio-analysis/5yzq...       216674
# 316  https://api.spotify.com/v1/audio-analysis/2j5A...       141503
# 317  https://api.spotify.com/v1/audio-analysis/0BWB...       199006
# 318  https://api.spotify.com/v1/audio-analysis/1ifV...       181290
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 314               4
# 315               4
# 316               4
# 317               4
# 318               4
#
# [319 rows x 18 columns]

# %%
everything_good_af_df.to_csv("../data/everything_good_af.csv")

# %% [markdown]
# ## Adding more playlists

# %% [markdown]
# ### Greatestest hip hop songs of all time

# %%
greatest_hiphop_playlist_id = "29S1jCDVUgUlF4baQA7wxB"
greatest_hiphop_username = "KD"
greatest_hiphop_af_df = playlist_audio_features(greatest_hiphop_username,greatest_hiphop_playlist_id)
greatest_hiphop_af_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.532   0.819    6    -5.282     0       0.2560       0.01570
# 1           0.716   0.531    7    -7.355     1       0.1220       0.07030
# 2           0.746   0.978    9    -5.324     1       0.0978       0.05550
# 3           0.596   0.620    5    -6.133     0       0.0390       0.01220
# 4           0.775   0.734    7    -5.410     1       0.2150       0.00138
# ..            ...     ...  ...       ...   ...          ...           ...
# 230         0.935   0.780    6    -5.795     0       0.1970       0.01580
# 231         0.886   0.620    5    -5.854     1       0.3070       0.08200
# 232         0.849   0.755    1    -7.400     0       0.3630       0.34600
# 233         0.821   0.856    6    -3.172     0       0.2660       0.04750
# 234         0.780   0.575    9    -7.247     0       0.2730       0.43000
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000000    0.3710    0.594   90.215  audio_features
# 1            0.000000    0.2240    0.344   71.994  audio_features
# 2            0.000041    0.0260    0.653  153.809  audio_features
# 3            0.000000    0.8200    0.102   80.029  audio_features
# 4            0.000000    0.3040    0.342   90.001  audio_features
# ..                ...       ...      ...      ...             ...
# 230          0.000000    0.1640    0.918  123.895  audio_features
# 231          0.000000    0.1000    0.600   76.035  audio_features
# 232          0.000000    0.0564    0.393  144.188  audio_features
# 233          0.000000    0.3470    0.533   91.023  audio_features
# 234          0.000000    0.1430    0.773   84.492  audio_features
#
#                          id                                   uri  \
# 0    1fotoYONO343JjbC8XvPSl  spotify:track:1fotoYONO343JjbC8XvPSl
# 1    74tLlkN3rgVzRqQJgPfink  spotify:track:74tLlkN3rgVzRqQJgPfink
# 2    3WibbMr6canxRJXhNtAvLU  spotify:track:3WibbMr6canxRJXhNtAvLU
# 3    0mEdbdeRFQwBhN4xfyIeUM  spotify:track:0mEdbdeRFQwBhN4xfyIeUM
# 4    2LhhnqrHPWvXYveZVHLKrd  spotify:track:2LhhnqrHPWvXYveZVHLKrd
# ..                      ...                                   ...
# 230  1wLhwzPAtze5JT8qqXlqaO  spotify:track:1wLhwzPAtze5JT8qqXlqaO
# 231  7cVmKBwzPsh4Fmb6SplfEm  spotify:track:7cVmKBwzPsh4Fmb6SplfEm
# 232  7EcE5yCPVZaZut1JqowbcI  spotify:track:7EcE5yCPVZaZut1JqowbcI
# 233  6SSJcmQgBEvHqqCivyVfqG  spotify:track:6SSJcmQgBEvHqqCivyVfqG
# 234  2g8HN35AnVGIk7B8yMucww  spotify:track:2g8HN35AnVGIk7B8yMucww
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/1fotoYONO343...
# 1    https://api.spotify.com/v1/tracks/74tLlkN3rgVz...
# 2    https://api.spotify.com/v1/tracks/3WibbMr6canx...
# 3    https://api.spotify.com/v1/tracks/0mEdbdeRFQwB...
# 4    https://api.spotify.com/v1/tracks/2LhhnqrHPWvX...
# ..                                                 ...
# 230  https://api.spotify.com/v1/tracks/1wLhwzPAtze5...
# 231  https://api.spotify.com/v1/tracks/7cVmKBwzPsh4...
# 232  https://api.spotify.com/v1/tracks/7EcE5yCPVZaZ...
# 233  https://api.spotify.com/v1/tracks/6SSJcmQgBEvH...
# 234  https://api.spotify.com/v1/tracks/2g8HN35AnVGI...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/1fot...       247333
# 1    https://api.spotify.com/v1/audio-analysis/74tL...       386907
# 2    https://api.spotify.com/v1/audio-analysis/3Wib...       304227
# 3    https://api.spotify.com/v1/audio-analysis/0mEd...       271600
# 4    https://api.spotify.com/v1/audio-analysis/2Lhh...       210840
# ..                                                 ...          ...
# 230  https://api.spotify.com/v1/audio-analysis/1wLh...       226160
# 231  https://api.spotify.com/v1/audio-analysis/7cVm...       229813
# 232  https://api.spotify.com/v1/audio-analysis/7EcE...       206655
# 233  https://api.spotify.com/v1/audio-analysis/6SSJ...       225373
# 234  https://api.spotify.com/v1/audio-analysis/2g8H...       252747
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 230               4
# 231               4
# 232               4
# 233               4
# 234               4
#
# [235 rows x 18 columns]

# %%
#export to csv
greatest_hiphop_af_df.to_csv("../data/greatest_hiphop_songs_of_all_time_af.csv")

# %% [markdown]
# ### The best of 80s

# %%
best_of_80s_playlist_id = "49l9GbetRtsnQC7z3kkiZw"
best_of_80s_username = "Keegan - Old Time Playlists"
best_of_80s_af_df = playlist_audio_features(best_of_80s_username,best_of_80s_playlist_id)
best_of_80s_af_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.710   0.799    6    -4.897     1       0.0328        0.2200
# 1           0.573   0.902    6    -7.638     0       0.0540        0.0180
# 2           0.645   0.795    7   -12.095     1       0.0527        0.3470
# 3           0.650   0.645    2    -7.823     0       0.0500        0.0249
# 4           0.671   0.373    9   -18.064     1       0.0323        0.2570
# ..            ...     ...  ...       ...   ...          ...           ...
# 382         0.658   0.866    6    -6.337     0       0.0352        0.0504
# 383         0.763   0.352    0   -11.789     1       0.0555        0.2610
# 384         0.641   0.619   11   -10.427     0       0.0418        0.1890
# 385         0.542   0.810    7    -7.960     1       0.0304        0.0763
# 386         0.673   0.944    0    -4.794     1       0.0654        0.2640
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000602    0.3490    0.725  120.372  audio_features
# 1            0.001250    0.0928    0.876   84.412  audio_features
# 2            0.003890    0.1040    0.535  112.067  audio_features
# 3            0.000016    0.1540    0.328  120.034  audio_features
# 4            0.000080    0.0481    0.732   92.718  audio_features
# ..                ...       ...      ...      ...             ...
# 382          0.020100    0.0394    0.848  104.898  audio_features
# 383          0.000084    0.0791    0.732   83.993  audio_features
# 384          0.160000    0.3490    0.434  159.925  audio_features
# 385          0.000004    0.0683    0.920  177.052  audio_features
# 386          0.000000    0.0684    0.928  140.760  audio_features
#
#                          id                                   uri  \
# 0    4y1LsJpmMti1PfRQV9AWWe  spotify:track:4y1LsJpmMti1PfRQV9AWWe
# 1    2WfaOiMkCvy7F5fcp2zZ8L  spotify:track:2WfaOiMkCvy7F5fcp2zZ8L
# 2    4RvWPyQ5RL0ao9LPZeSouE  spotify:track:4RvWPyQ5RL0ao9LPZeSouE
# 3    3z9W9fT8TFFeBY3t5WGLmm  spotify:track:3z9W9fT8TFFeBY3t5WGLmm
# 4    2374M0fQpWi3dLnB54qaLX  spotify:track:2374M0fQpWi3dLnB54qaLX
# ..                      ...                                   ...
# 382  0GZzK43dJ6uNjOuitlCxDr  spotify:track:0GZzK43dJ6uNjOuitlCxDr
# 383  3vYrrMpsebx3OJ1H5E1lWQ  spotify:track:3vYrrMpsebx3OJ1H5E1lWQ
# 384  6X1mehC9bJ1ExEip4HB79W  spotify:track:6X1mehC9bJ1ExEip4HB79W
# 385  0ukySDr4uEzZE36s7t7X8E  spotify:track:0ukySDr4uEzZE36s7t7X8E
# 386  24g7Wa2aTohgmuJVP4Gxia  spotify:track:24g7Wa2aTohgmuJVP4Gxia
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/4y1LsJpmMti1...
# 1    https://api.spotify.com/v1/tracks/2WfaOiMkCvy7...
# 2    https://api.spotify.com/v1/tracks/4RvWPyQ5RL0a...
# 3    https://api.spotify.com/v1/tracks/3z9W9fT8TFFe...
# 4    https://api.spotify.com/v1/tracks/2374M0fQpWi3...
# ..                                                 ...
# 382  https://api.spotify.com/v1/tracks/0GZzK43dJ6uN...
# 383  https://api.spotify.com/v1/tracks/3vYrrMpsebx3...
# 384  https://api.spotify.com/v1/tracks/6X1mehC9bJ1E...
# 385  https://api.spotify.com/v1/tracks/0ukySDr4uEzZ...
# 386  https://api.spotify.com/v1/tracks/24g7Wa2aTohg...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/4y1L...       238267
# 1    https://api.spotify.com/v1/audio-analysis/2Wfa...       225280
# 2    https://api.spotify.com/v1/audio-analysis/4RvW...       251489
# 3    https://api.spotify.com/v1/audio-analysis/3z9W...       186000
# 4    https://api.spotify.com/v1/audio-analysis/2374...       295893
# ..                                                 ...          ...
# 382  https://api.spotify.com/v1/audio-analysis/0GZz...       227680
# 383  https://api.spotify.com/v1/audio-analysis/3vYr...       218427
# 384  https://api.spotify.com/v1/audio-analysis/6X1m...       191800
# 385  https://api.spotify.com/v1/audio-analysis/0uky...       222613
# 386  https://api.spotify.com/v1/audio-analysis/24g7...       184200
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 382               4
# 383               4
# 384               4
# 385               4
# 386               4
#
# [387 rows x 18 columns]

# %%
#export to csv
best_of_80s_af_df.to_csv("../data/the_best_of_80s_af.csv")

# %% [markdown]
# ### The best of 90s

# %%
best_of_90s_playlist_id = "5Y4aQH7GJvb1pFmqAoIOix"
best_of_90s_username = "Keegan - Old Time Playlists"
best_of_90s_af_df = playlist_audio_features(best_of_90s_username,best_of_90s_playlist_id)
best_of_90s_af_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.500   0.824    4    -5.846     0       0.0388      0.000160
# 1           0.608   0.419   11   -10.016     1       0.0331      0.602000
# 2           0.472   0.652    1   -10.171     0       0.0305      0.013100
# 3           0.549   0.946    7    -4.265     0       0.0377      0.000945
# 4           0.666   0.855    9    -5.051     0       0.0295      0.179000
# ..            ...     ...  ...       ...   ...          ...           ...
# 166         0.438   0.905    9    -6.161     1       0.0419      0.000009
# 167         0.682   0.765    1    -5.021     0       0.0395      0.026800
# 168         0.391   0.951    6    -7.419     1       0.0692      0.012600
# 169         0.398   0.927    9    -4.212     1       0.0567      0.000062
# 170         0.378   0.531    2    -6.451     1       0.0270      0.253000
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.001610    0.0916    0.539  120.125  audio_features
# 1            0.000008    0.1080    0.602  100.220  audio_features
# 2            0.000011    0.1400    0.401  140.124  audio_features
# 3            0.002070    0.3680    0.477  135.959  audio_features
# 4            0.000001    0.0987    0.803  125.639  audio_features
# ..                ...       ...      ...      ...             ...
# 166          0.000054    0.3630    0.723  134.163  audio_features
# 167          0.000034    0.1880    0.567   90.807  audio_features
# 168          0.000378    0.0878    0.468  157.660  audio_features
# 169          0.000177    0.0575    0.311   77.106  audio_features
# 170          0.000000    0.3490    0.338  105.723  audio_features
#
#                          id                                   uri  \
# 0    2RsAajgo0g7bMCHxwH3Sk0  spotify:track:2RsAajgo0g7bMCHxwH3Sk0
# 1    4vDBJeeQCbhP9FaPPMsYkY  spotify:track:4vDBJeeQCbhP9FaPPMsYkY
# 2    0wokCRaKD0zPNhMRXAgVsr  spotify:track:0wokCRaKD0zPNhMRXAgVsr
# 3    1Ab3miDy9TBJskMFlkiB5Z  spotify:track:1Ab3miDy9TBJskMFlkiB5Z
# 4    31AOj9sFz2gM0O3hMARRBx  spotify:track:31AOj9sFz2gM0O3hMARRBx
# ..                      ...                                   ...
# 166  2V4Bc2I962j7acQj1N0PiQ  spotify:track:2V4Bc2I962j7acQj1N0PiQ
# 167  2hnMS47jN0etwvFPzYk11f  spotify:track:2hnMS47jN0etwvFPzYk11f
# 168  4LJhJ6DQS7NwE7UKtvcM52  spotify:track:4LJhJ6DQS7NwE7UKtvcM52
# 169  4dVbhS6OiYvFikshyaQaCN  spotify:track:4dVbhS6OiYvFikshyaQaCN
# 170  3jiAm2Pe7Iv2jO1tZxvZvK  spotify:track:3jiAm2Pe7Iv2jO1tZxvZvK
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/2RsAajgo0g7b...
# 1    https://api.spotify.com/v1/tracks/4vDBJeeQCbhP...
# 2    https://api.spotify.com/v1/tracks/0wokCRaKD0zP...
# 3    https://api.spotify.com/v1/tracks/1Ab3miDy9TBJ...
# 4    https://api.spotify.com/v1/tracks/31AOj9sFz2gM...
# ..                                                 ...
# 166  https://api.spotify.com/v1/tracks/2V4Bc2I962j7...
# 167  https://api.spotify.com/v1/tracks/2hnMS47jN0et...
# 168  https://api.spotify.com/v1/tracks/4LJhJ6DQS7Nw...
# 169  https://api.spotify.com/v1/tracks/4dVbhS6OiYvF...
# 170  https://api.spotify.com/v1/tracks/3jiAm2Pe7Iv2...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/2RsA...       218920
# 1    https://api.spotify.com/v1/audio-analysis/4vDB...       268333
# 2    https://api.spotify.com/v1/audio-analysis/0wok...       340200
# 3    https://api.spotify.com/v1/audio-analysis/1Ab3...       214360
# 4    https://api.spotify.com/v1/audio-analysis/31AO...       268427
# ..                                                 ...          ...
# 166  https://api.spotify.com/v1/audio-analysis/2V4B...       162667
# 167  https://api.spotify.com/v1/audio-analysis/2hnM...       182747
# 168  https://api.spotify.com/v1/audio-analysis/4LJh...       148360
# 169  https://api.spotify.com/v1/audio-analysis/4dVb...       260027
# 170  https://api.spotify.com/v1/audio-analysis/3jiA...       230680
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 166               4
# 167               4
# 168               4
# 169               4
# 170               4
#
# [171 rows x 18 columns]

# %%
#export to csv
best_of_90s_af_df.to_csv("../data/the_best_of_90s_af.csv")

# %% [markdown]
# ### The best of 70s

# %%
best_of_70s_playlist_id = "7e6gKFwEXMF6uDQzmD9YXn"
best_of_70s_username = "Keegan - Old Time Playlists"
best_of_70s_af_df = playlist_audio_features(best_of_70s_username,best_of_70s_playlist_id)
best_of_70s_af_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.380   0.917    9    -4.486     1       0.0733      0.003150
# 1           0.445   0.384   10   -14.642     1       0.0417      0.635000
# 2           0.579   0.508    2    -9.484     1       0.0270      0.005740
# 3           0.601   0.532   10    -9.119     1       0.0286      0.432000
# 4           0.733   0.794    5   -10.023     1       0.0307      0.061400
# ..            ...     ...  ...       ...   ...          ...           ...
# 280         0.197   0.796    2    -7.335     1       0.0645      0.000541
# 281         0.670   0.763    7    -6.864     1       0.0341      0.155000
# 282         0.609   0.624    7   -11.717     1       0.0292      0.039600
# 283         0.423   0.852    8    -9.269     1       0.0327      0.006500
# 284         0.667   0.804    2    -8.583     1       0.0398      0.032800
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000138    0.0628    0.849  162.521  audio_features
# 1            0.000077    0.0539    0.216  123.295  audio_features
# 2            0.000494    0.0575    0.609  147.125  audio_features
# 3            0.000006    0.0925    0.341  136.571  audio_features
# 4            0.036700    0.3300    0.931  148.174  audio_features
# ..                ...       ...      ...      ...             ...
# 280          0.417000    0.1870    0.522  175.020  audio_features
# 281          0.000000    0.0799    0.610  114.398  audio_features
# 282          0.000168    0.2770    0.691  123.191  audio_features
# 283          0.899000    0.3310    0.667  114.710  audio_features
# 284          0.054400    0.0632    0.759  105.799  audio_features
#
#                          id                                   uri  \
# 0    1fl5TvpPkPjx8zo45HY0UQ  spotify:track:1fl5TvpPkPjx8zo45HY0UQ
# 1    3ZE3wv8V3w2T2f7nOCjV0N  spotify:track:3ZE3wv8V3w2T2f7nOCjV0N
# 2    40riOy7x9W7GXjyGp4pjAv  spotify:track:40riOy7x9W7GXjyGp4pjAv
# 3    3gdewACMIVMEWVbyb8O9sY  spotify:track:3gdewACMIVMEWVbyb8O9sY
# 4    37Tmv4NnfQeb0ZgUC4fOJj  spotify:track:37Tmv4NnfQeb0ZgUC4fOJj
# ..                      ...                                   ...
# 280  5u5qlnyVaewWugJIjzilIc  spotify:track:5u5qlnyVaewWugJIjzilIc
# 281  4OJFkrRQqol4FsPesF8eu4  spotify:track:4OJFkrRQqol4FsPesF8eu4
# 282  4RFqi5JQduiSlRZCVlUDGH  spotify:track:4RFqi5JQduiSlRZCVlUDGH
# 283  7B265QWYkUeqG2ihVEUZ5D  spotify:track:7B265QWYkUeqG2ihVEUZ5D
# 284  1vP2JEXRsGrFbwOZ0foOQ5  spotify:track:1vP2JEXRsGrFbwOZ0foOQ5
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/1fl5TvpPkPjx...
# 1    https://api.spotify.com/v1/tracks/3ZE3wv8V3w2T...
# 2    https://api.spotify.com/v1/tracks/40riOy7x9W7G...
# 3    https://api.spotify.com/v1/tracks/3gdewACMIVME...
# 4    https://api.spotify.com/v1/tracks/37Tmv4NnfQeb...
# ..                                                 ...
# 280  https://api.spotify.com/v1/tracks/5u5qlnyVaewW...
# 281  https://api.spotify.com/v1/tracks/4OJFkrRQqol4...
# 282  https://api.spotify.com/v1/tracks/4RFqi5JQduiS...
# 283  https://api.spotify.com/v1/tracks/7B265QWYkUeq...
# 284  https://api.spotify.com/v1/tracks/1vP2JEXRsGrF...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/1fl5...       213093
# 1    https://api.spotify.com/v1/audio-analysis/3ZE3...       235987
# 2    https://api.spotify.com/v1/audio-analysis/40ri...       391376
# 3    https://api.spotify.com/v1/audio-analysis/3gde...       281613
# 4    https://api.spotify.com/v1/audio-analysis/37Tm...       348624
# ..                                                 ...          ...
# 280  https://api.spotify.com/v1/audio-analysis/5u5q...       261387
# 281  https://api.spotify.com/v1/audio-analysis/4OJF...       235667
# 282  https://api.spotify.com/v1/audio-analysis/4RFq...       184333
# 283  https://api.spotify.com/v1/audio-analysis/7B26...       167413
# 284  https://api.spotify.com/v1/audio-analysis/1vP2...       184382
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 280               4
# 281               4
# 282               4
# 283               4
# 284               4
#
# [285 rows x 18 columns]

# %%
#export to csv
best_of_70s_af_df.to_csv("../data/the_best_of_70s_af.csv")

# %% [markdown]
# ### The best of 60s

# %%
best_of_60s_playlist_id = "3OeNPjOCG6JXQB2ezRRfW1"
best_of_60s_username = "Keegan - Old Time Playlists"
best_of_60s_af_df = playlist_audio_features(best_of_60s_username,best_of_60s_playlist_id)
best_of_60s_af_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.400   0.836    7    -6.791     1       0.0359       0.37700
# 1           0.634   0.630    1    -8.277     0       0.0310       0.44700
# 2           0.438   0.805    8    -6.237     1       0.0624       0.00255
# 3           0.640   0.663    0    -7.516     1       0.0374       0.20100
# 4           0.563   0.915    7    -5.062     1       0.0800       0.24700
# ..            ...     ...  ...       ...   ...          ...           ...
# 129         0.668   0.253    9   -11.352     1       0.0412       0.59400
# 130         0.347   0.381    8   -11.169     1       0.0302       0.84900
# 131         0.671   0.725    2   -10.065     1       0.0650       0.29600
# 132         0.657   0.825    0    -8.940     1       0.0980       0.21900
# 133         0.646   0.374    8   -10.706     0       0.1030       0.15100
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000000    0.0652    0.907   75.403  audio_features
# 1            0.039000    0.1700    0.489  118.628  audio_features
# 2            0.000057    0.0842    0.564  113.253  audio_features
# 3            0.008060    0.1520    0.663  132.770  audio_features
# 4            0.000085    0.0613    0.710  136.345  audio_features
# ..                ...       ...      ...      ...             ...
# 129          0.000042    0.3530    0.672  119.253  audio_features
# 130          0.000031    0.2280    0.296   89.159  audio_features
# 131          0.000220    0.0889    0.956   85.270  audio_features
# 132          0.845000    0.3540    0.582  126.817  audio_features
# 133          0.651000    0.2080    0.475   87.593  audio_features
#
#                          id                                   uri  \
# 0    01K1zFyjJhG2Qk7PIkSAEA  spotify:track:01K1zFyjJhG2Qk7PIkSAEA
# 1    6H3kDe7CGoWYBabAeVWGiD  spotify:track:6H3kDe7CGoWYBabAeVWGiD
# 2    2aoo2jlRnM3A0NyLQqMN2f  spotify:track:2aoo2jlRnM3A0NyLQqMN2f
# 3    4BP3uh0hFLFRb5cjsgLqDh  spotify:track:4BP3uh0hFLFRb5cjsgLqDh
# 4    1mfV2kv9RwFKVI8kEQlmOJ  spotify:track:1mfV2kv9RwFKVI8kEQlmOJ
# ..                      ...                                   ...
# 129  1vcqtVEolygBkOjxtUV1Kb  spotify:track:1vcqtVEolygBkOjxtUV1Kb
# 130  3yuJ5HOIXe4ag9fQ9d1dmD  spotify:track:3yuJ5HOIXe4ag9fQ9d1dmD
# 131  1FRP8d6l2jm3DS5f78ZrhK  spotify:track:1FRP8d6l2jm3DS5f78ZrhK
# 132  7j96wehhMtN0fkVvFhD8Ix  spotify:track:7j96wehhMtN0fkVvFhD8Ix
# 133  22Bvku5X3odiXj2wbtgY4T  spotify:track:22Bvku5X3odiXj2wbtgY4T
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/01K1zFyjJhG2...
# 1    https://api.spotify.com/v1/tracks/6H3kDe7CGoWY...
# 2    https://api.spotify.com/v1/tracks/2aoo2jlRnM3A...
# 3    https://api.spotify.com/v1/tracks/4BP3uh0hFLFR...
# 4    https://api.spotify.com/v1/tracks/1mfV2kv9RwFK...
# ..                                                 ...
# 129  https://api.spotify.com/v1/tracks/1vcqtVEolygB...
# 130  https://api.spotify.com/v1/tracks/3yuJ5HOIXe4a...
# 131  https://api.spotify.com/v1/tracks/1FRP8d6l2jm3...
# 132  https://api.spotify.com/v1/tracks/7j96wehhMtN0...
# 133  https://api.spotify.com/v1/tracks/22Bvku5X3odi...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/01K1...       142160
# 1    https://api.spotify.com/v1/audio-analysis/6H3k...       270773
# 2    https://api.spotify.com/v1/audio-analysis/2aoo...       240800
# 3    https://api.spotify.com/v1/audio-analysis/4BP3...       140773
# 4    https://api.spotify.com/v1/audio-analysis/1mfV...       142227
# ..                                                 ...          ...
# 129  https://api.spotify.com/v1/audio-analysis/1vcq...       174707
# 130  https://api.spotify.com/v1/audio-analysis/3yuJ...       185813
# 131  https://api.spotify.com/v1/audio-analysis/1FRP...       140400
# 132  https://api.spotify.com/v1/audio-analysis/7j96...       137667
# 133  https://api.spotify.com/v1/audio-analysis/22Bv...       129800
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 129               4
# 130               4
# 131               4
# 132               4
# 133               4
#
# [134 rows x 18 columns]

# %%
#export to csv
best_of_60s_af_df.to_csv("../data/the_best_of_60s_af.csv")

# %% [markdown]
# ### 1000 of the best rock songs of all time

# %%
best_rock_all_time_playlist_id = "0Y8LL8xygULBsQnNWQgHiL"
best_rock_all_time_username = "bimsalasimm"
best_rock_all_time_af_df = playlist_audio_features(best_rock_all_time_username,best_rock_all_time_playlist_id)
best_rock_all_time_af_df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.671   0.712    2    -7.815     1       0.0476      0.429000
# 1            0.511   0.632    6    -9.645     1       0.0439      0.012000
# 2            0.204   0.837    5    -7.618     1       0.0676      0.281000
# 3            0.500   0.851    2    -6.027     1       0.0380      0.012800
# 4            0.685   0.633    9    -7.259     1       0.0377      0.013600
# ...            ...     ...  ...       ...   ...          ...           ...
# 1406         0.490   0.854    7    -7.489     1       0.0407      0.000258
# 1407         0.625   0.609    7    -8.318     0       0.0264      0.015100
# 1408         0.395   0.843    8    -4.476     1       0.0374      0.004830
# 1409         0.605   0.742    4    -4.363     0       0.0327      0.002860
# 1410         0.701   0.539    2    -8.968     1       0.0277      0.000655
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.1030    0.462  113.805  audio_features
# 1             0.099600    0.3060    0.483   97.612  audio_features
# 2             0.004050    0.2910    0.392  171.514  audio_features
# 3             0.006980    0.1360    0.358  125.599  audio_features
# 4             0.000106    0.0935    0.731  131.397  audio_features
# ...                ...       ...      ...      ...             ...
# 1406          0.000735    0.2990    0.443  132.032  audio_features
# 1407          0.063500    0.0909    0.888  126.584  audio_features
# 1408          0.000000    0.0404    0.481  112.423  audio_features
# 1409          0.001050    0.2560    0.470  105.040  audio_features
# 1410          0.005000    0.0589    0.752  107.531  audio_features
#
#                           id                                   uri  \
# 0     2fuCquhmrzHpu5xcA1ci9x  spotify:track:2fuCquhmrzHpu5xcA1ci9x
# 1     4HCWqhZGWPWwryXmQ6D4UU  spotify:track:4HCWqhZGWPWwryXmQ6D4UU
# 2     0VafPclbphrwh36WraHWws  spotify:track:0VafPclbphrwh36WraHWws
# 3     2TlXPShOrPn4K51fP0Fykd  spotify:track:2TlXPShOrPn4K51fP0Fykd
# 4     1jM23jASF0JrhgqYhqCZfl  spotify:track:1jM23jASF0JrhgqYhqCZfl
# ...                      ...                                   ...
# 1406  2rbcCco3PrSyMinVJdh61J  spotify:track:2rbcCco3PrSyMinVJdh61J
# 1407  5gDrMfCS7UxMZF5PHslroV  spotify:track:5gDrMfCS7UxMZF5PHslroV
# 1408  0nnwn7LWHCAu09jfuH1xTA  spotify:track:0nnwn7LWHCAu09jfuH1xTA
# 1409  4tXr9v3K7nWW1aebWqR1B7  spotify:track:4tXr9v3K7nWW1aebWqR1B7
# 1410  0z1b34WikhOH9ZxU8QDWcv  spotify:track:0z1b34WikhOH9ZxU8QDWcv
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/2fuCquhmrzHp...
# 1     https://api.spotify.com/v1/tracks/4HCWqhZGWPWw...
# 2     https://api.spotify.com/v1/tracks/0VafPclbphrw...
# 3     https://api.spotify.com/v1/tracks/2TlXPShOrPn4...
# 4     https://api.spotify.com/v1/tracks/1jM23jASF0Jr...
# ...                                                 ...
# 1406  https://api.spotify.com/v1/tracks/2rbcCco3PrSy...
# 1407  https://api.spotify.com/v1/tracks/5gDrMfCS7UxM...
# 1408  https://api.spotify.com/v1/tracks/0nnwn7LWHCAu...
# 1409  https://api.spotify.com/v1/tracks/4tXr9v3K7nWW...
# 1410  https://api.spotify.com/v1/tracks/0z1b34WikhOH...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/2fuC...       248440
# 1     https://api.spotify.com/v1/audio-analysis/4HCW...       240093
# 2     https://api.spotify.com/v1/audio-analysis/0Vaf...       590000
# 3     https://api.spotify.com/v1/audio-analysis/2TlX...       275040
# 4     https://api.spotify.com/v1/audio-analysis/1jM2...       317240
# ...                                                 ...          ...
# 1406  https://api.spotify.com/v1/audio-analysis/2rbc...       307960
# 1407  https://api.spotify.com/v1/audio-analysis/5gDr...       213533
# 1408  https://api.spotify.com/v1/audio-analysis/0nnw...       212067
# 1409  https://api.spotify.com/v1/audio-analysis/4tXr...       271160
# 1410  https://api.spotify.com/v1/audio-analysis/0z1b...       312627
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 1406               4
# 1407               4
# 1408               4
# 1409               4
# 1410               4
#
# [1411 rows x 18 columns]

# %%
#export to csv
best_rock_all_time_af_df.to_csv("../data/the_best_rock_all_time_af.csv")

# %% [markdown]
# ### Guilty pleasures

# %%
guilty_pleasures_playlist_id = "3GnAT8Z3WNcon2uh6eVIiA"
guilty_pleasures_username = "janvelthuis1960"
guilty_pleasures_af_df = playlist_audio_features(guilty_pleasures_username,guilty_pleasures_playlist_id)
guilty_pleasures_af_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.548   0.258   11    -8.874     1       0.0293       0.47500
# 1           0.768   0.864   11    -6.145     1       0.0324       0.10100
# 2           0.721   0.939    8   -11.823     1       0.0376       0.11500
# 3           0.543   0.870    9    -6.514     1       0.0428       0.35800
# 4           0.798   0.740   11    -4.865     1       0.0458       0.04190
# ..            ...     ...  ...       ...   ...          ...           ...
# 759         0.841   0.655    8    -8.150     1       0.2390       0.20800
# 760         0.553   0.702    2    -4.829     1       0.1080       0.00532
# 761         0.667   0.753    5    -9.196     1       0.0543       0.01050
# 762         0.849   0.875    0    -6.236     1       0.0300       0.09470
# 763         0.783   0.541    5   -13.398     0       0.0405       0.10900
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000029    0.4590    0.644  126.921  audio_features
# 1            0.000000    0.1620    0.891  110.008  audio_features
# 2            0.000038    0.1080    0.914  113.309  audio_features
# 3            0.000939    0.7920    0.754  100.804  audio_features
# 4            0.000002    0.1570    0.834  128.054  audio_features
# ..                ...       ...      ...      ...             ...
# 759          0.000003    0.2910    0.865  108.442  audio_features
# 760          0.000005    0.0446    0.453  201.868  audio_features
# 761          0.000000    0.3370    0.785  123.463  audio_features
# 762          0.021300    0.3640    0.898  130.013  audio_features
# 763          0.082200    0.0891    0.967  125.816  audio_features
#
#                          id                                   uri  \
# 0    6PHf8qq1n8mWplJ9nEZ9ED  spotify:track:6PHf8qq1n8mWplJ9nEZ9ED
# 1    1Je1IMUlBXcx1Fz0WE7oPT  spotify:track:1Je1IMUlBXcx1Fz0WE7oPT
# 2    4PTG3Z6ehGkBFwjybzWkR8  spotify:track:4PTG3Z6ehGkBFwjybzWkR8
# 3    0GjEhVFGZW8afUYGChu3Rr  spotify:track:0GjEhVFGZW8afUYGChu3Rr
# 4    1cSXzDZt8vzuUp2XREQEJN  spotify:track:1cSXzDZt8vzuUp2XREQEJN
# ..                      ...                                   ...
# 759  6Bne501HS96nEeNq8Gn87R  spotify:track:6Bne501HS96nEeNq8Gn87R
# 760  3px156RqKPoqmxq44b3pSD  spotify:track:3px156RqKPoqmxq44b3pSD
# 761  2sHmscm6NClVLvPtqk1A73  spotify:track:2sHmscm6NClVLvPtqk1A73
# 762  4IiKITgHYaHrF1zUlcTyVH  spotify:track:4IiKITgHYaHrF1zUlcTyVH
# 763  2BEArHIJsI5fxYEpCZv2sF  spotify:track:2BEArHIJsI5fxYEpCZv2sF
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/6PHf8qq1n8mW...
# 1    https://api.spotify.com/v1/tracks/1Je1IMUlBXcx...
# 2    https://api.spotify.com/v1/tracks/4PTG3Z6ehGkB...
# 3    https://api.spotify.com/v1/tracks/0GjEhVFGZW8a...
# 4    https://api.spotify.com/v1/tracks/1cSXzDZt8vzu...
# ..                                                 ...
# 759  https://api.spotify.com/v1/tracks/6Bne501HS96n...
# 760  https://api.spotify.com/v1/tracks/3px156RqKPoq...
# 761  https://api.spotify.com/v1/tracks/2sHmscm6NClV...
# 762  https://api.spotify.com/v1/tracks/4IiKITgHYaHr...
# 763  https://api.spotify.com/v1/tracks/2BEArHIJsI5f...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/6PHf...       200293
# 1    https://api.spotify.com/v1/audio-analysis/1Je1...       173027
# 2    https://api.spotify.com/v1/audio-analysis/4PTG...       213573
# 3    https://api.spotify.com/v1/audio-analysis/0GjE...       230400
# 4    https://api.spotify.com/v1/audio-analysis/1cSX...       219720
# ..                                                 ...          ...
# 759  https://api.spotify.com/v1/audio-analysis/6Bne...       170507
# 760  https://api.spotify.com/v1/audio-analysis/3px1...       240200
# 761  https://api.spotify.com/v1/audio-analysis/2sHm...       264653
# 762  https://api.spotify.com/v1/audio-analysis/4IiK...       230933
# 763  https://api.spotify.com/v1/audio-analysis/2BEA...       212009
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 759               4
# 760               4
# 761               4
# 762               4
# 763               4
#
# [764 rows x 18 columns]

# %%
#export to csv
guilty_pleasures_af_df.to_csv("../data/guilty_pleasures_af.csv")

# %% [markdown]
# ### Top 5000 pop songs

# %%
top_5000_pop_playlist_id = "4RVf1hHtwvMEED3yuCNi8q"
top_5000_pop_username = "1165808128"
top_5000_pop_af_df = playlist_audio_features(top_5000_pop_username,top_5000_pop_playlist_id)
top_5000_pop_af_df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.429   0.554    9    -6.128     0       0.0291        0.6700
# 1            0.920   0.654   11    -3.051     0       0.0401        0.0236
# 2            0.386   0.607   10    -7.700     1       0.0261        0.0112
# 3            0.367   0.452   10   -10.422     1       0.0307        0.0353
# 4            0.711   0.362    3   -10.851     0       0.0381        0.2720
# ...            ...     ...  ...       ...   ...          ...           ...
# 3645         0.690   0.843    9    -9.394     1       0.0352        0.5760
# 3646         0.653   0.658    1   -10.380     1       0.0335        0.2250
# 3647         0.745   0.560    8    -9.009     0       0.0269        0.1720
# 3648         0.686   0.755    1    -8.304     0       0.0488        0.1490
# 3649         0.350   0.371   11   -10.538     0       0.0319        0.2190
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000152    0.1050    0.407  136.302  audio_features
# 1             0.015300    0.0360    0.847  117.046  audio_features
# 2             0.000014    0.0880    0.532  147.207  audio_features
# 3             0.002280    0.6890    0.189  113.066  audio_features
# 4             0.000000    0.1270    0.616  117.287  audio_features
# ...                ...       ...      ...      ...             ...
# 3645          0.012400    0.1160    0.739  110.808  audio_features
# 3646          0.001080    0.0599    0.575  122.074  audio_features
# 3647          0.000124    0.1530    0.925  105.634  audio_features
# 3648          0.063000    0.1110    0.686  119.895  audio_features
# 3649          0.000000    0.1510    0.210  131.603  audio_features
#
#                           id                                   uri  \
# 0     1GcVa4jFySlun4jLSuMhiq  spotify:track:1GcVa4jFySlun4jLSuMhiq
# 1     5ChkMS8OtdzJeqyybCc9R5  spotify:track:5ChkMS8OtdzJeqyybCc9R5
# 2     0aym2LBJBk9DAYuHHutrIl  spotify:track:0aym2LBJBk9DAYuHHutrIl
# 3     3lUjT0JcV1PcuugwMl2MQj  spotify:track:3lUjT0JcV1PcuugwMl2MQj
# 4     1tqT6DhmsrtQgyCKUwotiw  spotify:track:1tqT6DhmsrtQgyCKUwotiw
# ...                      ...                                   ...
# 3645  5RqCmbI9RfoJu1oSXk3UTi  spotify:track:5RqCmbI9RfoJu1oSXk3UTi
# 3646  0WujVnyLeCEOoPpdV2wOj6  spotify:track:0WujVnyLeCEOoPpdV2wOj6
# 3647  3OiMyoS1QCu8ozdDEj1WWD  spotify:track:3OiMyoS1QCu8ozdDEj1WWD
# 3648  5wdlG60d0WHoo8P3QzrlbG  spotify:track:5wdlG60d0WHoo8P3QzrlbG
# 3649  4V3AGIIQeJoBUPaTCLiscB  spotify:track:4V3AGIIQeJoBUPaTCLiscB
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/1GcVa4jFySlu...
# 1     https://api.spotify.com/v1/tracks/5ChkMS8OtdzJ...
# 2     https://api.spotify.com/v1/tracks/0aym2LBJBk9D...
# 3     https://api.spotify.com/v1/tracks/3lUjT0JcV1Pc...
# 4     https://api.spotify.com/v1/tracks/1tqT6DhmsrtQ...
# ...                                                 ...
# 3645  https://api.spotify.com/v1/tracks/5RqCmbI9RfoJ...
# 3646  https://api.spotify.com/v1/tracks/0WujVnyLeCEO...
# 3647  https://api.spotify.com/v1/tracks/3OiMyoS1QCu8...
# 3648  https://api.spotify.com/v1/tracks/5wdlG60d0WHo...
# 3649  https://api.spotify.com/v1/tracks/4V3AGIIQeJoB...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/1GcV...       272000
# 1     https://api.spotify.com/v1/audio-analysis/5Chk...       293827
# 2     https://api.spotify.com/v1/audio-analysis/0aym...       425653
# 3     https://api.spotify.com/v1/audio-analysis/3lUj...       520787
# 4     https://api.spotify.com/v1/audio-analysis/1tqT...       194293
# ...                                                 ...          ...
# 3645  https://api.spotify.com/v1/audio-analysis/5RqC...       359960
# 3646  https://api.spotify.com/v1/audio-analysis/0Wuj...       256267
# 3647  https://api.spotify.com/v1/audio-analysis/3OiM...       277707
# 3648  https://api.spotify.com/v1/audio-analysis/5wdl...       470507
# 3649  https://api.spotify.com/v1/audio-analysis/4V3A...       211920
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 3645               4
# 3646               4
# 3647               4
# 3648               4
# 3649               4
#
# [3650 rows x 18 columns]

# %%
#export to csv
top_5000_pop_af_df.to_csv("../data/top_5000_pop_af.csv")

# %% [markdown]
# ### 1000 greatest songs of all time

# %%
greatest_songs_all_time_playlist_id = "2LOxEzC4KmoWJ9NhW0kz5M"
greatest_songs_all_time_username = "maxaustralia"
greatest_songs_all_time_af_df = playlist_audio_features(greatest_songs_all_time_username,greatest_songs_all_time_playlist_id)
greatest_songs_all_time_af_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.414   0.404    0    -9.928     0       0.0499      0.271000
# 1           0.446   0.952    6    -5.321     1       0.0523      0.090100
# 2           0.502   0.912    1    -4.556     1       0.0564      0.000025
# 3           0.547   0.257    0   -12.358     1       0.0252      0.907000
# 4           0.369   0.762   10    -8.993     1       0.0464      0.220000
# ..            ...     ...  ...       ...   ...          ...           ...
# 987         0.531   0.948    9    -5.438     1       0.0568      0.006000
# 988         0.558   0.768    2    -9.997     1       0.0343      0.121000
# 989         0.535   0.505    2    -8.926     0       0.2450      0.039300
# 990         0.445   0.706    8    -9.803     1       0.0461      0.234000
# 991         0.490   0.827    8    -9.481     1       0.0482      0.000212
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000000    0.3000    0.224   71.105  audio_features
# 1            0.085700    0.1120    0.624  125.303  audio_features
# 2            0.000173    0.1060    0.720  116.761  audio_features
# 3            0.183000    0.0935    0.169   75.752  audio_features
# 4            0.000028    0.5790    0.644   84.957  audio_features
# ..                ...       ...      ...      ...             ...
# 987          0.011700    0.6940    0.498  136.891  audio_features
# 988          0.062600    0.1240    0.429   81.909  audio_features
# 989          0.000000    0.0923    0.495   99.935  audio_features
# 990          0.000252    0.2050    0.768   80.823  audio_features
# 991          0.004060    0.1120    0.626  108.577  audio_features
#
#                          id                                   uri  \
# 0    4u7EnebtmKWzUH433cf5Qv  spotify:track:4u7EnebtmKWzUH433cf5Qv
# 1    7snQQk1zcKl8gZ92AnueZW  spotify:track:7snQQk1zcKl8gZ92AnueZW
# 2    4CeeEOM32jQcH3eN9Q2dGj  spotify:track:4CeeEOM32jQcH3eN9Q2dGj
# 3    7pKfPomDEeI4TPT6EOYjn9  spotify:track:7pKfPomDEeI4TPT6EOYjn9
# 4    5NwkWwfRJaT55hEPtCmJHx  spotify:track:5NwkWwfRJaT55hEPtCmJHx
# ..                      ...                                   ...
# 987  3UrDYCWfY6fTsiA63NNL27  spotify:track:3UrDYCWfY6fTsiA63NNL27
# 988  44aTAUBF0g6sMkMNE8I5kd  spotify:track:44aTAUBF0g6sMkMNE8I5kd
# 989  0uEp9E98JB5awlA084uaIg  spotify:track:0uEp9E98JB5awlA084uaIg
# 990  43DeSV93pJPT4lCZaWZ6b1  spotify:track:43DeSV93pJPT4lCZaWZ6b1
# 991  4D01oA1mGouaAT7fubvKRT  spotify:track:4D01oA1mGouaAT7fubvKRT
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/4u7EnebtmKWz...
# 1    https://api.spotify.com/v1/tracks/7snQQk1zcKl8...
# 2    https://api.spotify.com/v1/tracks/4CeeEOM32jQc...
# 3    https://api.spotify.com/v1/tracks/7pKfPomDEeI4...
# 4    https://api.spotify.com/v1/tracks/5NwkWwfRJaT5...
# ..                                                 ...
# 987  https://api.spotify.com/v1/tracks/3UrDYCWfY6fT...
# 988  https://api.spotify.com/v1/tracks/44aTAUBF0g6s...
# 989  https://api.spotify.com/v1/tracks/0uEp9E98JB5a...
# 990  https://api.spotify.com/v1/tracks/43DeSV93pJPT...
# 991  https://api.spotify.com/v1/tracks/4D01oA1mGoua...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/4u7E...       354320
# 1    https://api.spotify.com/v1/audio-analysis/7snQ...       356067
# 2    https://api.spotify.com/v1/audio-analysis/4Cee...       301920
# 3    https://api.spotify.com/v1/audio-analysis/7pKf...       187867
# 4    https://api.spotify.com/v1/audio-analysis/5Nwk...       302107
# ..                                                 ...          ...
# 987  https://api.spotify.com/v1/audio-analysis/3UrD...       298093
# 988  https://api.spotify.com/v1/audio-analysis/44aT...       260573
# 989  https://api.spotify.com/v1/audio-analysis/0uEp...       320267
# 990  https://api.spotify.com/v1/audio-analysis/43De...       266720
# 991  https://api.spotify.com/v1/audio-analysis/4D01...       179360
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 987               4
# 988               4
# 989               4
# 990               4
# 991               4
#
# [992 rows x 18 columns]

# %%
#export to csv
greatest_songs_all_time_af_df.to_csv("../data/greatest_songs_all_time_af.csv")

# %% [markdown]
# ### Longest playlist ever

# %%
longest_playlist_ever_playlist_id = "6yPiKpy7evrwvZodByKvM9"
longest_playlist_ever_username = "12160726861"
longest_playlist_ever_af_df = playlist_audio_features(longest_playlist_ever_username,longest_playlist_ever_playlist_id)
longest_playlist_ever_af_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 3
#       1 longest_playlist_ever_playlist_id = "6yPiKpy7evrwvZodByKvM9"
#       2 longest_playlist_ever_username = "12160726861"
# ----> 3 longest_playlist_ever_af_df = playlist_audio_features(longest_playlist_ever_username,longest_playlist_ever_playlist_id)
#       4 longest_playlist_ever_af_df
#
# Cell In[58], line 21, in playlist_audio_features(username, playlist_id)
#      18         print(f"Error retrieving audio features for chunk: {e}")
#      20 # Create dataframe
# ---> 21 af_df = pd.DataFrame(af_list)
#      23 return af_df
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:806, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     804     if columns is not None:
#     805         columns = ensure_index(columns)
# --> 806     arrays, columns, index = nested_data_to_arrays(
#     807         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     808         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#     809         data,
#     810         columns,
#     811         index,  # type: ignore[arg-type]
#     812         dtype,
#     813     )
#     814     mgr = arrays_to_mgr(
#     815         arrays,
#     816         columns,
#    (...)
#     819         typ=manager,
#     820     )
#     821 else:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/construction.py:520, in nested_data_to_arrays(data, columns, index, dtype)
#     517 if is_named_tuple(data[0]) and columns is None:
#     518     columns = ensure_index(data[0]._fields)
# --> 520 arrays, columns = to_arrays(data, columns, dtype=dtype)
#     521 columns = ensure_index(columns)
#     523 if index is None:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/construction.py:837, in to_arrays(data, columns, dtype)
#     835     arr = _list_to_arrays(data)
#     836 elif isinstance(data[0], abc.Mapping):
# --> 837     arr, columns = _list_of_dict_to_arrays(data, columns)
#     838 elif isinstance(data[0], ABCSeries):
#     839     arr, columns = _list_of_series_to_arrays(data, columns)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/construction.py:917, in _list_of_dict_to_arrays(data, columns)
#     915     gen = (list(x.keys()) for x in data)
#     916     sort = not any(isinstance(d, dict) for d in data)
# --> 917     pre_cols = lib.fast_unique_multiple_list_gen(gen, sort=sort)
#     918     columns = ensure_index(pre_cols)
#     920 # assure that they are of the base dict class and not of derived
#     921 # classes
#
# File lib.pyx:393, in pandas._libs.lib.fast_unique_multiple_list_gen()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/construction.py:915, in <genexpr>(.0)
#     895 """
#     896 Convert list of dicts to numpy arrays
#     897
#    (...)
#     912 columns : Index
#     913 """
#     914 if columns is None:
# --> 915     gen = (list(x.keys()) for x in data)
#     916     sort = not any(isinstance(d, dict) for d in data)
#     917     pre_cols = lib.fast_unique_multiple_list_gen(gen, sort=sort)
#
# AttributeError: 'NoneType' object has no attribute 'keys'

# %% [markdown]
# Note: my function 'playlist audio feature' returned an error for this playlist. below is the investigative work on why this happened

# %% [markdown]
# #### Investigation

# %%
longest_playlist_ever_test_playlist_id = "6yPiKpy7evrwvZodByKvM9"
longest_playlist_ever_test_username = "12160726861"

tracks = get_playlist_tracks(longest_playlist_ever_test_username,longest_playlist_ever_test_playlist_id)

# %%
#for all
track_ids = []
for i in tracks:
    track_ids.append(i['track']['id'])

# %% [markdown]
# Note: identified 'None' values in list of track ids. I believe this is why my function was returning an error. I believe song on spotify being "unavailable" results in a track_id of 'none'

# %%
#removing null values
filtered_track_ids = [item for item in track_ids if item is not None]

# %%
#Chopping into chunks
chunk_size = 100
filtered_track_ids_chopped = [filtered_track_ids[i:i+chunk_size] for i in range(0,len(filtered_track_ids), 100)]

# %%
#getting audio features
af_list_2 = []
for i in filtered_track_ids_chopped:
    af_list_2.extend(sp.audio_features(i))

# %%
af_list_2_filtered = [item for item in af_list_2 if item is not None]

# %%
#creating data frame
longest_playlist_ever_af_df_2 = pd.DataFrame(af_list_2_filtered)

# %%
longest_playlist_ever_af_df_2
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.406   0.445    7   -13.355     0       0.0745       0.09300
# 1            0.419   0.565    5   -11.565     1       0.0347       0.13700
# 2            0.532   0.303    9   -13.076     1       0.0311       0.58700
# 3            0.717   0.800    5    -5.794     0       0.0497       0.37100
# 4            0.571   0.724    0    -5.967     1       0.0260       0.02310
# ...            ...     ...  ...       ...   ...          ...           ...
# 9912         0.651   0.801    0    -7.340     1       0.0514       0.12300
# 9913         0.812   0.644    0   -10.761     1       0.0493       0.08770
# 9914         0.687   0.606    7    -5.920     1       0.0262       0.17800
# 9915         0.711   0.718    6    -5.739     1       0.0380       0.00824
# 9916         0.324   0.997    1    -3.440     1       0.2640       0.00772
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.072100    0.1130    0.123  134.972  audio_features
# 1             0.337000    0.1280    0.648  151.277  audio_features
# 2             0.065700    0.1110    0.225  124.157  audio_features
# 3             0.158000    0.3270    0.954  129.642  audio_features
# 4             0.003110    0.0919    0.385  116.755  audio_features
# ...                ...       ...      ...      ...             ...
# 9912          0.000000    0.0825    0.776  133.769  audio_features
# 9913          0.785000    0.0563    0.989  140.075  audio_features
# 9914          0.000326    0.0830    0.748   80.569  audio_features
# 9915          0.002080    0.0732    0.688  117.071  audio_features
# 9916          0.110000    0.9480    0.316  200.031  audio_features
#
#                           id                                   uri  \
# 0     3lMSWyB8H0A0rSRhUDSwoz  spotify:track:3lMSWyB8H0A0rSRhUDSwoz
# 1     3UnyplmZaq547hwsfOR5yy  spotify:track:3UnyplmZaq547hwsfOR5yy
# 2     3HPLfZhQUds6N6tZ4WiApn  spotify:track:3HPLfZhQUds6N6tZ4WiApn
# 3     5iFhkFf9JLA3XiROdYsg1i  spotify:track:5iFhkFf9JLA3XiROdYsg1i
# 4     1VZedwJj1gyi88WFRhfThb  spotify:track:1VZedwJj1gyi88WFRhfThb
# ...                      ...                                   ...
# 9912  5jzma6gCzYtKB1DbEwFZKH  spotify:track:5jzma6gCzYtKB1DbEwFZKH
# 9913  7Bz8yww6UMbTgTVLG6zbI4  spotify:track:7Bz8yww6UMbTgTVLG6zbI4
# 9914  0jpk88zk40MjQ63ljrq7V2  spotify:track:0jpk88zk40MjQ63ljrq7V2
# 9915  0sEm1ld0V8YTCPcjPVfIsc  spotify:track:0sEm1ld0V8YTCPcjPVfIsc
# 9916  1ZRPhbplXmODTxBfmILr16  spotify:track:1ZRPhbplXmODTxBfmILr16
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/3lMSWyB8H0A0...
# 1     https://api.spotify.com/v1/tracks/3UnyplmZaq54...
# 2     https://api.spotify.com/v1/tracks/3HPLfZhQUds6...
# 3     https://api.spotify.com/v1/tracks/5iFhkFf9JLA3...
# 4     https://api.spotify.com/v1/tracks/1VZedwJj1gyi...
# ...                                                 ...
# 9912  https://api.spotify.com/v1/tracks/5jzma6gCzYtK...
# 9913  https://api.spotify.com/v1/tracks/7Bz8yww6UMbT...
# 9914  https://api.spotify.com/v1/tracks/0jpk88zk40Mj...
# 9915  https://api.spotify.com/v1/tracks/0sEm1ld0V8YT...
# 9916  https://api.spotify.com/v1/tracks/1ZRPhbplXmOD...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/3lMS...       152560
# 1     https://api.spotify.com/v1/audio-analysis/3Uny...       197707
# 2     https://api.spotify.com/v1/audio-analysis/3HPL...       244285
# 3     https://api.spotify.com/v1/audio-analysis/5iFh...       250000
# 4     https://api.spotify.com/v1/audio-analysis/1VZe...       278320
# ...                                                 ...          ...
# 9912  https://api.spotify.com/v1/audio-analysis/5jzm...       200480
# 9913  https://api.spotify.com/v1/audio-analysis/7Bz8...       190827
# 9914  https://api.spotify.com/v1/audio-analysis/0jpk...       206307
# 9915  https://api.spotify.com/v1/audio-analysis/0sEm...       200293
# 9916  https://api.spotify.com/v1/audio-analysis/1ZRP...       409013
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 9912               4
# 9913               4
# 9914               4
# 9915               4
# 9916               4
#
# [9917 rows x 18 columns]

# %%
#export to csv
longest_playlist_ever_af_df_2.to_csv("../data/longest_playlist_ever_af.csv")

# %% [markdown]
# ### Worlds largest playlist

# %%
worlds_largest_playlist_id = "4vBaGi0msaCBxhAq9lWXk3"
worlds_largest_username = "larrypeay"
worlds_largest_af_df = playlist_audio_features(worlds_largest_username,worlds_largest_playlist_id)
worlds_largest_af_df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.485   0.721    5    -7.840     0       0.0348        0.4790
# 1            0.402   0.643    5    -8.749     1       0.0317        0.2400
# 2            0.489   0.561    4    -7.933     1       0.0274        0.2000
# 3            0.568   0.634    4   -12.336     1       0.0282        0.4940
# 4            0.714   0.886   11    -8.629     0       0.0554        0.1160
# ...            ...     ...  ...       ...   ...          ...           ...
# 5595         0.660   0.639    9   -12.749     1       0.0369        0.0966
# 5596         0.511   0.308    7   -15.021     1       0.0247        0.4080
# 5597         0.612   0.876    0    -7.836     1       0.0340        0.0949
# 5598         0.620   0.427    0   -13.819     1       0.0294        0.7330
# 5599         0.246   0.343   10   -15.643     1       0.0303        0.7960
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.6700    0.880  136.892  audio_features
# 1             0.000039    0.1180    0.525  150.086  audio_features
# 2             0.000046    0.1790    0.238   83.457  audio_features
# 3             0.002810    0.2520    0.866  142.686  audio_features
# 4             0.184000    0.1800    0.954  156.351  audio_features
# ...                ...       ...      ...      ...             ...
# 5595          0.001040    0.0442    0.843   84.124  audio_features
# 5596          0.000024    0.1500    0.380   83.545  audio_features
# 5597          0.000045    0.0764    0.971  135.106  audio_features
# 5598          0.000142    0.0929    0.931   87.777  audio_features
# 5599          0.483000    0.1430    0.374  170.276  audio_features
#
#                           id                                   uri  \
# 0     6rBgZvSsyJrk5ZXtKc8mcf  spotify:track:6rBgZvSsyJrk5ZXtKc8mcf
# 1     5OuaAMBmGjjJMK7yXpaFAK  spotify:track:5OuaAMBmGjjJMK7yXpaFAK
# 2     1KHdq8NK9QxnGjdXb55NiG  spotify:track:1KHdq8NK9QxnGjdXb55NiG
# 3     40h65HAR8COEoqkMwUUQHu  spotify:track:40h65HAR8COEoqkMwUUQHu
# 4     3oAWTk92mZBxKBOKf8mR5v  spotify:track:3oAWTk92mZBxKBOKf8mR5v
# ...                      ...                                   ...
# 5595  3PJ9yQv8IUmLx24KFvaVEI  spotify:track:3PJ9yQv8IUmLx24KFvaVEI
# 5596  2Xa2C6ftMdcg3j7YSot8dY  spotify:track:2Xa2C6ftMdcg3j7YSot8dY
# 5597  5hrNXBpS7BDrZtIsqNpReY  spotify:track:5hrNXBpS7BDrZtIsqNpReY
# 5598  2ons8YrupZvbMgJoL3zy77  spotify:track:2ons8YrupZvbMgJoL3zy77
# 5599  5DBEFajBEaHgbbwe7oN0KP  spotify:track:5DBEFajBEaHgbbwe7oN0KP
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/6rBgZvSsyJrk...
# 1     https://api.spotify.com/v1/tracks/5OuaAMBmGjjJ...
# 2     https://api.spotify.com/v1/tracks/1KHdq8NK9Qxn...
# 3     https://api.spotify.com/v1/tracks/40h65HAR8COE...
# 4     https://api.spotify.com/v1/tracks/3oAWTk92mZBx...
# ...                                                 ...
# 5595  https://api.spotify.com/v1/tracks/3PJ9yQv8IUmL...
# 5596  https://api.spotify.com/v1/tracks/2Xa2C6ftMdcg...
# 5597  https://api.spotify.com/v1/tracks/5hrNXBpS7BDr...
# 5598  https://api.spotify.com/v1/tracks/2ons8YrupZvb...
# 5599  https://api.spotify.com/v1/tracks/5DBEFajBEaHg...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/6rBg...       142573
# 1     https://api.spotify.com/v1/audio-analysis/5Oua...       199707
# 2     https://api.spotify.com/v1/audio-analysis/1KHd...       244987
# 3     https://api.spotify.com/v1/audio-analysis/40h6...       257963
# 4     https://api.spotify.com/v1/audio-analysis/3oAW...       119360
# ...                                                 ...          ...
# 5595  https://api.spotify.com/v1/audio-analysis/3PJ9...       194667
# 5596  https://api.spotify.com/v1/audio-analysis/2Xa2...       235560
# 5597  https://api.spotify.com/v1/audio-analysis/5hrN...       249827
# 5598  https://api.spotify.com/v1/audio-analysis/2ons...       192200
# 5599  https://api.spotify.com/v1/audio-analysis/5DBE...       450107
#
#       time_signature
# 0                  4
# 1                  4
# 2                  3
# 3                  4
# 4                  4
# ...              ...
# 5595               4
# 5596               4
# 5597               4
# 5598               4
# 5599               3
#
# [5600 rows x 18 columns]

# %%
#export to csv
worlds_largest_af_df.to_csv("../data/worlds_largest_af.csv")

# %% [markdown]
# ### R&B Throwbacks 90s & 00s

# %%
r_and_b_throwbacks_playlist_id = "7s17jTD83GgeKajAMogIen"
r_and_b_throwbacks_username = "12145397198"
r_and_b_throwbacks_af_df = playlist_audio_features(r_and_b_throwbacks_username,r_and_b_throwbacks_playlist_id)
r_and_b_throwbacks_af_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.727   0.552    2    -8.074     0       0.1400        0.2270
# 1           0.622   0.593    7    -8.352     0       0.0916        0.1630
# 2           0.684   0.455    5    -8.216     1       0.0307        0.2150
# 3           0.536   0.612    4    -5.847     1       0.2720        0.1190
# 4           0.412   0.876    5    -6.008     0       0.4700        0.1020
# ..            ...     ...  ...       ...   ...          ...           ...
# 291         0.468   0.723    1    -5.344     1       0.0782        0.1900
# 292         0.730   0.602    6    -3.782     0       0.2060        0.3620
# 293         0.794   0.662    6    -4.913     0       0.2490        0.0789
# 294         0.764   0.821    4    -6.095     0       0.1940        0.0922
# 295         0.652   0.473    0    -7.981     0       0.0313        0.2430
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000164    0.1980    0.607  168.189  audio_features
# 1            0.000000    0.0979    0.607   94.364  audio_features
# 2            0.000001    0.2630    0.487   97.956  audio_features
# 3            0.000000    0.2090    0.570   86.768  audio_features
# 4            0.000000    0.2970    0.703  130.159  audio_features
# ..                ...       ...      ...      ...             ...
# 291          0.000000    0.3660    0.449  178.860  audio_features
# 292          0.000004    0.1690    0.927   97.954  audio_features
# 293          0.000000    0.0937    0.683   93.053  audio_features
# 294          0.000000    0.1590    0.962  162.495  audio_features
# 295          0.000000    0.1340    0.368  123.208  audio_features
#
#                          id                                   uri  \
# 0    0ARK753YaiJbpLUk7z5yIM  spotify:track:0ARK753YaiJbpLUk7z5yIM
# 1    5WphWTUIfRe7x8NZss79cY  spotify:track:5WphWTUIfRe7x8NZss79cY
# 2    174rZBKJAqD10VBnOjlQQ3  spotify:track:174rZBKJAqD10VBnOjlQQ3
# 3    7DFnq8FYhHMCylykf6ZCxA  spotify:track:7DFnq8FYhHMCylykf6ZCxA
# 4    5Y77SQxEr1eiofPeUTPHxM  spotify:track:5Y77SQxEr1eiofPeUTPHxM
# ..                      ...                                   ...
# 291  1PzVLh1uoq5pAUnqNQElQq  spotify:track:1PzVLh1uoq5pAUnqNQElQq
# 292  69XUpOpjzDKcfdxqZebGiI  spotify:track:69XUpOpjzDKcfdxqZebGiI
# 293  6Wnlq1Pu3I0BajLvxn05Vr  spotify:track:6Wnlq1Pu3I0BajLvxn05Vr
# 294  75ABQumvUWSaUsEGjZFu3G  spotify:track:75ABQumvUWSaUsEGjZFu3G
# 295  2b29qJRy4asbQNFjPO96XC  spotify:track:2b29qJRy4asbQNFjPO96XC
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/0ARK753YaiJb...
# 1    https://api.spotify.com/v1/tracks/5WphWTUIfRe7...
# 2    https://api.spotify.com/v1/tracks/174rZBKJAqD1...
# 3    https://api.spotify.com/v1/tracks/7DFnq8FYhHMC...
# 4    https://api.spotify.com/v1/tracks/5Y77SQxEr1ei...
# ..                                                 ...
# 291  https://api.spotify.com/v1/tracks/1PzVLh1uoq5p...
# 292  https://api.spotify.com/v1/tracks/69XUpOpjzDKc...
# 293  https://api.spotify.com/v1/tracks/6Wnlq1Pu3I0B...
# 294  https://api.spotify.com/v1/tracks/75ABQumvUWSa...
# 295  https://api.spotify.com/v1/tracks/2b29qJRy4asb...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/0ARK...       289160
# 1    https://api.spotify.com/v1/audio-analysis/5Wph...       249093
# 2    https://api.spotify.com/v1/audio-analysis/174r...       216893
# 3    https://api.spotify.com/v1/audio-analysis/7DFn...       229040
# 4    https://api.spotify.com/v1/audio-analysis/5Y77...       273133
# ..                                                 ...          ...
# 291  https://api.spotify.com/v1/audio-analysis/1PzV...       181027
# 292  https://api.spotify.com/v1/audio-analysis/69XU...       221133
# 293  https://api.spotify.com/v1/audio-analysis/6Wnl...       284640
# 294  https://api.spotify.com/v1/audio-analysis/75AB...       282173
# 295  https://api.spotify.com/v1/audio-analysis/2b29...       294867
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 5
# ..              ...
# 291               4
# 292               4
# 293               4
# 294               4
# 295               4
#
# [296 rows x 18 columns]

# %%
#export to csv
r_and_b_throwbacks_af_df.to_csv("../data/r_and_b_throwbacks_af.csv")

# %% [markdown]
# ### Billboard_hot_100

# %%
billboard_hot_100_playlist_id = "6UeSakyzhiEt4NB3UAd6NQ"
billboard_hot_100_username = "billboard.com"
billboard_hot_100_af_df = playlist_audio_features(billboard_hot_100_username,billboard_hot_100_playlist_id)
billboard_hot_100_af_df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.745   0.663    1    -5.056     1       0.4230        0.0780
# 1          0.943   0.558    2    -4.911     1       0.0568        0.0026
# 2          0.552   0.702    9    -5.707     1       0.1570        0.1170
# 3          0.561   0.604    9    -4.409     1       0.0337        0.1990
# 4          0.750   0.733    6    -3.180     0       0.0319        0.2560
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.431   0.628   10    -6.259     0       0.0384        0.4030
# 96         0.486   0.640    3    -8.027     1       0.0551        0.1360
# 97         0.606   0.757    1    -6.206     1       0.0302        0.0157
# 98         0.455   0.621    0    -7.694     0       0.0517        0.6510
# 99         0.808   0.719   10    -4.980     0       0.1050        0.1880
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000000    0.2130    0.686  167.137  audio_features
# 1           0.000002    0.0937    0.606  104.983  audio_features
# 2           0.000021    0.1050    0.564  169.994  audio_features
# 3           0.000019    0.1040    0.242  159.920  audio_features
# 4           0.000000    0.1140    0.844  111.018  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.000008    0.2720    0.277  118.016  audio_features
# 96          0.000076    0.1050    0.289  122.017  audio_features
# 97          0.000205    0.3430    0.588  103.051  audio_features
# 98          0.000003    0.1230    0.280  119.043  audio_features
# 99          0.000000    0.2040    0.569   94.998  audio_features
#
#                         id                                   uri  \
# 0   79AHPJd8upvNxyK2qQcY8J  spotify:track:79AHPJd8upvNxyK2qQcY8J
# 1   4xhsWYTOGcal8zt0J161CU  spotify:track:4xhsWYTOGcal8zt0J161CU
# 2   1BxfuPKGuaTgP7aM0Bbdwr  spotify:track:1BxfuPKGuaTgP7aM0Bbdwr
# 3   6usohdchdzW9oML7VC4Uhk  spotify:track:6usohdchdzW9oML7VC4Uhk
# 4   3rUGC1vUpkDG9CZFHMur1t  spotify:track:3rUGC1vUpkDG9CZFHMur1t
# ..                     ...                                   ...
# 95  6RWCvgNCEqXuVZYnDTPDEh  spotify:track:6RWCvgNCEqXuVZYnDTPDEh
# 96  4oEf84vBYVftf6KmZexhVo  spotify:track:4oEf84vBYVftf6KmZexhVo
# 97  0lbHiQaHPlp5gGtsUPtj6l  spotify:track:0lbHiQaHPlp5gGtsUPtj6l
# 98  4kjI1gwQZRKNDkw1nI475M  spotify:track:4kjI1gwQZRKNDkw1nI475M
# 99  08oo0eCDQZ9XC3zQR8q44y  spotify:track:08oo0eCDQZ9XC3zQR8q44y
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/79AHPJd8upvN...
# 1   https://api.spotify.com/v1/tracks/4xhsWYTOGcal...
# 2   https://api.spotify.com/v1/tracks/1BxfuPKGuaTg...
# 3   https://api.spotify.com/v1/tracks/6usohdchdzW9...
# 4   https://api.spotify.com/v1/tracks/3rUGC1vUpkDG...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/6RWCvgNCEqXu...
# 96  https://api.spotify.com/v1/tracks/4oEf84vBYVft...
# 97  https://api.spotify.com/v1/tracks/0lbHiQaHPlp5...
# 98  https://api.spotify.com/v1/tracks/4kjI1gwQZRKN...
# 99  https://api.spotify.com/v1/tracks/08oo0eCDQZ9X...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/79AH...       192819
# 1   https://api.spotify.com/v1/audio-analysis/4xhs...       138411
# 2   https://api.spotify.com/v1/audio-analysis/1Bxf...       178427
# 3   https://api.spotify.com/v1/audio-analysis/6uso...       210689
# 4   https://api.spotify.com/v1/audio-analysis/3rUG...       131872
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/6RWC...       250880
# 96  https://api.spotify.com/v1/audio-analysis/4oEf...       267256
# 97  https://api.spotify.com/v1/audio-analysis/0lbH...       162345
# 98  https://api.spotify.com/v1/audio-analysis/4kjI...       251250
# 99  https://api.spotify.com/v1/audio-analysis/08oo...       188333
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                3
# 4                1
# ..             ...
# 95               4
# 96               4
# 97               4
# 98               4
# 99               4
#
# [100 rows x 18 columns]

# %%
#export to csv
billboard_hot_100_af_df.to_csv("../data/billboard_hot_100_af.csv")

# %% [markdown]
# ## Final dataframe

# %%
#Import latest dataframe
full_af_from_csv = pd.read_csv('../data/full_af.csv')

# %%
full_af = pd.concat([full_af_from_csv,greatest_songs_all_time_af_df,worlds_largest_af_df,r_and_b_throwbacks_af_df], ignore_index=True)
full_af
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 full_af = pd.concat([full_af_from_csv,greatest_songs_all_time_af_df,worlds_largest_af_df,r_and_b_throwbacks_af_df], ignore_index=True)
#       2 full_af
#
# NameError: name 'greatest_songs_all_time_af_df' is not defined

# %%
#export to csv
full_af.to_csv("../data/full_af.csv")

# %%
full_af = full_af.drop_duplicates()
full_af
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.382   0.451    7    -6.606     0       0.0293        0.5570
# 1             0.742   0.375    7   -13.829     1       0.0482        0.3970
# 2             0.585   0.552    0   -10.613     1       0.0353        0.1940
# 3             0.405   0.535    6    -7.504     0       0.0531        0.0531
# 4             0.586   0.526    0    -6.928     1       0.0564        0.5550
# ...             ...     ...  ...       ...   ...          ...           ...
# 13943         0.660   0.639    9   -12.749     1       0.0369        0.0966
# 13944         0.511   0.308    7   -15.021     1       0.0247        0.4080
# 13945         0.612   0.876    0    -7.836     1       0.0340        0.0949
# 13946         0.620   0.427    0   -13.819     1       0.0294        0.7330
# 13947         0.246   0.343   10   -15.643     1       0.0303        0.7960
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.000034    0.2650    0.506  150.803  audio_features
# 1              0.901000    0.0996    0.105  102.023  audio_features
# 2              0.017100    0.0735    0.496  100.089  audio_features
# 3              0.106000    0.0696    0.637   97.698  audio_features
# 4              0.000000    0.2340    0.456  107.153  audio_features
# ...                 ...       ...      ...      ...             ...
# 13943          0.001040    0.0442    0.843   84.124  audio_features
# 13944          0.000024    0.1500    0.380   83.545  audio_features
# 13945          0.000045    0.0764    0.971  135.106  audio_features
# 13946          0.000142    0.0929    0.931   87.777  audio_features
# 13947          0.483000    0.1430    0.374  170.276  audio_features
#
#                            id                                   uri  \
# 0      6yzJiHzsscf0n88xb9aNT4  spotify:track:6yzJiHzsscf0n88xb9aNT4
# 1      5zdXRoKLZ54VBdbdn7yhz4  spotify:track:5zdXRoKLZ54VBdbdn7yhz4
# 2      5qvCKAyjgHnpR5c63OedCY  spotify:track:5qvCKAyjgHnpR5c63OedCY
# 3      2vByA9JgfMU2bPjUqmxCdv  spotify:track:2vByA9JgfMU2bPjUqmxCdv
# 4      0pPQwIjwqduvLfZORYYEaI  spotify:track:0pPQwIjwqduvLfZORYYEaI
# ...                       ...                                   ...
# 13943  3PJ9yQv8IUmLx24KFvaVEI  spotify:track:3PJ9yQv8IUmLx24KFvaVEI
# 13944  2Xa2C6ftMdcg3j7YSot8dY  spotify:track:2Xa2C6ftMdcg3j7YSot8dY
# 13945  5hrNXBpS7BDrZtIsqNpReY  spotify:track:5hrNXBpS7BDrZtIsqNpReY
# 13946  2ons8YrupZvbMgJoL3zy77  spotify:track:2ons8YrupZvbMgJoL3zy77
# 13947  5DBEFajBEaHgbbwe7oN0KP  spotify:track:5DBEFajBEaHgbbwe7oN0KP
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/6yzJiHzsscf0...
# 1      https://api.spotify.com/v1/tracks/5zdXRoKLZ54V...
# 2      https://api.spotify.com/v1/tracks/5qvCKAyjgHnp...
# 3      https://api.spotify.com/v1/tracks/2vByA9JgfMU2...
# 4      https://api.spotify.com/v1/tracks/0pPQwIjwqduv...
# ...                                                  ...
# 13943  https://api.spotify.com/v1/tracks/3PJ9yQv8IUmL...
# 13944  https://api.spotify.com/v1/tracks/2Xa2C6ftMdcg...
# 13945  https://api.spotify.com/v1/tracks/5hrNXBpS7BDr...
# 13946  https://api.spotify.com/v1/tracks/2ons8YrupZvb...
# 13947  https://api.spotify.com/v1/tracks/5DBEFajBEaHg...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/6yzJ...       267540
# 1      https://api.spotify.com/v1/audio-analysis/5zdX...       342163
# 2      https://api.spotify.com/v1/audio-analysis/5qvC...       267813
# 3      https://api.spotify.com/v1/audio-analysis/2vBy...       210800
# 4      https://api.spotify.com/v1/audio-analysis/0pPQ...       161267
# ...                                                  ...          ...
# 13943  https://api.spotify.com/v1/audio-analysis/3PJ9...       194667
# 13944  https://api.spotify.com/v1/audio-analysis/2Xa2...       235560
# 13945  https://api.spotify.com/v1/audio-analysis/5hrN...       249827
# 13946  https://api.spotify.com/v1/audio-analysis/2ons...       192200
# 13947  https://api.spotify.com/v1/audio-analysis/5DBE...       450107
#
#        time_signature
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 13943               4
# 13944               4
# 13945               4
# 13946               4
# 13947               3
#
# [10970 rows x 18 columns]
